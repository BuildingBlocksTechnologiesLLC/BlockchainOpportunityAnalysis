# %%
# loading dependencies
import numpy as np
import pandas as pd
import os, json
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import time 
import re
import pickle

# %% [markdown]
# ## load data
# I first loaded the labeled training data. I kept features such as salary, location, company name from NER as well as url,and body of each file. They are then turned into a dataframe.

# %%
path = 'Data/Jobs_labeled/'
def open_file(path):
    json_files = [pos_json for pos_json in os.listdir(path)]
    #df = pd.DataFrame(columns=['label', 'site', 'url', 'title', 'body'])
    df = pd.DataFrame(columns=['label','site','title_loc','title_org', 'salary', 'url', 'title', 'body'])
        
    for index, js in enumerate(json_files):
        with open(os.path.join(path, js)) as json_file:
            job = json.load(json_file)
            label = job['Label']
            # include NER entities
            site = job['DomainId']
            title_loc = job['Location']
            title_org = job['CompanyName']
            salary = job['Salary']
            url = job['Url']
            title = job['Title']
            body = job['Body']
            #df.loc[index] = [label, site, url, title, body]
            df.loc[index] = [label,site, title_loc, title_org, salary, url, title, body]
    return df

# %%
start = time.time()
df = open_file(path)
end = time.time()
end - start # The wall time is about 10 minutes for combining 50k json files to a dataframe.
# Out:
# 865.835198879242

# %%
df.head()
# Out:
#   label         site                                 title_loc     title_org  \
# 0     0  simplyhired                                 Not Found     Not Found
# 1     1     linkedin          Chicago, Illinois, United States  CapB InfoteK
# 2     0  simplyhired                                 Not Found     Not Found
# 3     0  simplyhired                                 Not Found     Not Found
# 4     1     linkedin  San Francisco, California, United States        Solana
#
#       salary                                                url  \
# 0  Not Found  https://www.simplyhired.com/search?q=general%2...
# 1  Not Found  https://www.linkedin.com/jobs/view/java-8-deve...
# 2  Not Found  https://za.simplyhired.com/search?q=education&...
# 3  Not Found  https://www.simplyhired.com/search?q=coinbase&...
# 4  Not Found  https://www.linkedin.com/jobs/view/software-en...
#
#                                                title  \
# 0  20 Best general+dynamics+mission+systems,+inc ...
# 1  CapB InfoteK hiring Java 8 Developer in Chicag...
# 2  20 Best education jobs in Johannesburg, Gauten...
# 3  20 Best coinbase jobs in San Francisco, CA (Hi...
# 4  Solana hiring Software Engineer in San Francis...
#
#                                                 body
# 0   general+dynamics+mission+systems,+inc jobs Ke...
# 1   CapB is a global leader on IT Solutions and M...
# 2  Skip to content Ã Sign In or Create Account U...
# 3   coinbase jobs near San Francisco, CA Keywords...
# 4   Solana is a high performant blockchain that c...

# %%
# checking for the balance of the labels 
print('The distribution of real job posting is %f.' % (sum(df['label'])/len(df['label'])))
# Out:
# The distribution of real job posting is 0.500036.

# %% [markdown]
# ## Preprocessing
# Location, salary info and company name are turned into indicator variables. For each row, if those entity exists, "1" is assigned to it, 0 otherwise.

# %%
df_updated = df.replace({'title_loc' : 'Not Found', 'title_org' : 'Not Found', 'salary' : 'Not Found'}, 0)

# %%
df_updated.loc[~df_updated["title_loc"].isin([0]), "title_loc"] = 1

# %%
df_updated.loc[~df_updated["title_org"].isin([0]), "title_org"] = 1

# %%
df_updated.loc[~df_updated["salary"].isin([0]), "salary"] = 1

# %%
df_updated
# Out:
#        label            site  title_loc  title_org  salary  \
# 0          0     simplyhired          0          0       0
# 1          1        linkedin          1          1       0
# 2          0     simplyhired          0          0       0
# 3          0     simplyhired          0          0       0
# 4          1        linkedin          1          1       0
# 5          0          google          0          1       0
# 6          0     simplyhired          0          0       0
# 7          1        linkedin          1          1       0
# 8          1        linkedin          1          1       0
# 9          0          google          0          1       0
# 10         0     simplyhired          0          0       0
# 11         1  cryptojobslist          0          1       0
# 12         1        linkedin          1          1       0
# 13         1        linkedin          1          1       0
# 14         0     simplyhired          0          0       0
# 15         1         monster          1          1       0
# 16         0     simplyhired          0          0       0
# 17         0     simplyhired          0          0       0
# 18         0     simplyhired          0          0       0
# 19         0     simplyhired          0          0       0
# 20         1        linkedin          1          1       0
# 21         0     simplyhired          0          0       0
# 22         1        linkedin          1          1       0
# 23         0     simplyhired          0          0       0
# 24         0     simplyhired          0          0       0
# 25         0     simplyhired          0          0       0
# 26         1            dice          1          1       0
# 27         0     simplyhired          0          0       0
# 28         1        linkedin          1          1       0
# 29         1        linkedin          1          1       0
# ...      ...             ...        ...        ...     ...
# 41479      0     simplyhired          0          0       0
# 41480      1        linkedin          1          1       0
# 41481      0          google          1          1       0
# 41482      0          google          1          1       0
# 41483      1         monster          1          1       0
# 41484      0     simplyhired          0          0       0
# 41485      1        linkedin          1          1       0
# 41486      1        linkedin          1          1       0
# 41487      0     simplyhired          0          0       0
# 41488      0          google          0          1       0
# 41489      1        linkedin          1          1       0
# 41490      1        linkedin          1          1       0
# 41491      1        linkedin          1          1       0
# 41492      1        linkedin          1          1       0
# 41493      0     simplyhired          0          0       0
# 41494      1        linkedin          1          1       0
# 41495      1        linkedin          1          1       0
# 41496      0     simplyhired          0          0       0
# 41497      1     simplyhired          1          0       1
# 41498      0     simplyhired          0          0       0
# 41499      1     simplyhired          1          1       1
# 41500      1        linkedin          1          1       1
# 41501      1        linkedin          1          1       0
# 41502      1        linkedin          1          1       0
# 41503      1          crypto          1          1       1
# 41504      1        linkedin          1          1       0
# 41505      0          google          0          1       0
# 41506      0          google          0          1       0
# 41507      0          google          0          1       0
# 41508      0     simplyhired          0          0       0
#
#                                                      url  \
# 0      https://www.simplyhired.com/search?q=general%2...
# 1      https://www.linkedin.com/jobs/view/java-8-deve...
# 2      https://za.simplyhired.com/search?q=education&...
# 3      https://www.simplyhired.com/search?q=coinbase&...
# 4      https://www.linkedin.com/jobs/view/software-en...
# 5      https://www.google.com/search?ie=UTF-8&tbm=isc...
# 6      https://www.simplyhired.com/search/Data-and-Da...
# 7      https://www.linkedin.com/jobs/view/corejava-de...
# 8      https://www.linkedin.com/jobs/view/research-sc...
# 9      https://www.google.com/search?ie=UTF-8&tbm=isc...
# 10     https://www.simplyhired.de/search?q=empfang&l=...
# 11     https://cryptojobslist.com/jobs/site-reliabili...
# 12     https://www.linkedin.com/jobs/view/blockchain-...
# 13     https://www.linkedin.com/jobs/view/vp-of-produ...
# 14     https://www.simplyhired.com/search?q=medici%2B...
# 15     https://job-openings.monster.com/cryptographic...
# 16     https://www.simplyhired.com/search?q=capb%2Bin...
# 17     https://www.simplyhired.com/search?q=cisco%2Bs...
# 18     https://www.simplyhired.com/search?q=blockchai...
# 19     https://www.simplyhired.com/search?q=u.s.%2Bar...
# 20     https://www.linkedin.com/jobs/view/platform-en...
# 21     https://www.simplyhired.com/search?q=blockchai...
# 22     https://sg.linkedin.com/jobs/view/blockchain-c...
# 23     https://www.simplyhired.de/search?q=fahrer&fdb...
# 24     https://www.simplyhired.com/search?q=blockchai...
# 25     https://www.simplyhired.com/search?q=blockchai...
# 26     https://www.dice.com/jobs/detail/UX-Writer-%28...
# 27     https://www.simplyhired.com/search?q=capb%2Bin...
# 28     https://www.linkedin.com/jobs/view/developer-m...
# 29     https://nl.linkedin.com/jobs/view/informatiema...
# ...                                                  ...
# 41479  https://www.simplyhired.com/search/Technology/...
# 41480  https://www.linkedin.com/jobs/view/junior-it-s...
# 41481  https://www.google.com/search?ie=UTF-8&tbm=isc...
# 41482  https://www.google.com/search?ie=UTF-8&tbm=isc...
# 41483  https://job-openings.monster.com/production-en...
# 41484  https://www.simplyhired.com/search/map?q=block...
# 41485  https://www.linkedin.com/jobs/view/blockchain-...
# 41486  https://fr.linkedin.com/jobs/view/blockchain-p...
# 41487  https://www.simplyhired.com/search?q=capb%2Bin...
# 41488  https://www.google.com/search?ie=UTF-8&tbm=isc...
# 41489  https://www.linkedin.com/jobs/view/quantitativ...
# 41490  https://www.linkedin.com/jobs/view/software-en...
# 41491  https://www.linkedin.com/jobs/view/software-en...
# 41492  https://www.linkedin.com/jobs/view/sales-devel...
# 41493  https://www.simplyhired.com/search/Technology/...
# 41494  https://www.linkedin.com/jobs/view/software-en...
# 41495  https://www.linkedin.com/jobs/view/ux-writer-t...
# 41496  https://www.simplyhired.com/search?q=capb%2Bin...
# 41497  https://www.simplyhired.com/job/_IzyMUd7IXUno0...
# 41498  https://www.simplyhired.com/search?q=ibm&fdb=1...
# 41499  https://www.simplyhired.com/job/A4UM8TYtPHdtel...
# 41500  https://www.linkedin.com/jobs/view/java-full-s...
# 41501  https://www.linkedin.com/jobs/view/blockchain-...
# 41502  https://www.linkedin.com/jobs/view/senior-soft...
# 41503  https://crypto.jobs/jobs/technical-marketing-m...
# 41504  https://www.linkedin.com/jobs/view/technical-p...
# 41505  https://www.google.com/search?ie=UTF-8&tbm=isc...
# 41506  https://www.google.com/search?ie=UTF-8&tbm=isc...
# 41507  https://www.google.com/search?ie=UTF-8&tbm=isc...
# 41508  https://za.simplyhired.com/search?q=attorney&p...
#
#                                                    title  \
# 0      20 Best general+dynamics+mission+systems,+inc ...
# 1      CapB InfoteK hiring Java 8 Developer in Chicag...
# 2      20 Best education jobs in Johannesburg, Gauten...
# 3      20 Best coinbase jobs in San Francisco, CA (Hi...
# 4      Solana hiring Software Engineer in San Francis...
# 5                        blockchain+jobs - Google Search
# 6      20 Best Data and Database jobs (Hiring Now!) |...
# 7      Synechron hiring CoreJava Developer in Charlot...
# 8      Findora hiring Research Scientist, Consensus/D...
# 9               blockchain+contract+jobs - Google Search
# 10             empfang Jobs in DÃ¼sseldorf | SimplyHired
# 11      Site Reliability Engineer job at NEAR | Anywhere
# 12     80Twenty hiring Blockchain Developer in New Yo...
# 13     EM Talent Consulting hiring VP of Product in N...
# 14     20 Best medici+ventures,+inc. jobs in Midvale,...
# 15     Cryptographic Security Architect job at Citize...
# 16     20 Best capb+infotek jobs (Hiring Now!) | Simp...
# 17     3 Best cisco+systems jobs in Boston, MA (Hirin...
# 18     20 Best blockchain jobs in San Francisco, CA (...
# 19     8 Best u.s.+army+new+england+recruiting+battal...
# 20     Ripple hiring Platform Engineer in San Francis...
# 21     20 Best blockchain jobs in Mountain View, CA (...
# 22     PayPal hiring Blockchain Customer Experience/ ...
# 23                             fahrer Jobs | SimplyHired
# 24     3 Best blockchain jobs in Waltham, MA (Hiring ...
# 25     20 Best blockchain jobs in New York, NY (Hirin...
# 26     UX Writer (Cryptocurrency / Equity / Trading) ...
# 27     2 Best capb+infotek jobs (Hiring Now!) | Simpl...
# 28     Libra Association hiring Developer Marketing L...
# 29     Gemeente Papendrecht hiring Informatiemanager ...
# ...                                                  ...
# 41479  20 Best Technology jobs (Hiring Now!) | Simply...
# 41480  Blockchain.com hiring Junior IT Support & Offi...
# 41481                    blockchain+jobs - Google Search
# 41482       blockchain+jobs+for+freshers - Google Search
# 41483  Production Engineer - Remote job at Axoni | Mo...
# 41484  20 Best blockchain jobs in Midvale, UT (Hiring...
# 41485  8K Miles Software Services Ltd hiring BLOCKCHA...
# 41486  Wavestone hiring BLOCKCHAIN : POUR QUELS USAGE...
# 41487  20 Best capb+infotek jobs (Hiring Now!) | Simp...
# 41488                    blockchain+jobs - Google Search
# 41489  Trade Terminal hiring Quantitative Researcher ...
# 41490  Messari hiring Software Engineer - Blockchain ...
# 41491  Anchorage hiring Software Engineer (Backend | ...
# 41492  R3 hiring Sales Development Representative in ...
# 41493  20 Best Technology jobs (Hiring Now!) | Simply...
# 41494  Energy Resourcing Canada Ltd. hiring Software ...
# 41495  MindSource hiring UX writer: Trading in San Fr...
# 41496  20 Best capb+infotek jobs (Hiring Now!) | Simp...
# 41497  Blockchain Technology Lead - Travoom | Santa M...
# 41498       20 Best ibm jobs (Hiring Now!) | SimplyHired
# 41499  Data Warehouse Developer - CapB InfoteK | Whip...
# 41500  Synechron hiring Java Full Stack Developer in ...
# 41501  Sila hiring Blockchain Infrastructure Engineer...
# 41502  TRON Foundation hiring Senior Software Enginee...
# 41503          Technical Marketing Manager Job at Status
# 41504  Coinbase hiring Technical Program Manager, Str...
# 41505                    blockchain+jobs - Google Search
# 41506                    blockchain+jobs - Google Search
# 41507                    blockchain+jobs - Google Search
# 41508  20 Best attorney jobs (Hiring Now!) | SimplyHired
#
#                                                     body
# 0       general+dynamics+mission+systems,+inc jobs Ke...
# 1       CapB is a global leader on IT Solutions and M...
# 2      Skip to content Ã Sign In or Create Account U...
# 3       coinbase jobs near San Francisco, CA Keywords...
# 4       Solana is a high performant blockchain that c...
# 5      ALL NEWS IMAGES VIDEOS blockchain+technology??...
# 6      Skip to content Ã Sign In or Create Account U...
# 7       Synechron is one of the fastest-growing digit...
# 8       Research Scientists work with a talented team...
# 9      ALL NEWS IMAGES VIDEOS bitcoin????????????????...
# 10     Skip to content Ã Anmelden oder Konto erstell...
# 11     Site Reliability Engineer at NEAR NEAR is a sh...
# 12      We have partnered with one of the fastest gro...
# 13      Full-Time position New York City, NY Client E...
# 14     Skip to content Ã Sign In or Create Account U...
# 15      Cryptographic Security Architect at Citizens ...
# 16      capb+infotek jobs Keywords Location Search Jo...
# 17      cisco+systems jobs near Boston, MA Keywords L...
# 18     Skip to content Ã Sign In or Create Account U...
# 19      u.s.+army+new+england+recruiting+battalion jo...
# 20      As a Platform Engineer, you will play a criti...
# 21      blockchain jobs near Mountain View, CA Keywor...
# 22      Who We Are Fueled by a fundamental belief tha...
# 23     Skip to content Ã Anmelden oder Konto erstell...
# 24      blockchain jobs near Waltham, MA Keywords Loc...
# 25     Skip to content Ã Sign In or Create Account U...
# 26      UX Writer (Cryptocurrency / Equity / Trading)...
# 27      capb+infotek jobs Keywords Location Search Jo...
# 28      Position Description The Libra Association se...
# 29      Informatiemanager Papendrecht, 32 uur per wee...
# ...                                                  ...
# 41479   Technology jobs Keywords Location Search Jobs...
# 41480   What You Will Do Building and office manageme...
# 41481  ALL NEWS IMAGES VIDEOS job+openings???????????...
# 41482  ALL NEWS IMAGES VIDEOS blockchain+technology??...
# 41483   Production Engineer - Remote at Axoni New Yor...
# 41484  Skip to content Ã Sign In or Create Account U...
# 41485   Hi , We have an job immediate opening for BLO...
# 41486   Description du poste CONTEXTE La Blockchain, ...
# 41487   capb+infotek jobs Keywords Location Search Jo...
# 41488  ALL NEWS IMAGES VIDEOS job+openings???????????...
# 41489   We take 3 kinds of people, 1, People who has ...
# 41490   Messari is a fast growth startup in New York ...
# 41491   Role Description Build secure, resilient, and...
# 41492   R3 is an enterprise blockchain software firm ...
# 41493   Technology jobs Keywords Location Search Jobs...
# 41494   Software Engineer- Full Stack?? Permanent rol...
# 41495   MindSource thrives on placing the best kept s...
# 41496   capb+infotek jobs Keywords Location Search Jo...
# 41497   Blockchain Technology Lead Travoom - Santa Mo...
# 41498   ibm jobs Keywords Location Search Jobs Techno...
# 41499   Data Warehouse Developer CapB InfoteK - Whipp...
# 41500   Direct message the job poster from Synechron ...
# 41501   Direct message the job poster from Sila Bruce...
# 41502   TRON is dedicated to build the infrastructure...
# 41503   Please read first! About Status Status is the...
# 41504   Location: San Francisco, CA Coinbase has buil...
# 41505  ALL NEWS IMAGES VIDEOS job+market?????????????...
# 41506  ALL NEWS IMAGES VIDEOS smart+contracts????????...
# 41507  ALL NEWS IMAGES VIDEOS ethereum???????????????...
# 41508  Skip to content Ã Sign In or Create Account U...
#
# [41509 rows x 8 columns]

# %% [markdown]
# ### NLP preprcessing for the body of the text in json files
# Four features are considered in the training set, location, salary, company name, and the body of each job posting. NLP preprocessing work has been done for the body corpus including stemming, stop words evaluation, and processing bigrams.

# %%
import preprocessing as prep

# %%
# function to perform lemmatize and stem preprocessing steps on the data set.
preprocessor = prep.Preprocessor(df_updated['body'])
preprocessor.preprocess(lemmatize=True, stopwords=[], min_token_length=3)
preprocessor.get_bigrams_from_preprocessed()
preprocessed_text = preprocessor.preprocessed_text_

# %%
body_list = []
for i, arr in enumerate(preprocessed_text):
    l = ' '.join(preprocessed_text[i])
    body_list.append(l)

# %% [markdown]
# ### TF-IDF
# Document-term matrix tf-idf for corpus is made through the sklearn library.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer1 = TfidfVectorizer(max_features = 1000)

x_train_tfidf = vectorizer1.fit_transform(body_list)

vocabulary=vectorizer1.vocabulary_

# %%
with open('vocab.pickle', 'wb') as handle:
    pickle.dump(vocabulary, handle, protocol=pickle.HIGHEST_PROTOCOL)

    '''
with open('vocab.pickle', 'rb') as handle:
    b = pickle.load(handle)
    '''

# %%
x_train_tfidf = x_train_tfidf.toarray()

# %%
x_train_tfidf.shape
# Out:
# (41509, 1000)

# %% [markdown]
# ## Training
# After creating the sparse matrix for the body corpus, it is combined with the other three features.

# %%
salary = np.array(df_updated["salary"]).reshape(41509, 1)
#feature_matrix_1 = np.concatenate((x_train_tfidf, salary), axis=1)
feature_matrix_1 = np.hstack((x_train_tfidf, salary))

# %%
feature_matrix_1.shape
# Out:
# (41509, 1001)

# %%
title_loc = np.array(df_updated["title_loc"]).reshape(41509, 1)
title_org = np.array(df_updated["title_org"]).reshape(41509, 1)
feature_matrix_2 = np.hstack((title_loc, title_org))

# %%
feature_matrix_2.shape
# Out:
# (41509, 2)

# %%
X_train = np.hstack((feature_matrix_1, feature_matrix_2))

# %%
X_train.shape
# Out:
# (41509, 1003)

# %%
y = np.array(df_updated.label)
# Divide the data into training and validation sets. By default, 25% goes into the test set.
X_train, x_valid, y_train, y_valid = train_test_split(X_train, y, random_state=0, test_size = 0.3)

# %%
# label encode the target variable 
encoder = preprocessing.LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_valid = encoder.fit_transform(y_valid)

# %% [markdown]
# ## Model fitting

# %% [markdown]
# ## Naive Bayes
# Using naive Bayes for training and validation

# %%
from sklearn.naive_bayes import MultinomialNB
clf =  MultinomialNB().fit(X_train, y_train)

# %%
predicted = clf.predict(x_valid)
np.mean(predicted == y_valid)
# Out:
# 0.9844214245563319

# %% [markdown]
# ## Linear SVM
# Using SVM for training and validation

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC()
clf_2 = svm.fit(X_train,y_train)

# %%
predicted = clf_2.predict(x_valid)
np.mean(predicted == y_valid)
# Out:
# 0.9996787922588934

# %% [markdown]
# ## Saving the model

# %%
# save the model to disk
filename = 'svm_classifier.sav'
pickle.dump(clf_2, open(filename, 'wb'))
