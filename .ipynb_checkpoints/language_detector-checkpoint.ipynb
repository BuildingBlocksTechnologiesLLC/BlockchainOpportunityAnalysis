# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score

# %%
import re

# %%
## Loading data

# %%
labels_file = 'wili-2018/labels.csv'
x_train_file = 'wili-2018/x_train.txt'
y_train_file = 'wili-2018/y_train.txt'
x_test_file = 'wili-2018/x_test.txt'
y_test_file = 'wili-2018/y_test.txt'

# %%
def read_file(x, y):
    
    # Read contents of 'y_file' into a dataframe
    y_df = pd.read_csv(y_file, header=None)
    # y_df has only one column; name it 'Label'
    y_df.columns = ['Label']

    # Read contents of 'x_file' into a list of strings
    with open(x_file, encoding='utf8') as f:
        x_pars = f.readlines()
    
    # Remove all whitespace characters (such as '\n') from the beginning and the end of the strings
    x_pars = [t.strip() for t in x_pars]
    # Convert the list into a dataframe, with one column: 'Par'
    x_df = pd.DataFrame(x_pars, columns=['Par']) 
    return (x_df, y_df)

# %%
x_train, y_train = read_file(x_train_file, y_train_file)

# %%
labels_df = pd.read_csv(labels_file, sep=';')
labels_df
# Out:
#          Label                     English  Wiki Code ISO 369-3  \
# 0          ace                    Achinese        ace       ace
# 1          afr                   Afrikaans         af       afr
# 2          als            Alemannic German        als       gsw
# 3          amh                     Amharic         am       amh
# 4          ang                Old English         ang       ang
# 5          ara                      Arabic         ar       ara
# 6          arg                   Aragonese         an       arg
# 7          arz             Egyptian Arabic        arz       arz
# 8          asm                    Assamese         as       asm
# 9          ast                    Asturian        ast       ast
# 10         ava                        Avar         av       ava
# 11         aym                      Aymara         ay       aym
# 12         azb           South Azerbaijani        azb       azb
# 13         aze                 Azerbaijani         az       aze
# 14         bak                     Bashkir         ba       bak
# 15         bar                    Bavarian        bar       bar
# 16         bcl               Central Bikol        bcl       bcl
# 17   be-tarask  Belarusian (Taraschkewiza)  be-tarask       NaN
# 18         bel                  Belarusian         be       bel
# 19         ben                     Bengali         bn       ben
# 20         bho                    Bhojpuri         bh       bho
# 21         bjn                      Banjar        bjn       bjn
# 22         bod                     Tibetan         bo       bod
# 23         bos                     Bosnian         bs       bos
# 24         bpy                 Bishnupriya        bpy       bpy
# 25         bre                      Breton         br       bre
# 26         bul                   Bulgarian         bg       bul
# 27         bxr                      Buryat        bxr       bxr
# 28         cat                     Catalan         ca       cat
# 29         cbk                   Chavacano    cbk-zam       cbk
# ..         ...                         ...        ...       ...
# 205        tgk                       Tajik         tg       tgk
# 206        tgl                     Tagalog         tl       tgl
# 207        tha                        Thai         th       tha
# 208        ton                      Tongan         to       ton
# 209        tsn                      Tswana         tn       tsn
# 210        tuk                     Turkmen         tk       tuk
# 211        tur                     Turkish         tr       tur
# 212        tyv                       Tuvan        tyv       tyv
# 213        udm                      Udmurt        udm       udm
# 214        uig                      Uighur         ug       uig
# 215        ukr                   Ukrainian         uk       ukr
# 216        urd                        Urdu         ur       urd
# 217        uzb                       Uzbek         uz       uzb
# 218        vec                    Venetian        vec       vec
# 219        vep                        Veps        vep       vep
# 220        vie                  Vietnamese         vi       vie
# 221        vls                      Vlaams        vls       vls
# 222        vol                     Volapük         vo       vol
# 223        vro                        Võro    fiu-vro       vro
# 224        war                       Waray        war       war
# 225        wln                     Walloon         wa       wln
# 226        wol                       Wolof         wo       wol
# 227        wuu                  Wu Chinese        wuu       wuu
# 228        xho                       Xhosa         xh       xho
# 229        xmf                  Mingrelian        xmf       xmf
# 230        yid                     Yiddish         yi       yid
# 231        yor                      Yoruba         yo       yor
# 232        zea                      Zeeuws        zea       zea
# 233     zh-yue                   Cantonese     zh-yue       NaN
# 234        zho            Standard Chinese         zh       zho
#
#                            German      Language family  \
# 0                     Achinesisch         Austronesian
# 1                       Afrikaans        Indo-European
# 2                     Alemannisch        Indo-European
# 3                       Amharisch         Afro-Asiatic
# 4                     Altenglisch        Indo-European
# 5                        Arabisch         Afro-Asiatic
# 6                    Aragonesisch        Indo-European
# 7              Ägyptisch-Arabisch         Afro-Asiatic
# 8                     Assamesisch        Indo-European
# 9                       Asturisch        Indo-European
# 10                       Awarisch  Northeast Caucasian
# 11                         Aymara              Aymaran
# 12           Südaserbaidschanisch               Turkic
# 13              Aserbaidschanisch               Turkic
# 14                   Baschkirisch               Turkic
# 15                       Bairisch        Indo-European
# 16                       Bikolano         Austronesian
# 17   Weißrussisch (Taraschkewiza)        Indo-European
# 18                   Weißrussisch        Indo-European
# 19                     Bengalisch        Indo-European
# 20                       Bhojpuri        Indo-European
# 21                   Banjaresisch         Austronesian
# 22                      Tibetisch         Sino-Tibetan
# 23                       Bosnisch        Indo-European
# 24           Bishnupriya Manipuri        Indo-European
# 25                     Bretonisch        Indo-European
# 26                     Bulgarisch        Indo-European
# 27                     Burjatisch             Mongolic
# 28                    Katalanisch        Indo-European
# 29                      Chabacano        Indo-European
# ..                            ...                  ...
# 205                  Tadschikisch        Indo-European
# 206                       Tagalog         Austronesian
# 207                  Thailändisch            Tai-Kadai
# 208                     Tongaisch         Austronesian
# 209                      Setswana          Niger-Congo
# 210                   Turkmenisch               Turkic
# 211                      Türkisch               Turkic
# 212                     Tuwinisch               Turkic
# 213                    Udmurtisch               Uralic
# 214                     Uigurisch               Turkic
# 215                    Ukrainisch        Indo-European
# 216                          Urdu        Indo-European
# 217                     Usbekisch               Turkic
# 218                     Venetisch        Indo-European
# 219                      Wepsisch               Uralic
# 220                 Vietnamesisch         Austronesian
# 221                  Westflämisch        Indo-European
# 222                       Volapük          Constructed
# 223                          Võro               Uralic
# 224                   Wáray-Wáray         Austronesian
# 225                    Wallonisch        Indo-European
# 226                         Wolof          Niger-Congo
# 227                            Wu         Sino-Tibetan
# 228                      isiXhosa          Niger-Congo
# 229                   Mingrelisch           Kartvelian
# 230                      Jiddisch        Indo-European
# 231                        Yoruba          Niger-Congo
# 232                   Seeländisch        Indo-European
# 233                  Kantonesisch         Sino-Tibetan
# 234                    Chinesisch         Sino-Tibetan
#
#                                         Writing system  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                              Arabic
# 13                                               Latin
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27   Cyrillic:::Mongolian script:::Vagindra script:...
# 28                                               Latin
# 29                                                 NaN
# ..                                                 ...
# 205                                                NaN
# 206                                                NaN
# 207                                                NaN
# 208                                              Latin
# 209                                              Latin
# 210                                                NaN
# 211                                                NaN
# 212                                           Cyrillic
# 213                                                NaN
# 214                                                NaN
# 215                                           Cyrillic
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219                                                NaN
# 220                                              Latin
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                              Latin
# 225                                                NaN
# 226                                     Latin:::Arabic
# 227                                                NaN
# 228                                              Latin
# 229                                                NaN
# 230                                                NaN
# 231                                                NaN
# 232                                                NaN
# 233                                                NaN
# 234                                                NaN
#
#                            Remarks        Synonyms
# 0                              NaN             NaN
# 1                              NaN             NaN
# 2    (ursprünglich nur Elsässisch)             NaN
# 3                              NaN             NaN
# 4                   (ca. 450-1100)  Angelsächsisch
# 5                              NaN             NaN
# 6                              NaN             NaN
# 7                              NaN             NaN
# 8                              NaN             NaN
# 9                              NaN             NaN
# 10                             NaN             NaN
# 11                             NaN             NaN
# 12                             NaN             NaN
# 13                             NaN             NaN
# 14                             NaN             NaN
# 15                             NaN             NaN
# 16                             NaN             NaN
# 17                             NaN             NaN
# 18                      (normativ)             NaN
# 19                             NaN             NaN
# 20                             NaN             NaN
# 21                             NaN             NaN
# 22                             NaN             NaN
# 23                             NaN             NaN
# 24                             NaN             NaN
# 25                             NaN             NaN
# 26                             NaN             NaN
# 27                             NaN          Buriat
# 28                             NaN             NaN
# 29                             NaN             NaN
# ..                             ...             ...
# 205                            NaN             NaN
# 206                            NaN             NaN
# 207                            NaN             NaN
# 208                            NaN             NaN
# 209                            NaN        Setswana
# 210                            NaN             NaN
# 211                            NaN             NaN
# 212                            NaN             NaN
# 213                            NaN             NaN
# 214                            NaN             NaN
# 215                            NaN             NaN
# 216                            NaN             NaN
# 217                            NaN             NaN
# 218                            NaN             NaN
# 219                            NaN             NaN
# 220                            NaN             NaN
# 221                            NaN             NaN
# 222                            NaN             NaN
# 223                            NaN             NaN
# 224                            NaN             NaN
# 225                            NaN             NaN
# 226                            NaN             NaN
# 227                            NaN             NaN
# 228                            NaN        isiXhosa
# 229                            NaN             NaN
# 230                            NaN             NaN
# 231                            NaN             NaN
# 232                            NaN             NaN
# 233                            NaN             NaN
# 234                            NaN             NaN
#
# [235 rows x 9 columns]

# %%
y_tr_1k = y_train[0:1000]

# %%
y_tr_new = y_tr_1k.merge(labels_df, on = "Label", how = "left")
y_tr_new_1k = y_tr_new['English']

# %%
train_list = list(y_tr_new_1k)

# %%
y_tr_new_1k_2 = y_tr_new['Wiki Code']

# %%
y_tr_new_1k_2
# Out:
# 0             et
# 1             sv
# 2            mai
# 3             oc
# 4             th
# 5             om
# 6             li
# 7             gu
# 8            pnb
# 9            zea
# 10           krc
# 11            ht
# 12           pcd
# 13            ta
# 14            vi
# 15            pa
# 16           szl
# 17           ckb
# 18           fur
# 19           wuu
# 20           arz
# 21            to
# 22            eu
# 23       map-bms
# 24           glk
# 25       map-bms
# 26            nl
# 27           arz
# 28            bo
# 29            ja
#          ...
# 970          scn
# 971           yo
# 972           vo
# 973           af
# 974          zea
# 975           qu
# 976          udm
# 977      cbk-zam
# 978           lv
# 979           cs
# 980           cs
# 981          wuu
# 982           af
# 983          zea
# 984           tr
# 985          vls
# 986           wo
# 987          als
# 988          pnb
# 989          pam
# 990          pap
# 991          mhr
# 992           sa
# 993    be-tarask
# 994          cdo
# 995          tcy
# 996           bn
# 997           et
# 998          srn
# 999           an
# Name: Wiki Code, Length: 1000, dtype: object

# %%
## Spacy

# %%
#!pip install spacy-langdetect
#!python -m spacy download en
import spacy
from spacy_langdetect import LanguageDetector

nlp = spacy.load("en")
nlp.add_pipe(LanguageDetector(), name="language_detector", last=True)
text = "This is English text Er lebt mit seinen Eltern und seiner Schwester in Berlin. Yo me divierto todos los días en el parque. Je m'appelle Angélica Summer, j'ai 12 ans et je suis canadienne."
doc = nlp(text)
# document level language detection. Think of it like average language of document!
print(doc._.language['language'])
# sentence level language detection
for i, sent in enumerate(doc.sents):
    print(sent, sent._.language)
# Out:
# fr
# This is English text {'language': 'en', 'score': 0.9999983198032172}
# Er lebt mit seinen {'language': 'de', 'score': 0.9999969687866875}
# Eltern und seiner Schwester in Berlin. {'language': 'de', 'score': 0.9999956876999901}
# Yo me {'language': 'id', 'score': 0.9999947568149832}
# divierto todos los días en el parque. {'language': 'es', 'score': 0.999996449223586}
# Je m'appelle Angélica Summer, j'ai 12 ans et je suis canadienne. {'language': 'fr', 'score': 0.999997298086013}

# %%
predictions = []
for i in range(1000): 
    doc = nlp(x_train['Par'][i])
    predicted_lang = doc._.language['language']
    print(predicted_lang)
    predictions.append(predicted_lang)
# Out:
# et
# en
# hi
# ca
# th
# so
# nl
# en
# ur
# nl
# ru
# no
# fr
# ta
# vi
# pa
# pl
# fa
# it
# zh-cn
# ar
# fi
# nl
# id
# fa
# id
# nl
# ar
# zh-cn
# ja
# es
# es
# es
# UNKNOWN
# tr
# ru
# tr
# tl
# tr
# de
# ru
# ca
# ru
# de
# ur
# ru
# ja
# ru
# UNKNOWN
# id
# ru
# ko
# da
# pt
# fr
# so
# tl
# ne
# no
# hr
# mr
# UNKNOWN
# UNKNOWN
# hr
# sl
# hr
# id
# zh-cn
# ko
# ru
# ro
# es
# so
# bg
# th
# en
# sw
# id
# tr
# sw
# id
# nl
# ru
# ru
# ne
# sw
# et
# ro
# pt
# vi
# en
# bn
# hr
# hi
# mr
# fr
# ca
# ca
# it
# UNKNOWN
# sw
# ta
# tl
# hu
# pl
# ru
# cy
# fr
# id
# vi
# ru
# it
# uk
# tr
# cy
# no
# tl
# he
# et
# es
# bg
# ru
# ru
# no
# tr
# fr
# fr
# mr
# de
# ru
# ne
# no
# tr
# tr
# et
# ko
# de
# ru
# de
# it
# hr
# pl
# no
# no
# no
# vi
# ru
# de
# cy
# mk
# fa
# de
# te
# sw
# nl
# mr
# sl
# fa
# uk
# es
# pl
# ca
# no
# nl
# bg
# UNKNOWN
# id
# so
# it
# fa
# nl
# nl
# fr
# ca
# it
# fr
# ru
# ru
# af
# ro
# fa
# ar
# et
# fi
# fa
# nl
# tr
# en
# fa
# fr
# fa
# es
# ca
# gu
# en
# ru
# it
# fr
# ro
# hi
# no
# ca
# sw
# hi
# fr
# mk
# de
# ru
# lv
# et
# lv
# cs
# lv
# vi
# id
# ru
# id
# id
# es
# ru
# da
# id
# ru
# it
# ru
# ja
# et
# lt
# mr
# af
# id
# ar
# tl
# lt
# ru
# it
# fr
# sq
# so
# id
# sk
# es
# it
# it
# id
# vi
# pl
# fa
# it
# so
# de
# uk
# sw
# it
# es
# lt
# hr
# fr
# hi
# tr
# tr
# es
# pl
# hi
# ru
# sv
# tl
# en
# vi
# en
# cy
# bg
# de
# fr
# it
# ro
# zh-cn
# bn
# lt
# pl
# ru
# es
# it
# lt
# id
# kn
# fi
# ru
# he
# id
# bn
# cy
# ru
# ne
# tr
# et
# ru
# sw
# pa
# it
# UNKNOWN
# en
# pt
# it
# tl
# UNKNOWN
# en
# kn
# id
# en
# cs
# et
# ur
# it
# et
# ru
# tl
# bn
# sw
# en
# ru
# cy
# en
# id
# id
# nl
# lt
# et
# ne
# id
# vi
# fr
# ru
# fa
# id
# ru
# zh-tw
# es
# it
# ja
# ar
# ko
# sk
# nl
# vi
# tl
# fa
# ne
# ml
# ru
# fi
# tl
# he
# nl
# ru
# ru
# vi
# tr
# id
# en
# en
# ru
# af
# et
# sv
# UNKNOWN
# id
# en
# es
# sw
# so
# uk
# en
# ne
# bn
# ru
# ko
# uk
# nl
# id
# nl
# sq
# it
# bn
# ru
# ko
# ru
# zh-cn
# et
# fi
# en
# ru
# UNKNOWN
# ru
# et
# et
# bg
# ru
# nl
# ru
# ar
# pl
# ne
# ur
# ca
# id
# id
# tr
# ar
# tr
# ur
# id
# it
# hi
# ur
# en
# tl
# ur
# tl
# it
# zh-tw
# it
# ru
# ur
# es
# fr
# de
# de
# en
# en
# pl
# sv
# cy
# en
# ne
# de
# he
# nl
# no
# id
# et
# so
# tr
# lt
# vi
# de
# it
# cy
# hr
# en
# ru
# mr
# uk
# ru
# ru
# ru
# af
# pt
# el
# tl
# pt
# fa
# UNKNOWN
# no
# pt
# sw
# ca
# no
# cy
# de
# ru
# en
# en
# de
# es
# ro
# mk
# kn
# UNKNOWN
# vi
# bg
# fa
# sq
# vi
# he
# pl
# en
# ru
# so
# ru
# pt
# UNKNOWN
# hi
# ru
# ru
# fa
# gu
# ar
# it
# et
# sw
# te
# ru
# es
# tr
# pt
# pl
# bg
# af
# ur
# UNKNOWN
# es
# ne
# af
# fi
# ru
# sw
# ru
# it
# id
# it
# id
# it
# lv
# ru
# it
# bn
# ru
# so
# it
# vi
# sw
# vi
# ru
# ru
# id
# nl
# te
# fr
# ta
# sw
# hr
# et
# pt
# hu
# fr
# nl
# it
# tl
# lv
# ne
# ru
# so
# sl
# et
# sv
# et
# ru
# fa
# so
# zh-tw
# ru
# vi
# ru
# tl
# de
# ru
# nl
# tr
# pa
# pt
# sl
# fa
# en
# fr
# ko
# it
# mr
# lv
# ru
# lt
# pt
# hi
# tl
# lv
# he
# it
# bg
# ar
# et
# pl
# ne
# th
# sq
# it
# it
# pt
# es
# ro
# no
# he
# en
# ar
# uk
# sv
# ta
# id
# fa
# sv
# ne
# id
# ru
# af
# vi
# fa
# de
# et
# ru
# sw
# ca
# ca
# lv
# id
# he
# de
# it
# de
# tl
# ca
# ru
# so
# sw
# uk
# ru
# cs
# es
# en
# en
# en
# es
# pl
# uk
# ru
# et
# tl
# id
# en
# no
# vi
# hu
# mk
# it
# fr
# vi
# ca
# et
# af
# fa
# ru
# es
# hi
# ar
# tl
# tr
# sw
# ru
# es
# ro
# ur
# af
# de
# tr
# fi
# uk
# fa
# de
# UNKNOWN
# id
# pa
# es
# de
# ru
# th
# de
# lv
# et
# no
# vi
# et
# hi
# es
# en
# ru
# sv
# fi
# hr
# so
# sv
# bn
# ru
# en
# fa
# ru
# vi
# af
# tl
# ar
# sw
# es
# ru
# ru
# cs
# sv
# ru
# et
# mr
# it
# fa
# it
# fr
# zh-cn
# es
# cy
# zh-tw
# lv
# pl
# tl
# fr
# ru
# ru
# es
# en
# ro
# de
# uk
# et
# es
# ru
# de
# nl
# pt
# ja
# et
# id
# ca
# en
# pt
# kn
# es
# te
# vi
# it
# vi
# hu
# hi
# fr
# af
# hi
# hr
# bn
# fa
# et
# fa
# ru
# en
# it
# ar
# ru
# sw
# de
# ar
# no
# vi
# fr
# fr
# hr
# ca
# ca
# ru
# sl
# pl
# fa
# bg
# sv
# pa
# fr
# de
# it
# it
# tl
# id
# id
# sv
# it
# sw
# nl
# sl
# sw
# fa
# es
# ca
# fa
# nl
# fa
# bg
# hu
# fr
# it
# fi
# ru
# tl
# tl
# ru
# sv
# pl
# fa
# af
# pl
# ro
# sl
# sw
# it
# tr
# en
# bn
# it
# ur
# sw
# pa
# ru
# tr
# bg
# fa
# vi
# ur
# sw
# tl
# id
# en
# et
# cy
# id
# lt
# en
# cy
# ru
# UNKNOWN
# pt
# ne
# te
# et
# et
# it
# hr
# es
# et
# en
# ta
# ru
# pl
# en
# sw
# de
# ru
# mr
# id
# ru
# sv
# he
# de
# bn
# sw
# hi
# fr
# mk
# UNKNOWN
# ta
# hu
# sw
# hi
# id
# tr
# it
# uk
# ro
# hi
# nl
# cy
# ro
# UNKNOWN
# it
# sq
# en
# ca
# mk
# bn
# bg
# sw
# tr
# en
# ko
# id
# es
# en
# ru
# pl
# pl
# ru
# UNKNOWN
# hi
# vi
# it
# so
# tr
# id
# fa
# bg
# ru
# UNKNOWN
# id
# hr
# tl
# ko
# cy
# ca
# ja
# ru
# it
# el
# ru
# zh-cn
# tl
# pt
# pa
# en
# tl
# bn
# fr
# UNKNOWN
# ta
# sq
# id
# ru
# fa
# es
# hi
# pl
# ru
# th
# so
# cy
# ru
# uk
# tl
# et
# no
# UNKNOWN
# es
# pt
# bn
# bn
# af
# ru
# ru
# mk
# it
# tl
# ru
# sw
# bn
# it
# sw
# et
# af
# nl
# so
# ru
# es
# en
# cs
# cs
# zh-cn
# af
# af
# tr
# nl
# en
# de
# ur
# en
# es
# ru
# hi
# uk
# vi
# kn
# bn
# et
# af
# es

# %%
#!pip install pycountry
# Out:
# Collecting pycountry
#   Downloading pycountry-19.8.18.tar.gz (10.0 MB)
#      |████████████████████████████████| 10.0 MB 10.1 MB/s eta 0:00:01
# Building wheels for collected packages: pycountry
#   Building wheel for pycountry (setup.py) ... done
#   Created wheel for pycountry: filename=pycountry-19.8.18-py2.py3-none-any.whl size=10627360 sha256=b5f22b0bb4c3f35ad8a8733fb91750de15b599bbf3ee68f62260a5b25b7183af
#   Stored in directory: /Users/lu_qxl/Library/Caches/pip/wheels/5e/d3/aa/d4d009d8d8489715d33932f44fc2582dfc216e0fde3a5016ee
# Successfully built pycountry
# Installing collected packages: pycountry
# Successfully installed pycountry-19.8.18

# %%
#!pip install pycountry
from pycountry import languages
# Out:
# French

# %%
names = []
for i in range(len(predictions)):
    if predictions[i] == 'UNKNOWN':
        names.append('nan')
    elif predictions[i] == 'zh-cn':
        names.append(languages.get(alpha_2= 'zh').name)
    elif predictions[i] == 'zh-tw':
        names.append(languages.get(alpha_2= 'zh').name)
    else:
        lang_name = languages.get(alpha_2=predictions[i]).name
        print(lang_name)
        names.append(lang_name)
# Out:
# Estonian
# English
# Hindi
# Catalan
# Thai
# Somali
# Dutch
# English
# Urdu
# Dutch
# Russian
# Norwegian
# French
# Tamil
# Vietnamese
# Panjabi
# Polish
# Persian
# Italian
# Arabic
# Finnish
# Dutch
# Indonesian
# Persian
# Indonesian
# Dutch
# Arabic
# Japanese
# Spanish
# Spanish
# Spanish
# Turkish
# Russian
# Turkish
# Tagalog
# Turkish
# German
# Russian
# Catalan
# Russian
# German
# Urdu
# Russian
# Japanese
# Russian
# Indonesian
# Russian
# Korean
# Danish
# Portuguese
# French
# Somali
# Tagalog
# Nepali (macrolanguage)
# Norwegian
# Croatian
# Marathi
# Croatian
# Slovenian
# Croatian
# Indonesian
# Korean
# Russian
# Romanian
# Spanish
# Somali
# Bulgarian
# Thai
# English
# Swahili (macrolanguage)
# Indonesian
# Turkish
# Swahili (macrolanguage)
# Indonesian
# Dutch
# Russian
# Russian
# Nepali (macrolanguage)
# Swahili (macrolanguage)
# Estonian
# Romanian
# Portuguese
# Vietnamese
# English
# Bengali
# Croatian
# Hindi
# Marathi
# French
# Catalan
# Catalan
# Italian
# Swahili (macrolanguage)
# Tamil
# Tagalog
# Hungarian
# Polish
# Russian
# Welsh
# French
# Indonesian
# Vietnamese
# Russian
# Italian
# Ukrainian
# Turkish
# Welsh
# Norwegian
# Tagalog
# Hebrew
# Estonian
# Spanish
# Bulgarian
# Russian
# Russian
# Norwegian
# Turkish
# French
# French
# Marathi
# German
# Russian
# Nepali (macrolanguage)
# Norwegian
# Turkish
# Turkish
# Estonian
# Korean
# German
# Russian
# German
# Italian
# Croatian
# Polish
# Norwegian
# Norwegian
# Norwegian
# Vietnamese
# Russian
# German
# Welsh
# Macedonian
# Persian
# German
# Telugu
# Swahili (macrolanguage)
# Dutch
# Marathi
# Slovenian
# Persian
# Ukrainian
# Spanish
# Polish
# Catalan
# Norwegian
# Dutch
# Bulgarian
# Indonesian
# Somali
# Italian
# Persian
# Dutch
# Dutch
# French
# Catalan
# Italian
# French
# Russian
# Russian
# Afrikaans
# Romanian
# Persian
# Arabic
# Estonian
# Finnish
# Persian
# Dutch
# Turkish
# English
# Persian
# French
# Persian
# Spanish
# Catalan
# Gujarati
# English
# Russian
# Italian
# French
# Romanian
# Hindi
# Norwegian
# Catalan
# Swahili (macrolanguage)
# Hindi
# French
# Macedonian
# German
# Russian
# Latvian
# Estonian
# Latvian
# Czech
# Latvian
# Vietnamese
# Indonesian
# Russian
# Indonesian
# Indonesian
# Spanish
# Russian
# Danish
# Indonesian
# Russian
# Italian
# Russian
# Japanese
# Estonian
# Lithuanian
# Marathi
# Afrikaans
# Indonesian
# Arabic
# Tagalog
# Lithuanian
# Russian
# Italian
# French
# Albanian
# Somali
# Indonesian
# Slovak
# Spanish
# Italian
# Italian
# Indonesian
# Vietnamese
# Polish
# Persian
# Italian
# Somali
# German
# Ukrainian
# Swahili (macrolanguage)
# Italian
# Spanish
# Lithuanian
# Croatian
# French
# Hindi
# Turkish
# Turkish
# Spanish
# Polish
# Hindi
# Russian
# Swedish
# Tagalog
# English
# Vietnamese
# English
# Welsh
# Bulgarian
# German
# French
# Italian
# Romanian
# Bengali
# Lithuanian
# Polish
# Russian
# Spanish
# Italian
# Lithuanian
# Indonesian
# Kannada
# Finnish
# Russian
# Hebrew
# Indonesian
# Bengali
# Welsh
# Russian
# Nepali (macrolanguage)
# Turkish
# Estonian
# Russian
# Swahili (macrolanguage)
# Panjabi
# Italian
# English
# Portuguese
# Italian
# Tagalog
# English
# Kannada
# Indonesian
# English
# Czech
# Estonian
# Urdu
# Italian
# Estonian
# Russian
# Tagalog
# Bengali
# Swahili (macrolanguage)
# English
# Russian
# Welsh
# English
# Indonesian
# Indonesian
# Dutch
# Lithuanian
# Estonian
# Nepali (macrolanguage)
# Indonesian
# Vietnamese
# French
# Russian
# Persian
# Indonesian
# Russian
# Spanish
# Italian
# Japanese
# Arabic
# Korean
# Slovak
# Dutch
# Vietnamese
# Tagalog
# Persian
# Nepali (macrolanguage)
# Malayalam
# Russian
# Finnish
# Tagalog
# Hebrew
# Dutch
# Russian
# Russian
# Vietnamese
# Turkish
# Indonesian
# English
# English
# Russian
# Afrikaans
# Estonian
# Swedish
# Indonesian
# English
# Spanish
# Swahili (macrolanguage)
# Somali
# Ukrainian
# English
# Nepali (macrolanguage)
# Bengali
# Russian
# Korean
# Ukrainian
# Dutch
# Indonesian
# Dutch
# Albanian
# Italian
# Bengali
# Russian
# Korean
# Russian
# Estonian
# Finnish
# English
# Russian
# Russian
# Estonian
# Estonian
# Bulgarian
# Russian
# Dutch
# Russian
# Arabic
# Polish
# Nepali (macrolanguage)
# Urdu
# Catalan
# Indonesian
# Indonesian
# Turkish
# Arabic
# Turkish
# Urdu
# Indonesian
# Italian
# Hindi
# Urdu
# English
# Tagalog
# Urdu
# Tagalog
# Italian
# Italian
# Russian
# Urdu
# Spanish
# French
# German
# German
# English
# English
# Polish
# Swedish
# Welsh
# English
# Nepali (macrolanguage)
# German
# Hebrew
# Dutch
# Norwegian
# Indonesian
# Estonian
# Somali
# Turkish
# Lithuanian
# Vietnamese
# German
# Italian
# Welsh
# Croatian
# English
# Russian
# Marathi
# Ukrainian
# Russian
# Russian
# Russian
# Afrikaans
# Portuguese
# Modern Greek (1453-)
# Tagalog
# Portuguese
# Persian
# Norwegian
# Portuguese
# Swahili (macrolanguage)
# Catalan
# Norwegian
# Welsh
# German
# Russian
# English
# English
# German
# Spanish
# Romanian
# Macedonian
# Kannada
# Vietnamese
# Bulgarian
# Persian
# Albanian
# Vietnamese
# Hebrew
# Polish
# English
# Russian
# Somali
# Russian
# Portuguese
# Hindi
# Russian
# Russian
# Persian
# Gujarati
# Arabic
# Italian
# Estonian
# Swahili (macrolanguage)
# Telugu
# Russian
# Spanish
# Turkish
# Portuguese
# Polish
# Bulgarian
# Afrikaans
# Urdu
# Spanish
# Nepali (macrolanguage)
# Afrikaans
# Finnish
# Russian
# Swahili (macrolanguage)
# Russian
# Italian
# Indonesian
# Italian
# Indonesian
# Italian
# Latvian
# Russian
# Italian
# Bengali
# Russian
# Somali
# Italian
# Vietnamese
# Swahili (macrolanguage)
# Vietnamese
# Russian
# Russian
# Indonesian
# Dutch
# Telugu
# French
# Tamil
# Swahili (macrolanguage)
# Croatian
# Estonian
# Portuguese
# Hungarian
# French
# Dutch
# Italian
# Tagalog
# Latvian
# Nepali (macrolanguage)
# Russian
# Somali
# Slovenian
# Estonian
# Swedish
# Estonian
# Russian
# Persian
# Somali
# Russian
# Vietnamese
# Russian
# Tagalog
# German
# Russian
# Dutch
# Turkish
# Panjabi
# Portuguese
# Slovenian
# Persian
# English
# French
# Korean
# Italian
# Marathi
# Latvian
# Russian
# Lithuanian
# Portuguese
# Hindi
# Tagalog
# Latvian
# Hebrew
# Italian
# Bulgarian
# Arabic
# Estonian
# Polish
# Nepali (macrolanguage)
# Thai
# Albanian
# Italian
# Italian
# Portuguese
# Spanish
# Romanian
# Norwegian
# Hebrew
# English
# Arabic
# Ukrainian
# Swedish
# Tamil
# Indonesian
# Persian
# Swedish
# Nepali (macrolanguage)
# Indonesian
# Russian
# Afrikaans
# Vietnamese
# Persian
# German
# Estonian
# Russian
# Swahili (macrolanguage)
# Catalan
# Catalan
# Latvian
# Indonesian
# Hebrew
# German
# Italian
# German
# Tagalog
# Catalan
# Russian
# Somali
# Swahili (macrolanguage)
# Ukrainian
# Russian
# Czech
# Spanish
# English
# English
# English
# Spanish
# Polish
# Ukrainian
# Russian
# Estonian
# Tagalog
# Indonesian
# English
# Norwegian
# Vietnamese
# Hungarian
# Macedonian
# Italian
# French
# Vietnamese
# Catalan
# Estonian
# Afrikaans
# Persian
# Russian
# Spanish
# Hindi
# Arabic
# Tagalog
# Turkish
# Swahili (macrolanguage)
# Russian
# Spanish
# Romanian
# Urdu
# Afrikaans
# German
# Turkish
# Finnish
# Ukrainian
# Persian
# German
# Indonesian
# Panjabi
# Spanish
# German
# Russian
# Thai
# German
# Latvian
# Estonian
# Norwegian
# Vietnamese
# Estonian
# Hindi
# Spanish
# English
# Russian
# Swedish
# Finnish
# Croatian
# Somali
# Swedish
# Bengali
# Russian
# English
# Persian
# Russian
# Vietnamese
# Afrikaans
# Tagalog
# Arabic
# Swahili (macrolanguage)
# Spanish
# Russian
# Russian
# Czech
# Swedish
# Russian
# Estonian
# Marathi
# Italian
# Persian
# Italian
# French
# Spanish
# Welsh
# Latvian
# Polish
# Tagalog
# French
# Russian
# Russian
# Spanish
# English
# Romanian
# German
# Ukrainian
# Estonian
# Spanish
# Russian
# German
# Dutch
# Portuguese
# Japanese
# Estonian
# Indonesian
# Catalan
# English
# Portuguese
# Kannada
# Spanish
# Telugu
# Vietnamese
# Italian
# Vietnamese
# Hungarian
# Hindi
# French
# Afrikaans
# Hindi
# Croatian
# Bengali
# Persian
# Estonian
# Persian
# Russian
# English
# Italian
# Arabic
# Russian
# Swahili (macrolanguage)
# German
# Arabic
# Norwegian
# Vietnamese
# French
# French
# Croatian
# Catalan
# Catalan
# Russian
# Slovenian
# Polish
# Persian
# Bulgarian
# Swedish
# Panjabi
# French
# German
# Italian
# Italian
# Tagalog
# Indonesian
# Indonesian
# Swedish
# Italian
# Swahili (macrolanguage)
# Dutch
# Slovenian
# Swahili (macrolanguage)
# Persian
# Spanish
# Catalan
# Persian
# Dutch
# Persian
# Bulgarian
# Hungarian
# French
# Italian
# Finnish
# Russian
# Tagalog
# Tagalog
# Russian
# Swedish
# Polish
# Persian
# Afrikaans
# Polish
# Romanian
# Slovenian
# Swahili (macrolanguage)
# Italian
# Turkish
# English
# Bengali
# Italian
# Urdu
# Swahili (macrolanguage)
# Panjabi
# Russian
# Turkish
# Bulgarian
# Persian
# Vietnamese
# Urdu
# Swahili (macrolanguage)
# Tagalog
# Indonesian
# English
# Estonian
# Welsh
# Indonesian
# Lithuanian
# English
# Welsh
# Russian
# Portuguese
# Nepali (macrolanguage)
# Telugu
# Estonian
# Estonian
# Italian
# Croatian
# Spanish
# Estonian
# English
# Tamil
# Russian
# Polish
# English
# Swahili (macrolanguage)
# German
# Russian
# Marathi
# Indonesian
# Russian
# Swedish
# Hebrew
# German
# Bengali
# Swahili (macrolanguage)
# Hindi
# French
# Macedonian
# Tamil
# Hungarian
# Swahili (macrolanguage)
# Hindi
# Indonesian
# Turkish
# Italian
# Ukrainian
# Romanian
# Hindi
# Dutch
# Welsh
# Romanian
# Italian
# Albanian
# English
# Catalan
# Macedonian
# Bengali
# Bulgarian
# Swahili (macrolanguage)
# Turkish
# English
# Korean
# Indonesian
# Spanish
# English
# Russian
# Polish
# Polish
# Russian
# Hindi
# Vietnamese
# Italian
# Somali
# Turkish
# Indonesian
# Persian
# Bulgarian
# Russian
# Indonesian
# Croatian
# Tagalog
# Korean
# Welsh
# Catalan
# Japanese
# Russian
# Italian
# Modern Greek (1453-)
# Russian
# Tagalog
# Portuguese
# Panjabi
# English
# Tagalog
# Bengali
# French
# Tamil
# Albanian
# Indonesian
# Russian
# Persian
# Spanish
# Hindi
# Polish
# Russian
# Thai
# Somali
# Welsh
# Russian
# Ukrainian
# Tagalog
# Estonian
# Norwegian
# Spanish
# Portuguese
# Bengali
# Bengali
# Afrikaans
# Russian
# Russian
# Macedonian
# Italian
# Tagalog
# Russian
# Swahili (macrolanguage)
# Bengali
# Italian
# Swahili (macrolanguage)
# Estonian
# Afrikaans
# Dutch
# Somali
# Russian
# Spanish
# English
# Czech
# Czech
# Afrikaans
# Afrikaans
# Turkish
# Dutch
# English
# German
# Urdu
# English
# Spanish
# Russian
# Hindi
# Ukrainian
# Vietnamese
# Kannada
# Bengali
# Estonian
# Afrikaans
# Spanish

# %%
predictions[33]
# Out:
# 'UNKNOWN'

# %%
languages.get(alpha_2='zh').name
# Out:
# 'Chinese'

# %%
train_list
# Out:
# ['Estonian',
#  'Swedish',
#  'Maithili',
#  'Occitan',
#  'Thai',
#  'Oromo',
#  'Limburgan',
#  'Gujarati',
#  'Western Panjabi',
#  'Zeeuws',
#  'Karachay-Balkar',
#  'Haitian Creole',
#  'Picard',
#  'Tamil',
#  'Vietnamese',
#  'Panjabi',
#  'Silesian',
#  'Central Kurdish',
#  'Friulian',
#  'Wu Chinese',
#  'Egyptian Arabic',
#  'Tongan',
#  'Basque',
#  'Banyumasan',
#  'Gilaki',
#  'Banyumasan',
#  'Dutch',
#  'Egyptian Arabic',
#  'Tibetan',
#  'Japanese',
#  'Aragonese',
#  'Sardinian',
#  'Extremaduran',
#  'Sinhala',
#  'Kurdish',
#  'Chechen',
#  'Turkmen',
#  'Pangasinan',
#  'Turkish',
#  'Alemannic German',
#  'Komi-Permyak',
#  'Sardinian',
#  'Karachay-Balkar',
#  'Latin',
#  'Urdu',
#  'Tatar',
#  'Japanese',
#  'Buryat',
#  'Tibetan',
#  'Indonesian',
#  'Kirghiz',
#  'Cantonese',
#  'Danish',
#  'Portuguese',
#  'French',
#  'Oromo',
#  'Pangasinan',
#  'Oriya',
#  'Bokmål',
#  'Lojban',
#  'Konkani',
#  'Amharic',
#  'Central Khmer',
#  'Serbo-Croatian',
#  'Slovene',
#  'Bosnian',
#  'Tetum',
#  'Standard Chinese',
#  'Korean',
#  'Yakut',
#  'Aromanian',
#  'Asturian',
#  'Wolof',
#  'Bulgarian',
#  'Thai',
#  'Scottish Gaelic',
#  'Tongan',
#  'Malay',
#  'Crimean Tatar',
#  'Luganda',
#  'Sundanese',
#  'Breton',
#  'Kirghiz',
#  'Mongolian',
#  'Nepali (macrolanguage)',
#  'Igbo',
#  'Estonian',
#  'Lojban',
#  'Portuguese',
#  'Min Dong',
#  'Portuguese',
#  'Assamese',
#  'Guarani',
#  'Hindi',
#  'Marathi',
#  'Lingala',
#  'Interlingue',
#  'Interlingue',
#  'Lombard',
#  'Burmese',
#  'Lingala',
#  'Tamil',
#  'Iloko',
#  'Lingala',
#  'Kashubian',
#  'Tuvan',
#  'Irish',
#  'Min Nan Chinese',
#  'Jamaican Patois',
#  'Igbo',
#  'Karachay-Balkar',
#  'Sicilian',
#  'Belarusian (Taraschkewiza)',
#  'Dimli',
#  'Cornish',
#  'Faroese',
#  'Malagasy',
#  'Yiddish',
#  'Northern Sami',
#  'Spanish',
#  'Bulgarian',
#  'Kabardian',
#  'Udmurt',
#  'Icelandic',
#  'Turkmen',
#  'French',
#  'French',
#  'Marathi',
#  'Ripuarisch',
#  'Tatar',
#  'Sanskrit',
#  'Haitian Creole',
#  'Crimean Tatar',
#  'Azerbaijani',
#  'Estonian',
#  'Korean',
#  'Ripuarisch',
#  'Komi-Permyak',
#  'Danish',
#  'Neapolitan',
#  'Bosnian',
#  'Lower Sorbian',
#  'Bokmål',
#  'Icelandic',
#  'Icelandic',
#  'Vietnamese',
#  'Tatar',
#  'Pampanga',
#  'Welsh',
#  'Serbian',
#  'Gilaki',
#  'Saterfriesisch',
#  'Telugu',
#  'Swahili (macrolanguage)',
#  'Vlaams',
#  'Marathi',
#  'Slovene',
#  'Mazanderani',
#  'Belarusian',
#  'Ladino',
#  'Silesian',
#  'Interlingua',
#  'Faroese',
#  'Vlaams',
#  'Avar',
#  'Lao',
#  'Minangkabau',
#  'Oromo',
#  'Italian',
#  'Gilaki',
#  'West Low German',
#  'Basque',
#  'Interlingua',
#  'Interlingue',
#  'Sardinian',
#  'French',
#  'Mongolian',
#  'Ossetian',
#  'Kabyle',
#  'Aromanian',
#  'Pushto',
#  'Egyptian Arabic',
#  'Tetum',
#  'Finnish',
#  'Sindhi',
#  'Dutch',
#  'Karakalpak',
#  'Swahili (macrolanguage)',
#  'Persian',
#  'French',
#  'Gilaki',
#  'Chavacano',
#  'Catalan',
#  'Gujarati',
#  'Classical Nahuatl',
#  'Eastern Mari',
#  'Tarantino dialect',
#  'Arpitan',
#  'Romanian',
#  'Newari',
#  'Faroese',
#  'Occitan',
#  'Lingala',
#  'Newari',
#  'Picard',
#  'Serbian',
#  'Bavarian',
#  'Avar',
#  'Latgalian',
#  'Võro',
#  'Latvian',
#  'Czech',
#  'Latgalian',
#  'Yoruba',
#  'Northern Sotho',
#  'Bashkir',
#  'Banyumasan',
#  'Minangkabau',
#  'Extremaduran',
#  'Russian',
#  'Danish',
#  'Achinese',
#  'Moksha',
#  'Tarantino dialect',
#  'Ossetian',
#  'Japanese',
#  'Veps',
#  'Samogitian',
#  'Marathi',
#  'Kurdish',
#  'Jamaican Patois',
#  'Uighur',
#  'Northern Sotho',
#  'Lithuanian',
#  'Kabardian',
#  'Sicilian',
#  'Arpitan',
#  'Albanian',
#  'Somali',
#  'Indonesian',
#  'Slovak',
#  'Asturian',
#  'Latin',
#  'Italian',
#  'Sundanese',
#  'Min Nan Chinese',
#  'Kashubian',
#  'Sindhi',
#  'Sicilian',
#  'Oromo',
#  'Scots',
#  'Ukrainian',
#  'Maori',
#  'Latin',
#  'Interlingua',
#  'Lithuanian',
#  'Croatian',
#  'Arpitan',
#  'Sanskrit',
#  'Kurdish',
#  'Kurdish',
#  'Asturian',
#  'Silesian',
#  'Sanskrit',
#  'Belarusian (Taraschkewiza)',
#  'Volapük',
#  'Northern Sotho',
#  'Newari',
#  'Vietnamese',
#  'English',
#  'Manx',
#  'Udmurt',
#  'Alemannic German',
#  'French',
#  'Friulian',
#  'Friulian',
#  'Wu Chinese',
#  'Bengali',
#  'Lithuanian',
#  'Lower Sorbian',
#  'Moksha',
#  'Extremaduran',
#  'Ido',
#  'Lithuanian',
#  'Javanese',
#  'Tulu',
#  'Finnish',
#  'Western Mari',
#  'Yiddish',
#  'Minangkabau',
#  'Assamese',
#  'Cornish',
#  'Kirghiz',
#  'Oriya',
#  'Azerbaijani',
#  'Fiji Hindi',
#  'Kirghiz',
#  'Shona',
#  'Panjabi',
#  'Neapolitan',
#  'Lao',
#  'Scots',
#  'Portuguese',
#  'Interlingue',
#  'Waray',
#  'Burmese',
#  'English',
#  'Tulu',
#  'Kabyle',
#  'Central Khmer',
#  'Czech',
#  'Maltese',
#  'Urdu',
#  'Emilian',
#  'Võro',
#  'Yakut',
#  'Tswana',
#  'Bengali',
#  'Igbo',
#  'Scots',
#  'Lezghian',
#  'Cornish',
#  'Latin',
#  'Minangkabau',
#  'Indonesian',
#  'Breton',
#  'Lithuanian',
#  'Yoruba',
#  'Nepali (macrolanguage)',
#  'Indonesian',
#  'Hakka Chinese',
#  'Interlingue',
#  'Komi',
#  'South Azerbaijani',
#  'Quechua',
#  'Ossetian',
#  'Literary Chinese',
#  'Aragonese',
#  'Ido',
#  'Japanese',
#  'Arabic',
#  'Cantonese',
#  'Slovak',
#  'Western Frisian',
#  'Yoruba',
#  'Northern Sotho',
#  'Pushto',
#  'Doteli',
#  'Malayalam',
#  'Buryat',
#  'Maori',
#  'Iloko',
#  'Hebrew',
#  'Basque',
#  'Kabardian',
#  'Yakut',
#  'Hakka Chinese',
#  'Gagauz',
#  'Indonesian',
#  'Scottish Gaelic',
#  'Cornish',
#  'Chuvash',
#  'Afrikaans',
#  'Veps',
#  'Swedish',
#  'Central Khmer',
#  'Banyumasan',
#  'Cantonese',
#  'Papiamento',
#  'Kinyarwanda',
#  'Somali',
#  'Belarusian',
#  'Old English ',
#  'Newari',
#  'Assamese',
#  'Kazakh',
#  'Cantonese',
#  'Belarusian (Taraschkewiza)',
#  'Dutch',
#  'Banjar',
#  'Volapük',
#  'Albanian',
#  'Neapolitan',
#  'Assamese',
#  'Western Mari',
#  'Cantonese',
#  'Russian',
#  'Wu Chinese',
#  'Armenian',
#  'Livvi-Karelian',
#  'Scots',
#  'Ossetian',
#  'Burmese',
#  'Chuvash',
#  'Fiji Hindi',
#  'Mingrelian',
#  'Avar',
#  'Bashkir',
#  'Dutch',
#  'Komi',
#  'Arabic',
#  'Silesian',
#  'Doteli',
#  'Western Panjabi',
#  'Interlingue',
#  'Jamaican Patois',
#  'Jamaican Patois',
#  'Gagauz',
#  'Arabic',
#  'Turkish',
#  'Urdu',
#  'Uzbek',
#  'Ido',
#  'Maithili',
#  'Western Panjabi',
#  'Irish',
#  'Haitian Creole',
#  'Western Panjabi',
#  'Central Bikol',
#  'Friulian',
#  'Literary Chinese',
#  'Neapolitan',
#  'Buryat',
#  'Sindhi',
#  'Guarani',
#  'French',
#  'Bavarian',
#  'Pennsylvania German',
#  'Scottish Gaelic',
#  'Old English ',
#  'Silesian',
#  'Saterfriesisch',
#  'Cornish',
#  'Fiji Hindi',
#  'Sanskrit',
#  'Lingala',
#  'Hebrew',
#  'Zeeuws',
#  'Upper Sorbian',
#  'Sranan',
#  'Volapük',
#  'Oromo',
#  'Kurdish',
#  'Lao',
#  'Hakka Chinese',
#  'Ripuarisch',
#  'Neapolitan',
#  'Welsh',
#  'Serbo-Croatian',
#  'Scots',
#  'Mongolian',
#  'Konkani',
#  'Belarusian (Taraschkewiza)',
#  'Komi',
#  'Buryat',
#  'Bashkir',
#  'Afrikaans',
#  'Portuguese',
#  'Georgian',
#  'Tagalog',
#  'Guarani',
#  'Central Kurdish',
#  'Central Khmer',
#  'Norwegian Nynorsk',
#  'Galician',
#  'Swahili (macrolanguage)',
#  'Romansh',
#  'Maltese',
#  'Welsh',
#  'Pennsylvania German',
#  'Komi-Permyak',
#  'Scottish Gaelic',
#  'Scots',
#  'Alemannic German',
#  'Ido',
#  'Emilian',
#  'Serbian',
#  'Kannada',
#  'Cherokee',
#  'Vietnamese',
#  'Bulgarian',
#  'Northern Luri',
#  'Albanian',
#  'Hakka Chinese',
#  'Hebrew',
#  'Kashubian',
#  'Irish',
#  'Bashkir',
#  'Wolof',
#  'Komi',
#  'Tetum',
#  'Lao',
#  'Maithili',
#  'Karachay-Balkar',
#  'Tuvan',
#  'Mazanderani',
#  'Gujarati',
#  'Dhivehi',
#  'Friulian',
#  'Võro',
#  'Kinyarwanda',
#  'Telugu',
#  'Erzya',
#  'Sardinian',
#  'Turkmen',
#  'Portuguese',
#  'Silesian',
#  'Avar',
#  'West Low German',
#  'Sindhi',
#  'Tibetan',
#  'Extremaduran',
#  'Nepali (macrolanguage)',
#  'Kabyle',
#  'Livvi-Karelian',
#  'Mongolian',
#  'Swahili (macrolanguage)',
#  'Komi-Permyak',
#  'Friulian',
#  'Maltese',
#  'Corsican',
#  'Indonesian',
#  'Aromanian',
#  'Latvian',
#  'Yakut',
#  'Neapolitan',
#  'Assamese',
#  'Karachay-Balkar',
#  'Oromo',
#  'Romansh',
#  'Min Dong',
#  'Tswana',
#  'Vietnamese',
#  'Karachay-Balkar',
#  'Chuvash',
#  'Indonesian',
#  'Zeeuws',
#  'Telugu',
#  'Arpitan',
#  'Tamil',
#  'Shona',
#  'Bosnian',
#  'Veps',
#  'Irish',
#  'Hungarian',
#  'Narom',
#  'Vlaams',
#  'Italian',
#  'Banjar',
#  'Classical Nahuatl',
#  'Sanskrit',
#  'Udmurt',
#  'Somali',
#  'Slovene',
#  'Mingrelian',
#  'Swedish',
#  'Maori',
#  'Yakut',
#  'Persian',
#  'Wolof',
#  'Cantonese',
#  'Moksha',
#  'Vietnamese',
#  'Russian',
#  'Tswana',
#  'Palatine German',
#  'Komi-Permyak',
#  'Western Frisian',
#  'Karakalpak',
#  'Panjabi',
#  'Guarani',
#  'Lojban',
#  'Northern Luri',
#  'Thai',
#  'Walloon',
#  'Korean',
#  'Lombard',
#  'Marathi',
#  'Latvian',
#  'Lezghian',
#  'Samogitian',
#  'Ido',
#  'Bhojpuri',
#  'Central Bikol',
#  'Latgalian',
#  'Hebrew',
#  'Classical Nahuatl',
#  'Tuvan',
#  'Urdu',
#  'Northern Sami',
#  'Silesian',
#  'Nepali (macrolanguage)',
#  'Thai',
#  'Albanian',
#  'Interlingua',
#  'Corsican',
#  'Portuguese',
#  'Esperanto',
#  'Classical Nahuatl',
#  'Norwegian Nynorsk',
#  'Hebrew',
#  'Saterfriesisch',
#  'Arabic',
#  'Ukrainian',
#  'Volapük',
#  'Tamil',
#  'Pangasinan',
#  'Sindhi',
#  'Saterfriesisch',
#  'Oriya',
#  'Iloko',
#  'Karachay-Balkar',
#  'Afrikaans',
#  'Min Dong',
#  'Central Kurdish',
#  'German',
#  'Võro',
#  'Chechen',
#  'Guarani',
#  'Haitian Creole',
#  'Lombard',
#  'Latgalian',
#  'Maltese',
#  'Yiddish',
#  'Pennsylvania German',
#  'Romansh',
#  'Pennsylvania German',
#  'Northern Sotho',
#  'Catalan',
#  'Bashkir',
#  'Wolof',
#  'Malagasy',
#  'Belarusian (Taraschkewiza)',
#  'Lezghian',
#  'Navajo',
#  'Galician',
#  'Scottish Gaelic',
#  'Irish',
#  'Scots',
#  'Ido',
#  'Lower Sorbian',
#  'Kazakh',
#  'Chuvash',
#  'Võro',
#  'Haitian Creole',
#  'Achinese',
#  'Scots',
#  'Icelandic',
#  'Hakka Chinese',
#  'Hungarian',
#  'Serbian',
#  'Lojban',
#  'Arpitan',
#  'Min Dong',
#  'Romansh',
#  'Tongan',
#  'Western Frisian',
#  'Pushto',
#  'Bashkir',
#  'Galician',
#  'Maithili',
#  'Uighur',
#  'Waray',
#  'Crimean Tatar',
#  'Swahili (macrolanguage)',
#  'Chechen',
#  'Mirandese',
#  'Aromanian',
#  'Urdu',
#  'Afrikaans',
#  'Bavarian',
#  'Azerbaijani',
#  'Livvi-Karelian',
#  'Ukrainian',
#  'Pushto',
#  'Palatine German',
#  'Dhivehi',
#  'Minangkabau',
#  'Panjabi',
#  'Mirandese',
#  'Pampanga',
#  'Western Mari',
#  'Lao',
#  'German',
#  'Latvian',
#  'Võro',
#  'Bokmål',
#  'Igbo',
#  'Maori',
#  'Sanskrit',
#  'Extremaduran',
#  'Irish',
#  'Buryat',
#  'Volapük',
#  'Northern Sami',
#  'Serbo-Croatian',
#  'Navajo',
#  'Icelandic',
#  'Bengali',
#  'Komi',
#  'English',
#  'Gilaki',
#  'Chuvash',
#  'Hakka Chinese',
#  'Western Frisian',
#  'Malagasy',
#  'Egyptian Arabic',
#  'Tongan',
#  'Guarani',
#  'Komi',
#  'Kirghiz',
#  'Czech',
#  'Faroese',
#  'Russian',
#  'Uzbek',
#  'Marathi',
#  'Neapolitan',
#  'Persian',
#  'Tarantino dialect',
#  'Arpitan',
#  'Wu Chinese',
#  'Ladino',
#  'Welsh',
#  'Min Dong',
#  'Latvian',
#  'Polish',
#  'Iloko',
#  'Walloon',
#  'Rusyn',
#  'Tatar',
#  'Ladino',
#  'Oriya',
#  'Alemannic German',
#  'Pampanga',
#  'Armenian',
#  'Northern Sami',
#  'Mirandese',
#  'Eastern Mari',
#  'Bavarian',
#  'Saterfriesisch',
#  'Galician',
#  'Japanese',
#  'Veps',
#  'Jamaican Patois',
#  'Lombard',
#  'Scottish Gaelic',
#  'Portuguese',
#  'Kannada',
#  'Chavacano',
#  'Telugu',
#  'Vietnamese',
#  'Sicilian',
#  'Igbo',
#  'Navajo',
#  'Hindi',
#  'Walloon',
#  'Limburgan',
#  'Sanskrit',
#  'Serbo-Croatian',
#  'Bengali',
#  'Northern Luri',
#  'Veps',
#  'Persian',
#  'Yakut',
#  'Korean',
#  'Venetian',
#  'Uighur',
#  'Avar',
#  'Luganda',
#  'Low German',
#  'Egyptian Arabic',
#  'Norwegian Nynorsk',
#  'Hakka Chinese',
#  'Arpitan',
#  'Walloon',
#  'Croatian',
#  'Yoruba',
#  'Aymara',
#  'Tatar',
#  'Esperanto',
#  'Silesian',
#  'Northern Luri',
#  'Tajik',
#  'Swedish',
#  'Panjabi',
#  'Breton',
#  'Alemannic German',
#  'Corsican',
#  'Sardinian',
#  'Cebuano',
#  'Indonesian',
#  'Yoruba',
#  'Breton',
#  'Latin',
#  'Luganda',
#  'Zeeuws',
#  'Esperanto',
#  'Xhosa',
#  'Northern Luri',
#  'Classical Nahuatl',
#  'Catalan',
#  'Mazanderani',
#  'Vlaams',
#  'Sindhi',
#  'Bulgarian',
#  'Hungarian',
#  'French',
#  'Sicilian',
#  'Livvi-Karelian',
#  'Kabardian',
#  'Northern Sotho',
#  'Tagalog',
#  'Western Mari',
#  'Northern Sami',
#  'Lower Sorbian',
#  'Sindhi',
#  'Fiji Hindi',
#  'Silesian',
#  'Aromanian',
#  'Slovene',
#  'Tswana',
#  'Corsican',
#  'Crimean Tatar',
#  'Pennsylvania German',
#  'Assamese',
#  'Latin',
#  'Western Panjabi',
#  'Xhosa',
#  'Panjabi',
#  'Buryat',
#  'Azerbaijani',
#  'Bulgarian',
#  'Pushto',
#  'Hakka Chinese',
#  'Western Panjabi',
#  'Kinyarwanda',
#  'Central Bikol',
#  'Banyumasan',
#  'English',
#  'Estonian',
#  'Manx',
#  'Indonesian',
#  'Lithuanian',
#  'Scottish Gaelic',
#  'Welsh',
#  'Kazakh',
#  'Sinhala',
#  'Mirandese',
#  'Oriya',
#  'Telugu',
#  'Veps',
#  'Guarani',
#  'Maltese',
#  'Lojban',
#  'Mirandese',
#  'Armenian',
#  'Venetian',
#  'Tamil',
#  'Kazakh',
#  'Silesian',
#  'Irish',
#  'Luganda',
#  'Alemannic German',
#  'Karachay-Balkar',
#  'Doteli',
#  'Achinese',
#  'Eastern Mari',
#  'Volapük',
#  'Yiddish',
#  'Saterfriesisch',
#  'Bengali',
#  'Luganda',
#  'Sanskrit',
#  'Occitan',
#  'Tajik',
#  'Cherokee',
#  'Tamil',
#  'Navajo',
#  'Tongan',
#  'Bhojpuri',
#  'Malay',
#  'Crimean Tatar',
#  'Breton',
#  'Kazakh',
#  'Latin',
#  'Sanskrit',
#  'West Low German',
#  'Welsh',
#  'Aromanian',
#  'Central Khmer',
#  'Neapolitan',
#  'Albanian',
#  'Scots',
#  'Latin',
#  'Serbian',
#  'Bishnupriya',
#  'Bulgarian',
#  'Swahili (macrolanguage)',
#  'Kabyle',
#  'Scottish Gaelic',
#  'Cantonese',
#  'Basque',
#  'Ido',
#  'English',
#  'Tuvan',
#  'Upper Sorbian',
#  'Polish',
#  'Kabardian',
#  'Dhivehi',
#  'Newari',
#  'Min Dong',
#  'Lombard',
#  'Somali',
#  'Uzbek',
#  'Achinese',
#  'Pushto',
#  'Lezghian',
#  'Komi-Permyak',
#  'Tibetan',
#  'Banjar',
#  'Lojban',
#  'Northern Sotho',
#  'Korean',
#  'Welsh',
#  'Norwegian Nynorsk',
#  'Japanese',
#  'Russian',
#  'Italian',
#  'Modern Greek',
#  'Kabardian',
#  'Wu Chinese',
#  'Luganda',
#  'Tetum',
#  'Panjabi',
#  'Manx',
#  'Pangasinan',
#  'Bishnupriya',
#  'Narom',
#  'Tibetan',
#  'Tamil',
#  'Albanian',
#  'Malagasy',
#  'Buryat',
#  'Persian',
#  'Galician',
#  'Maithili',
#  'Polish',
#  'Kabardian',
#  'Thai',
#  'Oromo',
#  'Welsh',
#  'Udmurt',
#  'Ukrainian',
#  'Northern Sotho',
#  'Georgian',
#  'Haitian Creole',
#  'Central Khmer',
#  'Ladino',
#  'Tetum',
#  'Assamese',
#  'Bengali',
#  'Zeeuws',
#  'Bashkir',
#  'Moksha',
#  'Serbian',
#  'Maltese',
#  'Waray',
#  'Kabardian',
#  'Northern Sotho',
#  'Bishnupriya',
#  'Sicilian',
#  'Yoruba',
#  'Volapük',
#  'Afrikaans',
#  'Zeeuws',
#  'Quechua',
#  'Udmurt',
#  'Chavacano',
#  'Latvian',
#  'Czech',
#  'Czech',
#  'Wu Chinese',
#  'Afrikaans',
#  'Zeeuws',
#  'Turkish',
#  'Vlaams',
#  'Wolof',
#  'Alemannic German',
#  'Western Panjabi',
#  'Pampanga',
#  'Papiamento',
#  'Eastern Mari',
#  'Sanskrit',
#  'Belarusian (Taraschkewiza)',
#  'Min Dong',
#  'Tulu',
#  'Bengali',
#  'Estonian',
#  'Sranan',
#  'Aragonese']

# %%
acc = accuracy_score(train_list, names)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.213

# %%
## FastText 
#!pip install fasttext
import fasttext
model = fasttext.load_model('lid.176.ftz')
print(model.predict(x_train['Par'][0]))  # top 2 matching languages

# predictions = model.predict(sentences)
# print(predictions)
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# (('__label__et',), array([0.87263]))

# %%
ft_predict = []
for i in range(1000): 
    sentences = x_train['Par'][i]
    predicted_lang = model.predict(sentences)
    ft_predict.append(predicted_lang[0][0][9:])

# %%
ft_predict
# Out:
# ['et',
#  'en',
#  'hi',
#  'oc',
#  'th',
#  'fi',
#  'li',
#  'en',
#  'pnb',
#  'nl',
#  'ru',
#  'tl',
#  'fr',
#  'ta',
#  'vi',
#  'pa',
#  'pl',
#  'ckb',
#  'it',
#  'zh',
#  'ar',
#  'br',
#  'eu',
#  'id',
#  'ar',
#  'id',
#  'nl',
#  'ar',
#  'bo',
#  'ja',
#  'es',
#  'ca',
#  'es',
#  'si',
#  'ku',
#  'ce',
#  'tk',
#  'eo',
#  'tr',
#  'als',
#  'ru',
#  'fr',
#  'krc',
#  'de',
#  'ur',
#  'tt',
#  'ja',
#  'mn',
#  'bo',
#  'id',
#  'ru',
#  'zh',
#  'da',
#  'pt',
#  'fr',
#  'fi',
#  'la',
#  'or',
#  'no',
#  'jbo',
#  'mr',
#  'am',
#  'km',
#  'hr',
#  'sl',
#  'bs',
#  'cy',
#  'zh',
#  'ko',
#  'sah',
#  'it',
#  'es',
#  'nl',
#  'bg',
#  'th',
#  'gd',
#  'en',
#  'ms',
#  'tr',
#  'eo',
#  'su',
#  'br',
#  'ky',
#  'mn',
#  'ne',
#  'en',
#  'et',
#  'jbo',
#  'pt',
#  'ro',
#  'en',
#  'as',
#  'hu',
#  'hi',
#  'mr',
#  'fr',
#  'es',
#  'es',
#  'lmo',
#  'my',
#  'su',
#  'ta',
#  'ilo',
#  'cs',
#  'pl',
#  'ru',
#  'ga',
#  'ca',
#  'it',
#  'hr',
#  'krc',
#  'scn',
#  'be',
#  'ku',
#  'cy',
#  'is',
#  'mg',
#  'yi',
#  'cs',
#  'es',
#  'bg',
#  'ru',
#  'ru',
#  'is',
#  'tr',
#  'fr',
#  'fr',
#  'mr',
#  'nl',
#  'tt',
#  'sa',
#  'tl',
#  'tr',
#  'az',
#  'et',
#  'ko',
#  'de',
#  'ru',
#  'de',
#  'it',
#  'sh',
#  'pl',
#  'no',
#  'is',
#  'is',
#  'vi',
#  'ru',
#  'de',
#  'cy',
#  'sr',
#  'fa',
#  'fi',
#  'te',
#  'sw',
#  'nl',
#  'mr',
#  'sl',
#  'fa',
#  'be',
#  'es',
#  'pl',
#  'ia',
#  'is',
#  'nl',
#  'av',
#  'lo',
#  'id',
#  'fi',
#  'it',
#  'fa',
#  'nl',
#  'eu',
#  'fr',
#  'es',
#  'it',
#  'fr',
#  'mn',
#  'os',
#  'en',
#  'ro',
#  'ps',
#  'ar',
#  'pt',
#  'fi',
#  'sd',
#  'nl',
#  'tr',
#  'en',
#  'fa',
#  'fr',
#  'fa',
#  'es',
#  'ca',
#  'gu',
#  'en',
#  'ru',
#  'it',
#  'fr',
#  'ro',
#  'hi',
#  'is',
#  'oc',
#  'pl',
#  'new',
#  'fr',
#  'sr',
#  'de',
#  'ru',
#  'fi',
#  'et',
#  'lv',
#  'cs',
#  'lv',
#  'ca',
#  'tl',
#  'ba',
#  'id',
#  'min',
#  'es',
#  'ru',
#  'da',
#  'id',
#  'ru',
#  'it',
#  'os',
#  'ja',
#  'fi',
#  'lt',
#  'mr',
#  'ku',
#  'fi',
#  'ug',
#  'sw',
#  'lt',
#  'krc',
#  'it',
#  'fr',
#  'sq',
#  'so',
#  'id',
#  'sk',
#  'es',
#  'la',
#  'it',
#  'su',
#  'ca',
#  'fr',
#  'sd',
#  'it',
#  'fi',
#  'en',
#  'uk',
#  'lv',
#  'la',
#  'ia',
#  'lt',
#  'hr',
#  'fr',
#  'sa',
#  'ku',
#  'ku',
#  'ast',
#  'pl',
#  'sa',
#  'be',
#  'vo',
#  'sw',
#  'en',
#  'vi',
#  'en',
#  'en',
#  'ru',
#  'als',
#  'fr',
#  'it',
#  'it',
#  'zh',
#  'bn',
#  'lt',
#  'pl',
#  'ru',
#  'es',
#  'eo',
#  'lt',
#  'id',
#  'kn',
#  'fi',
#  'mrj',
#  'yi',
#  'min',
#  'as',
#  'kw',
#  'ky',
#  'or',
#  'az',
#  'es',
#  'ky',
#  'en',
#  'pa',
#  'it',
#  'lo',
#  'en',
#  'pt',
#  'en',
#  'war',
#  'my',
#  'en',
#  'kn',
#  'en',
#  'en',
#  'cs',
#  'mt',
#  'ur',
#  'it',
#  'fi',
#  'sah',
#  'sw',
#  'bn',
#  'en',
#  'en',
#  'ru',
#  'kw',
#  'en',
#  'min',
#  'id',
#  'br',
#  'lt',
#  'eo',
#  'ne',
#  'id',
#  'ku',
#  'fr',
#  'ru',
#  'azb',
#  'qu',
#  'os',
#  'zh',
#  'es',
#  'io',
#  'ja',
#  'ar',
#  'zh',
#  'sk',
#  'fy',
#  'ca',
#  'sw',
#  'fa',
#  'ne',
#  'ml',
#  'mn',
#  'en',
#  'ilo',
#  'he',
#  'eu',
#  'mhr',
#  'sah',
#  'tl',
#  'tr',
#  'id',
#  'gd',
#  'kw',
#  'cv',
#  'af',
#  'et',
#  'sv',
#  'km',
#  'id',
#  'en',
#  'es',
#  'fr',
#  'fi',
#  'be',
#  'is',
#  'new',
#  'as',
#  'kk',
#  'zh',
#  'be',
#  'nl',
#  'ms',
#  'vo',
#  'sq',
#  'nap',
#  'as',
#  'mrj',
#  'zh',
#  'ru',
#  'zh',
#  'hy',
#  'fi',
#  'sco',
#  'os',
#  'my',
#  'cv',
#  'fi',
#  'xmf',
#  'lez',
#  'ba',
#  'nl',
#  'ru',
#  'ar',
#  'pl',
#  'ne',
#  'pnb',
#  'es',
#  'fi',
#  'it',
#  'tr',
#  'ar',
#  'tr',
#  'ur',
#  'uz',
#  'eo',
#  'hi',
#  'pnb',
#  'ga',
#  'ht',
#  'pnb',
#  'tl',
#  'pt',
#  'ja',
#  'nap',
#  'mn',
#  'sd',
#  'es',
#  'fr',
#  'de',
#  'de',
#  'gd',
#  'en',
#  'pl',
#  'fi',
#  'cy',
#  'en',
#  'sa',
#  'kw',
#  'he',
#  'nl',
#  'hsb',
#  'nl',
#  'vo',
#  'fi',
#  'ku',
#  'lo',
#  'ku',
#  'id',
#  'nap',
#  'cy',
#  'hr',
#  'en',
#  'mn',
#  'mr',
#  'be',
#  'ru',
#  'mn',
#  'ba',
#  'nl',
#  'pt',
#  'ka',
#  'tl',
#  'gn',
#  'ckb',
#  'km',
#  'nn',
#  'gl',
#  'sw',
#  'it',
#  'mt',
#  'cy',
#  'de',
#  'ru',
#  'gd',
#  'en',
#  'als',
#  'io',
#  'pms',
#  'sr',
#  'kn',
#  'hu',
#  'vi',
#  'bg',
#  'fa',
#  'sq',
#  'vi',
#  'he',
#  'pl',
#  'ga',
#  'ba',
#  'cy',
#  'ru',
#  'es',
#  'lo',
#  'hi',
#  'ru',
#  'ru',
#  'fa',
#  'gu',
#  'dv',
#  'it',
#  'et',
#  'ceb',
#  'te',
#  'ru',
#  'ca',
#  'tk',
#  'pt',
#  'pl',
#  'bg',
#  'nl',
#  'sd',
#  'bo',
#  'es',
#  'hi',
#  'de',
#  'fi',
#  'mn',
#  'sw',
#  'ru',
#  'it',
#  'mt',
#  'it',
#  'id',
#  'es',
#  'lv',
#  'sah',
#  'it',
#  'as',
#  'krc',
#  'en',
#  'rm',
#  'eml',
#  'en',
#  'vi',
#  'krc',
#  'cv',
#  'id',
#  'nl',
#  'te',
#  'fr',
#  'ta',
#  'en',
#  'hr',
#  'ur',
#  'ga',
#  'hu',
#  'fr',
#  'nl',
#  'it',
#  'en',
#  'nah',
#  'sa',
#  'ru',
#  'eo',
#  'sl',
#  'xmf',
#  'sv',
#  'en',
#  'sah',
#  'fa',
#  'es',
#  'zh',
#  'ru',
#  'vi',
#  'ru',
#  'sw',
#  'de',
#  'ru',
#  'fy',
#  'tr',
#  'pa',
#  'es',
#  'jbo',
#  'ckb',
#  'en',
#  'wa',
#  'ko',
#  'lmo',
#  'mr',
#  'lv',
#  'lez',
#  'lt',
#  'io',
#  'hi',
#  'tl',
#  'lv',
#  'he',
#  'en',
#  'ru',
#  'ar',
#  'fi',
#  'pl',
#  'hi',
#  'th',
#  'sq',
#  'ia',
#  'it',
#  'pt',
#  'eo',
#  'nah',
#  'nn',
#  'he',
#  'de',
#  'ar',
#  'uk',
#  'vo',
#  'ta',
#  'ilo',
#  'sd',
#  'als',
#  'or',
#  'ilo',
#  'krc',
#  'af',
#  'vi',
#  'ckb',
#  'de',
#  'et',
#  'ce',
#  'gn',
#  'oc',
#  'lmo',
#  'lv',
#  'mt',
#  'yi',
#  'de',
#  'rm',
#  'de',
#  'sw',
#  'ca',
#  'ba',
#  'kw',
#  'mg',
#  'be',
#  'lez',
#  'cs',
#  'gl',
#  'gd',
#  'en',
#  'en',
#  'io',
#  'hsb',
#  'kk',
#  'cv',
#  'et',
#  'ht',
#  'id',
#  'en',
#  'is',
#  'pms',
#  'hu',
#  'sr',
#  'jbo',
#  'fr',
#  'eml',
#  'it',
#  'en',
#  'fy',
#  'ps',
#  'ba',
#  'gl',
#  'hi',
#  'ug',
#  'war',
#  'tr',
#  'sw',
#  'ce',
#  'mwl',
#  'ro',
#  'ur',
#  'af',
#  'de',
#  'az',
#  'fi',
#  'uk',
#  'ps',
#  'de',
#  'dv',
#  'id',
#  'pa',
#  'es',
#  'de',
#  'mrj',
#  'th',
#  'de',
#  'lv',
#  'et',
#  'no',
#  'en',
#  'lv',
#  'sa',
#  'es',
#  'ga',
#  'mn',
#  'vo',
#  'fi',
#  'sh',
#  'cs',
#  'is',
#  'bn',
#  'ru',
#  'en',
#  'fa',
#  'cv',
#  'vi',
#  'fy',
#  'mg',
#  'ar',
#  'qu',
#  'gn',
#  'ru',
#  'ky',
#  'cs',
#  'is',
#  'ru',
#  'uz',
#  'mr',
#  'nap',
#  'fa',
#  'fr',
#  'fr',
#  'zh',
#  'es',
#  'cy',
#  'zh',
#  'lv',
#  'pl',
#  'ilo',
#  'wa',
#  'ru',
#  'tt',
#  'es',
#  'en',
#  'en',
#  'de',
#  'hy',
#  'cs',
#  'es',
#  'mhr',
#  'de',
#  'als',
#  'gl',
#  'ja',
#  'vep',
#  'fi',
#  'lmo',
#  'gd',
#  'pt',
#  'kn',
#  'es',
#  'te',
#  'vi',
#  'it',
#  'vi',
#  'sk',
#  'hi',
#  'fr',
#  'nl',
#  'sa',
#  'sh',
#  'bn',
#  'fa',
#  'sl',
#  'fa',
#  'sah',
#  'en',
#  'vec',
#  'ug',
#  'ru',
#  'fi',
#  'de',
#  'arz',
#  'nn',
#  'en',
#  'fr',
#  'fr',
#  'hr',
#  'ga',
#  'qu',
#  'tt',
#  'eo',
#  'pl',
#  'fa',
#  'tg',
#  'sv',
#  'pa',
#  'br',
#  'als',
#  'it',
#  'es',
#  'ceb',
#  'id',
#  'sl',
#  'br',
#  'la',
#  'war',
#  'nl',
#  'eo',
#  'en',
#  'azb',
#  'es',
#  'ca',
#  'fa',
#  'nl',
#  'sd',
#  'bg',
#  'hu',
#  'fr',
#  'it',
#  'fi',
#  'be',
#  'sw',
#  'tl',
#  'mrj',
#  'sv',
#  'pl',
#  'sd',
#  'en',
#  'pl',
#  'ro',
#  'sl',
#  'eo',
#  'it',
#  'tr',
#  'en',
#  'as',
#  'la',
#  'pnb',
#  'sw',
#  'pa',
#  'mn',
#  'az',
#  'bg',
#  'ps',
#  'ms',
#  'ur',
#  'en',
#  'tl',
#  'id',
#  'en',
#  'et',
#  'kw',
#  'id',
#  'lt',
#  'gd',
#  'cy',
#  'kk',
#  'si',
#  'pt',
#  'or',
#  'te',
#  'fi',
#  'gn',
#  'mt',
#  'jbo',
#  'mwl',
#  'hy',
#  'en',
#  'ta',
#  'kk',
#  'pl',
#  'ga',
#  'en',
#  'de',
#  'ru',
#  'hi',
#  'ms',
#  'ru',
#  'vo',
#  'yi',
#  'da',
#  'bn',
#  'sq',
#  'sa',
#  'fr',
#  'tg',
#  'en',
#  'ta',
#  'hu',
#  'tl',
#  'hi',
#  'ms',
#  'tr',
#  'br',
#  'kk',
#  'la',
#  'sa',
#  'nl',
#  'cy',
#  'ro',
#  'km',
#  'nap',
#  'sq',
#  'en',
#  'la',
#  'sr',
#  'bpy',
#  'bg',
#  'sw',
#  'en',
#  'gd',
#  'zh',
#  'eu',
#  'es',
#  'en',
#  'tt',
#  'pl',
#  'pl',
#  'be',
#  'dv',
#  'hi',
#  'vi',
#  'it',
#  'en',
#  'uz',
#  'en',
#  'ps',
#  'lez',
#  'ru',
#  'bo',
#  'ms',
#  'jbo',
#  'ms',
#  'ko',
#  'cy',
#  'sv',
#  'ja',
#  'ru',
#  'it',
#  'el',
#  'krc',
#  'zh',
#  'war',
#  'es',
#  'pa',
#  'en',
#  'la',
#  'bpy',
#  'fr',
#  'bo',
#  'ta',
#  'sq',
#  'mg',
#  'mn',
#  'fa',
#  'gl',
#  'hi',
#  'pl',
#  'krc',
#  'th',
#  'fi',
#  'cy',
#  'ru',
#  'uk',
#  'fi',
#  'ka',
#  'tl',
#  'km',
#  'es',
#  'es',
#  'as',
#  'bn',
#  'nl',
#  'ba',
#  'ru',
#  'sr',
#  'mt',
#  'war',
#  'krc',
#  'sw',
#  'bpy',
#  'it',
#  'es',
#  'vo',
#  'nl',
#  'nl',
#  'qu',
#  'ru',
#  'es',
#  'en',
#  'cs',
#  'cs',
#  'zh',
#  'af',
#  'nl',
#  'tr',
#  'nl',
#  'en',
#  'de',
#  'pnb',
#  'en',
#  'es',
#  'ru',
#  'sa',
#  'be',
#  'vi',
#  'kn',
#  'bn',
#  'et',
#  'ca',
#  'es']

# %%
ft_names = []
for i in range(len(ft_predict)):
    if len(ft_predict[i]) == 3:
        ft_names.append('nan')
    else:
        lang_name = languages.get(alpha_2=ft_predict[i]).name
        if '(' in lang_name:
            ft_names.append(re.sub("[(\[].*?[\)]", "", lang_name)[:-1])
        else:
            ft_names.append(lang_name)

# %%
ft_names
# Out:
# ['Estonian',
#  'English',
#  'Hindi',
#  'Occitan',
#  'Thai',
#  'Finnish',
#  'Limburgan',
#  'English',
#  'nan',
#  'Dutch',
#  'Russian',
#  'Tagalog',
#  'French',
#  'Tamil',
#  'Vietnamese',
#  'Panjabi',
#  'Polish',
#  'nan',
#  'Italian',
#  'Chinese',
#  'Arabic',
#  'Breton',
#  'Basque',
#  'Indonesian',
#  'Arabic',
#  'Indonesian',
#  'Dutch',
#  'Arabic',
#  'Tibetan',
#  'Japanese',
#  'Spanish',
#  'Catalan',
#  'Spanish',
#  'Sinhala',
#  'Kurdish',
#  'Chechen',
#  'Turkmen',
#  'Esperanto',
#  'Turkish',
#  'nan',
#  'Russian',
#  'French',
#  'nan',
#  'German',
#  'Urdu',
#  'Tatar',
#  'Japanese',
#  'Mongolian',
#  'Tibetan',
#  'Indonesian',
#  'Russian',
#  'Chinese',
#  'Danish',
#  'Portuguese',
#  'French',
#  'Finnish',
#  'Latin',
#  'Oriya',
#  'Norwegian',
#  'nan',
#  'Marathi',
#  'Amharic',
#  'Central Khmer',
#  'Croatian',
#  'Slovenian',
#  'Bosnian',
#  'Welsh',
#  'Chinese',
#  'Korean',
#  'nan',
#  'Italian',
#  'Spanish',
#  'Dutch',
#  'Bulgarian',
#  'Thai',
#  'Scottish Gaelic',
#  'English',
#  'Malay',
#  'Turkish',
#  'Esperanto',
#  'Sundanese',
#  'Breton',
#  'Kirghiz',
#  'Mongolian',
#  'Nepali',
#  'English',
#  'Estonian',
#  'nan',
#  'Portuguese',
#  'Romanian',
#  'English',
#  'Assamese',
#  'Hungarian',
#  'Hindi',
#  'Marathi',
#  'French',
#  'Spanish',
#  'Spanish',
#  'nan',
#  'Burmese',
#  'Sundanese',
#  'Tamil',
#  'nan',
#  'Czech',
#  'Polish',
#  'Russian',
#  'Irish',
#  'Catalan',
#  'Italian',
#  'Croatian',
#  'nan',
#  'nan',
#  'Belarusian',
#  'Kurdish',
#  'Welsh',
#  'Icelandic',
#  'Malagasy',
#  'Yiddish',
#  'Czech',
#  'Spanish',
#  'Bulgarian',
#  'Russian',
#  'Russian',
#  'Icelandic',
#  'Turkish',
#  'French',
#  'French',
#  'Marathi',
#  'Dutch',
#  'Tatar',
#  'Sanskrit',
#  'Tagalog',
#  'Turkish',
#  'Azerbaijani',
#  'Estonian',
#  'Korean',
#  'German',
#  'Russian',
#  'German',
#  'Italian',
#  'Serbo-Croatian',
#  'Polish',
#  'Norwegian',
#  'Icelandic',
#  'Icelandic',
#  'Vietnamese',
#  'Russian',
#  'German',
#  'Welsh',
#  'Serbian',
#  'Persian',
#  'Finnish',
#  'Telugu',
#  'Swahili',
#  'Dutch',
#  'Marathi',
#  'Slovenian',
#  'Persian',
#  'Belarusian',
#  'Spanish',
#  'Polish',
#  'Interlingua',
#  'Icelandic',
#  'Dutch',
#  'Avaric',
#  'Lao',
#  'Indonesian',
#  'Finnish',
#  'Italian',
#  'Persian',
#  'Dutch',
#  'Basque',
#  'French',
#  'Spanish',
#  'Italian',
#  'French',
#  'Mongolian',
#  'Ossetian',
#  'English',
#  'Romanian',
#  'Pushto',
#  'Arabic',
#  'Portuguese',
#  'Finnish',
#  'Sindhi',
#  'Dutch',
#  'Turkish',
#  'English',
#  'Persian',
#  'French',
#  'Persian',
#  'Spanish',
#  'Catalan',
#  'Gujarati',
#  'English',
#  'Russian',
#  'Italian',
#  'French',
#  'Romanian',
#  'Hindi',
#  'Icelandic',
#  'Occitan',
#  'Polish',
#  'nan',
#  'French',
#  'Serbian',
#  'German',
#  'Russian',
#  'Finnish',
#  'Estonian',
#  'Latvian',
#  'Czech',
#  'Latvian',
#  'Catalan',
#  'Tagalog',
#  'Bashkir',
#  'Indonesian',
#  'nan',
#  'Spanish',
#  'Russian',
#  'Danish',
#  'Indonesian',
#  'Russian',
#  'Italian',
#  'Ossetian',
#  'Japanese',
#  'Finnish',
#  'Lithuanian',
#  'Marathi',
#  'Kurdish',
#  'Finnish',
#  'Uighur',
#  'Swahili',
#  'Lithuanian',
#  'nan',
#  'Italian',
#  'French',
#  'Albanian',
#  'Somali',
#  'Indonesian',
#  'Slovak',
#  'Spanish',
#  'Latin',
#  'Italian',
#  'Sundanese',
#  'Catalan',
#  'French',
#  'Sindhi',
#  'Italian',
#  'Finnish',
#  'English',
#  'Ukrainian',
#  'Latvian',
#  'Latin',
#  'Interlingua',
#  'Lithuanian',
#  'Croatian',
#  'French',
#  'Sanskrit',
#  'Kurdish',
#  'Kurdish',
#  'nan',
#  'Polish',
#  'Sanskrit',
#  'Belarusian',
#  'Volapük',
#  'Swahili',
#  'English',
#  'Vietnamese',
#  'English',
#  'English',
#  'Russian',
#  'nan',
#  'French',
#  'Italian',
#  'Italian',
#  'Chinese',
#  'Bengali',
#  'Lithuanian',
#  'Polish',
#  'Russian',
#  'Spanish',
#  'Esperanto',
#  'Lithuanian',
#  'Indonesian',
#  'Kannada',
#  'Finnish',
#  'nan',
#  'Yiddish',
#  'nan',
#  'Assamese',
#  'Cornish',
#  'Kirghiz',
#  'Oriya',
#  'Azerbaijani',
#  'Spanish',
#  'Kirghiz',
#  'English',
#  'Panjabi',
#  'Italian',
#  'Lao',
#  'English',
#  'Portuguese',
#  'English',
#  'nan',
#  'Burmese',
#  'English',
#  'Kannada',
#  'English',
#  'English',
#  'Czech',
#  'Maltese',
#  'Urdu',
#  'Italian',
#  'Finnish',
#  'nan',
#  'Swahili',
#  'Bengali',
#  'English',
#  'English',
#  'Russian',
#  'Cornish',
#  'English',
#  'nan',
#  'Indonesian',
#  'Breton',
#  'Lithuanian',
#  'Esperanto',
#  'Nepali',
#  'Indonesian',
#  'Kurdish',
#  'French',
#  'Russian',
#  'nan',
#  'Quechua',
#  'Ossetian',
#  'Chinese',
#  'Spanish',
#  'Ido',
#  'Japanese',
#  'Arabic',
#  'Chinese',
#  'Slovak',
#  'Western Frisian',
#  'Catalan',
#  'Swahili',
#  'Persian',
#  'Nepali',
#  'Malayalam',
#  'Mongolian',
#  'English',
#  'nan',
#  'Hebrew',
#  'Basque',
#  'nan',
#  'nan',
#  'Tagalog',
#  'Turkish',
#  'Indonesian',
#  'Scottish Gaelic',
#  'Cornish',
#  'Chuvash',
#  'Afrikaans',
#  'Estonian',
#  'Swedish',
#  'Central Khmer',
#  'Indonesian',
#  'English',
#  'Spanish',
#  'French',
#  'Finnish',
#  'Belarusian',
#  'Icelandic',
#  'nan',
#  'Assamese',
#  'Kazakh',
#  'Chinese',
#  'Belarusian',
#  'Dutch',
#  'Malay',
#  'Volapük',
#  'Albanian',
#  'nan',
#  'Assamese',
#  'nan',
#  'Chinese',
#  'Russian',
#  'Chinese',
#  'Armenian',
#  'Finnish',
#  'nan',
#  'Ossetian',
#  'Burmese',
#  'Chuvash',
#  'Finnish',
#  'nan',
#  'nan',
#  'Bashkir',
#  'Dutch',
#  'Russian',
#  'Arabic',
#  'Polish',
#  'Nepali',
#  'nan',
#  'Spanish',
#  'Finnish',
#  'Italian',
#  'Turkish',
#  'Arabic',
#  'Turkish',
#  'Urdu',
#  'Uzbek',
#  'Esperanto',
#  'Hindi',
#  'nan',
#  'Irish',
#  'Haitian',
#  'nan',
#  'Tagalog',
#  'Portuguese',
#  'Japanese',
#  'nan',
#  'Mongolian',
#  'Sindhi',
#  'Spanish',
#  'French',
#  'German',
#  'German',
#  'Scottish Gaelic',
#  'English',
#  'Polish',
#  'Finnish',
#  'Welsh',
#  'English',
#  'Sanskrit',
#  'Cornish',
#  'Hebrew',
#  'Dutch',
#  'nan',
#  'Dutch',
#  'Volapük',
#  'Finnish',
#  'Kurdish',
#  'Lao',
#  'Kurdish',
#  'Indonesian',
#  'nan',
#  'Welsh',
#  'Croatian',
#  'English',
#  'Mongolian',
#  'Marathi',
#  'Belarusian',
#  'Russian',
#  'Mongolian',
#  'Bashkir',
#  'Dutch',
#  'Portuguese',
#  'Georgian',
#  'Tagalog',
#  'Guarani',
#  'nan',
#  'Central Khmer',
#  'Norwegian Nynorsk',
#  'Galician',
#  'Swahili',
#  'Italian',
#  'Maltese',
#  'Welsh',
#  'German',
#  'Russian',
#  'Scottish Gaelic',
#  'English',
#  'nan',
#  'Ido',
#  'nan',
#  'Serbian',
#  'Kannada',
#  'Hungarian',
#  'Vietnamese',
#  'Bulgarian',
#  'Persian',
#  'Albanian',
#  'Vietnamese',
#  'Hebrew',
#  'Polish',
#  'Irish',
#  'Bashkir',
#  'Welsh',
#  'Russian',
#  'Spanish',
#  'Lao',
#  'Hindi',
#  'Russian',
#  'Russian',
#  'Persian',
#  'Gujarati',
#  'Dhivehi',
#  'Italian',
#  'Estonian',
#  'nan',
#  'Telugu',
#  'Russian',
#  'Catalan',
#  'Turkmen',
#  'Portuguese',
#  'Polish',
#  'Bulgarian',
#  'Dutch',
#  'Sindhi',
#  'Tibetan',
#  'Spanish',
#  'Hindi',
#  'German',
#  'Finnish',
#  'Mongolian',
#  'Swahili',
#  'Russian',
#  'Italian',
#  'Maltese',
#  'Italian',
#  'Indonesian',
#  'Spanish',
#  'Latvian',
#  'nan',
#  'Italian',
#  'Assamese',
#  'nan',
#  'English',
#  'Romansh',
#  'nan',
#  'English',
#  'Vietnamese',
#  'nan',
#  'Chuvash',
#  'Indonesian',
#  'Dutch',
#  'Telugu',
#  'French',
#  'Tamil',
#  'English',
#  'Croatian',
#  'Urdu',
#  'Irish',
#  'Hungarian',
#  'French',
#  'Dutch',
#  'Italian',
#  'English',
#  'nan',
#  'Sanskrit',
#  'Russian',
#  'Esperanto',
#  'Slovenian',
#  'nan',
#  'Swedish',
#  'English',
#  'nan',
#  'Persian',
#  'Spanish',
#  'Chinese',
#  'Russian',
#  'Vietnamese',
#  'Russian',
#  'Swahili',
#  'German',
#  'Russian',
#  'Western Frisian',
#  'Turkish',
#  'Panjabi',
#  'Spanish',
#  'nan',
#  'nan',
#  'English',
#  'Walloon',
#  'Korean',
#  'nan',
#  'Marathi',
#  'Latvian',
#  'nan',
#  'Lithuanian',
#  'Ido',
#  'Hindi',
#  'Tagalog',
#  'Latvian',
#  'Hebrew',
#  'English',
#  'Russian',
#  'Arabic',
#  'Finnish',
#  'Polish',
#  'Hindi',
#  'Thai',
#  'Albanian',
#  'Interlingua',
#  'Italian',
#  'Portuguese',
#  'Esperanto',
#  'nan',
#  'Norwegian Nynorsk',
#  'Hebrew',
#  'German',
#  'Arabic',
#  'Ukrainian',
#  'Volapük',
#  'Tamil',
#  'nan',
#  'Sindhi',
#  'nan',
#  'Oriya',
#  'nan',
#  'nan',
#  'Afrikaans',
#  'Vietnamese',
#  'nan',
#  'German',
#  'Estonian',
#  'Chechen',
#  'Guarani',
#  'Occitan',
#  'nan',
#  'Latvian',
#  'Maltese',
#  'Yiddish',
#  'German',
#  'Romansh',
#  'German',
#  'Swahili',
#  'Catalan',
#  'Bashkir',
#  'Cornish',
#  'Malagasy',
#  'Belarusian',
#  'nan',
#  'Czech',
#  'Galician',
#  'Scottish Gaelic',
#  'English',
#  'English',
#  'Ido',
#  'nan',
#  'Kazakh',
#  'Chuvash',
#  'Estonian',
#  'Haitian',
#  'Indonesian',
#  'English',
#  'Icelandic',
#  'nan',
#  'Hungarian',
#  'Serbian',
#  'nan',
#  'French',
#  'nan',
#  'Italian',
#  'English',
#  'Western Frisian',
#  'Pushto',
#  'Bashkir',
#  'Galician',
#  'Hindi',
#  'Uighur',
#  'nan',
#  'Turkish',
#  'Swahili',
#  'Chechen',
#  'nan',
#  'Romanian',
#  'Urdu',
#  'Afrikaans',
#  'German',
#  'Azerbaijani',
#  'Finnish',
#  'Ukrainian',
#  'Pushto',
#  'German',
#  'Dhivehi',
#  'Indonesian',
#  'Panjabi',
#  'Spanish',
#  'German',
#  'nan',
#  'Thai',
#  'German',
#  'Latvian',
#  'Estonian',
#  'Norwegian',
#  'English',
#  'Latvian',
#  'Sanskrit',
#  'Spanish',
#  'Irish',
#  'Mongolian',
#  'Volapük',
#  'Finnish',
#  'Serbo-Croatian',
#  'Czech',
#  'Icelandic',
#  'Bengali',
#  'Russian',
#  'English',
#  'Persian',
#  'Chuvash',
#  'Vietnamese',
#  'Western Frisian',
#  'Malagasy',
#  'Arabic',
#  'Quechua',
#  'Guarani',
#  'Russian',
#  'Kirghiz',
#  'Czech',
#  'Icelandic',
#  'Russian',
#  'Uzbek',
#  'Marathi',
#  'nan',
#  'Persian',
#  'French',
#  'French',
#  'Chinese',
#  'Spanish',
#  'Welsh',
#  'Chinese',
#  'Latvian',
#  'Polish',
#  'nan',
#  'Walloon',
#  'Russian',
#  'Tatar',
#  'Spanish',
#  'English',
#  'English',
#  'German',
#  'Armenian',
#  'Czech',
#  'Spanish',
#  'nan',
#  'German',
#  'nan',
#  'Galician',
#  'Japanese',
#  'nan',
#  'Finnish',
#  'nan',
#  'Scottish Gaelic',
#  'Portuguese',
#  'Kannada',
#  'Spanish',
#  'Telugu',
#  'Vietnamese',
#  'Italian',
#  'Vietnamese',
#  'Slovak',
#  'Hindi',
#  'French',
#  'Dutch',
#  'Sanskrit',
#  'Serbo-Croatian',
#  'Bengali',
#  'Persian',
#  'Slovenian',
#  'Persian',
#  'nan',
#  'English',
#  'nan',
#  'Uighur',
#  'Russian',
#  'Finnish',
#  'German',
#  'nan',
#  'Norwegian Nynorsk',
#  'English',
#  'French',
#  'French',
#  'Croatian',
#  'Irish',
#  'Quechua',
#  'Tatar',
#  'Esperanto',
#  'Polish',
#  'Persian',
#  'Tajik',
#  'Swedish',
#  'Panjabi',
#  'Breton',
#  'nan',
#  'Italian',
#  'Spanish',
#  'nan',
#  'Indonesian',
#  'Slovenian',
#  'Breton',
#  'Latin',
#  'nan',
#  'Dutch',
#  'Esperanto',
#  'English',
#  'nan',
#  'Spanish',
#  'Catalan',
#  'Persian',
#  'Dutch',
#  'Sindhi',
#  'Bulgarian',
#  'Hungarian',
#  'French',
#  'Italian',
#  'Finnish',
#  'Belarusian',
#  'Swahili',
#  'Tagalog',
#  'nan',
#  'Swedish',
#  'Polish',
#  'Sindhi',
#  'English',
#  'Polish',
#  'Romanian',
#  'Slovenian',
#  'Esperanto',
#  'Italian',
#  'Turkish',
#  'English',
#  'Assamese',
#  'Latin',
#  'nan',
#  'Swahili',
#  'Panjabi',
#  'Mongolian',
#  'Azerbaijani',
#  'Bulgarian',
#  'Pushto',
#  'Malay',
#  'Urdu',
#  'English',
#  'Tagalog',
#  'Indonesian',
#  'English',
#  'Estonian',
#  'Cornish',
#  'Indonesian',
#  'Lithuanian',
#  'Scottish Gaelic',
#  'Welsh',
#  'Kazakh',
#  'Sinhala',
#  'Portuguese',
#  'Oriya',
#  'Telugu',
#  'Finnish',
#  'Guarani',
#  'Maltese',
#  'nan',
#  'nan',
#  'Armenian',
#  'English',
#  'Tamil',
#  'Kazakh',
#  'Polish',
#  'Irish',
#  'English',
#  'German',
#  'Russian',
#  'Hindi',
#  'Malay',
#  'Russian',
#  'Volapük',
#  'Yiddish',
#  'Danish',
#  'Bengali',
#  'Albanian',
#  'Sanskrit',
#  'French',
#  'Tajik',
#  'English',
#  'Tamil',
#  'Hungarian',
#  'Tagalog',
#  'Hindi',
#  'Malay',
#  'Turkish',
#  'Breton',
#  'Kazakh',
#  'Latin',
#  'Sanskrit',
#  'Dutch',
#  'Welsh',
#  'Romanian',
#  'Central Khmer',
#  'nan',
#  'Albanian',
#  'English',
#  'Latin',
#  'Serbian',
#  'nan',
#  'Bulgarian',
#  'Swahili',
#  'English',
#  'Scottish Gaelic',
#  'Chinese',
#  'Basque',
#  'Spanish',
#  'English',
#  'Tatar',
#  'Polish',
#  'Polish',
#  'Belarusian',
#  'Dhivehi',
#  'Hindi',
#  'Vietnamese',
#  'Italian',
#  'English',
#  'Uzbek',
#  'English',
#  'Pushto',
#  'nan',
#  'Russian',
#  'Tibetan',
#  'Malay',
#  'nan',
#  'Malay',
#  'Korean',
#  'Welsh',
#  'Swedish',
#  'Japanese',
#  'Russian',
#  'Italian',
#  'Modern Greek',
#  'nan',
#  'Chinese',
#  'nan',
#  'Spanish',
#  'Panjabi',
#  'English',
#  'Latin',
#  'nan',
#  'French',
#  'Tibetan',
#  'Tamil',
#  'Albanian',
#  'Malagasy',
#  'Mongolian',
#  'Persian',
#  'Galician',
#  'Hindi',
#  'Polish',
#  'nan',
#  'Thai',
#  'Finnish',
#  'Welsh',
#  'Russian',
#  'Ukrainian',
#  'Finnish',
#  'Georgian',
#  'Tagalog',
#  'Central Khmer',
#  'Spanish',
#  'Spanish',
#  'Assamese',
#  'Bengali',
#  'Dutch',
#  'Bashkir',
#  'Russian',
#  'Serbian',
#  'Maltese',
#  'nan',
#  'nan',
#  'Swahili',
#  'nan',
#  'Italian',
#  'Spanish',
#  'Volapük',
#  'Dutch',
#  'Dutch',
#  'Quechua',
#  'Russian',
#  'Spanish',
#  'English',
#  'Czech',
#  'Czech',
#  'Chinese',
#  'Afrikaans',
#  'Dutch',
#  'Turkish',
#  'Dutch',
#  'English',
#  'German',
#  'nan',
#  'English',
#  'Spanish',
#  'Russian',
#  'Sanskrit',
#  'Belarusian',
#  'Vietnamese',
#  'Kannada',
#  'Bengali',
#  'Estonian',
#  'Catalan',
#  'Spanish']

# %%
acc = accuracy_score(train_list, ft_names)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.424

# %%
ft_names[3]
# Out:
# 'Occitan (post 1500)'

# %%
re.sub("[(\[].*?[\)]", "", ft_names[3])[:-1]
# Out:
# 'Occita'

# %%
'(' in ft_names[3]
# Out:
# False

# %%
acc = accuracy_score(y_tr_new_1k_2, ft_predict)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.519

# %%
langs = ["Gujarati", "Malayalam", "Albanian", "Punjabi", "Telugu", "Arabic", "Bulgarian", "Bengali", "Macedonian", 
      "Tamil", "Tagalog", "Chinese", "Croatian", "Czech", "Danish", "Dutch", "English", "Estonian", "Finnish", 
      "French", "German", "Greek", "Hebrew", "Hindi", "Hungarian", "Indonesian", "Italian", "Japanese", "Korean", 
      "Latvian", "Lithuanian", "Norwegian", "Persian", "Polish", "Portuguese", "Romanian", "Russian", "Slovak", 
      "Spanish", "Swedish", "Thai", "Turkish", "Ukrainian", "Urdu", "Vietnamese"]

# %%
len(langs)
# Out:
# 45

# %%
for name in labels_df['English']:
    if  name == 'Wu Chinese' or 'Cantonese' or 'Standard Chinese' or 'Hakka Chinese' or 'Literary Chinese':
        labels_df['English'][i] == 'Chinese'
    elif name == 'modern Greek ':
        labels_df['English'][i] == 'Greek'
    elif name == 'Norwegian Nynorsk':
        labels_df['English'][i] == 'Norwegian'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-156-54684d391827> in <module>
#       1 for name in labels_df['English']:
#       2     if  name == 'Wu Chinese' or 'Cantonese' or 'Standard Chinese' or 'Hakka Chinese' or 'Literary Chinese':
# ----> 3         labels_df['English'][i] == 'Chinese'
#       4     elif name == 'modern Greek ':
#       5         labels_df['English'][i] == 'Greek'
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 999

# %%
labels_df['English'].replace({"Wu Chinese": "Chinese", "Cantonese": "Chinese", "Standard Chinese": 'Chinese',
                              'Hakka Chinese': 'Chinese', 'Literary Chinese': 'Chinese', 'Modern Greek': 'Greek',
                             'Norwegian Nynorsk': 'Norwegian'}, inplace=True)

# %%
lang_labels = list(labels_df[labels_df['English'].isin(langs)]['Label'])
len(lang_labels)
# Out:
# 48

# %%
lang_names = (list(labels_df[labels_df['English'].isin(langs)]['English']))
lang_names
# Out:
# ['Arabic',
#  'Bengali',
#  'Bulgarian',
#  'Czech',
#  'Danish',
#  'German',
#  'Greek',
#  'English',
#  'Estonian',
#  'Persian',
#  'Finnish',
#  'French',
#  'Gujarati',
#  'Chinese',
#  'Hebrew',
#  'Hindi',
#  'Croatian',
#  'Hungarian',
#  'Indonesian',
#  'Italian',
#  'Japanese',
#  'Korean',
#  'Latvian',
#  'Lithuanian',
#  'Chinese',
#  'Malayalam',
#  'Macedonian',
#  'Dutch',
#  'Norwegian',
#  'Polish',
#  'Portuguese',
#  'Romanian',
#  'Russian',
#  'Slovak',
#  'Spanish',
#  'Albanian',
#  'Swedish',
#  'Tamil',
#  'Telugu',
#  'Tagalog',
#  'Thai',
#  'Turkish',
#  'Ukrainian',
#  'Urdu',
#  'Vietnamese',
#  'Chinese',
#  'Chinese',
#  'Chinese']

# %%
## Greek - modern Greek 
## Chinese
## Norwegian - Norwegian Nynorsk
## Slovenian exclude

# %%
def read_file(x_file, y_file):
    y_df = pd.read_csv(y_file, header=None)
    # y_df has only one column; name it 'Label'
    y_df.columns = ['Label']

    # Read contents of 'x_file' into a list of strings
    with open(x_file, encoding='utf8') as f:
        x_pars = f.readlines()
    
    # Remove all whitespace characters (such as '\n') from the beginning and the end of the strings
    x_pars = [t.strip() for t in x_pars]
    # Convert the list into a dataframe, with one column: 'Par'
    x_df = pd.DataFrame(x_pars, columns=['Par']) 
    # Just keep paragraphs of languages in lang_labels (and remove other languages)
    x_df = x_df[y_df['Label'].isin(lang_labels)]
    # Just keep languages in lang_labels
    y_df = y_df[y_df['Label'].isin(lang_labels)]

    return (x_df, y_df)

# %%
x_train, y_train = read_file(x_train_file, y_train_file)

# %%
x_train['Par'][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-183-bdddac97c129> in <module>
# ----> 1 x_train['Par'][2]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2

# %%
y_tr_1k = y_train

# %%
y_tr_new = y_train.merge(labels_df, on = "Label", how = "left")
y_tr_new_1k = y_tr_new['English']

# %%
x_train.reset_index()
# Out:
#         index                                                Par
# 0           0  Klement Gottwaldi surnukeha palsameeriti ning ...
# 1           1  Sebes, Joseph; Pereira Thomas (1961) (på eng)....
# 2           4  ถนนเจริญกรุง (อักษรโรมัน: Thanon Charoen Krung...
# 3           7  He was a economics graduate from Elphinstone C...
# 4          13  விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...
# 5          14  Bùi Tiến Dũng (sinh năm 1959 tại huyện Ứng Hòa...
# 6          19  UNC有得一只历史悠久个'诚信守则'。渠是由学堂个诚信法庭（Honor Court）来执行个...
# 7          26  De spons behoort tot het geslacht Haliclona en...
# 8          29  エノが行きがかりでバスに乗ってしまい、気分が悪くなった際に助けるが、今すぐバスを降りたいと運...
# 9          38  Tsutinalar (İngilizce: Tsuut'ina): Kanada'da A...
# 10         44  برقی بار (electric charge) تمام زیرجوہری ذرات ...
# 11         46  シャーリー・フィールドは、サン・ベルナルド・アベニュー沿い市民センターとR&Tマーティン高校...
# 12         49  Kemunculan pertamanya adalah ketika mencium ka...
# 13         51  1998年11月，一位中年女人自創燒炭自殺，將自己同燒烤爐封響沖涼房裏面。由於呢種方法之前，...
# 14         52  Indtil 1545 havde flådecheferne kunnet hyre et...
# 15         53  Barocco (pt: Escândalo de 1ª página) é um film...
# 16         54  Association de recherche et de sauvegarde de l...
# 17         67  胡赛尼本人和小说的主人公阿米尔一样，都是出生在阿富汗首都喀布尔，少年时代便离开了这个国家。胡...
# 18         68  한국에서 성씨가 사용되기 시작한 정확한 시기는 알 수 없으나, 한자(漢字) 등 중국...
# 19         73  Разположено е в полите на планината Плана и из...
# 20         74  การฟาดฟันของบรรดาสาวงามในกองประกวด Miss Beauty...
# 21         86  Dorota Rabczewska, artistinimega Doda (sündinu...
# 22         88  Diante destes gerenciamentos, podendo ser feit...
# 23         90  Besemer, S., Van der Geest, V., Murray, J., Bi...
# 24         93  महाराष्ट्र, १ मई १९६० को भारत का राज्य बनाया ग...
# 25        101  ஆங்கில எழுத்துக்களை மட்டும் அல்லாமல் பன்மொழி எ...
# 26        119  En Navidad de 1974, poco después de que interp...
# 27        120  Маратѐа (на италиански: Maratea, на местен диа...
# 28        125  La chirurgie comprenant principalement l'ablat...
# 29        126  Dès les années 1920, les communes voisines d'A...
# ...       ...                                                ...
# 23970  117333  Fnatmide (Sarcoptes scabiei) er en type mide, ...
# 23971  117337  פרופיל B (warm and wet)- תחת פרופיל זה החולה ע...
# 23972  117342  Podemos fazer a mesma coisa durante anos, sem,...
# 23973  117346  Мустанг групується навколо річки Калі-Гандакі ...
# 23974  117347  20 Haziran 2012 tarihinde Arianespace, Kazakis...
# 23975  117351  In Schiedam bevinden zich ongeveer 35 scholen ...
# 23976  117361  வாராந்தாவினைச் சார்ந்த பகுதியில் டீ/காஃபி பெறு...
# 23977  117364  Si Papa Benedicto IX (c. 1012 – c. 1056) na ip...
# 23978  117375  Džingulis – tradicinis lietuvių liaudies ritmi...
# 23979  117381  Birželio 13 d. – Gintaras Goda, teisininkas, t...
# 23980  117382  സ്വർഗ്ഗവാതിലിന് മുൻപിൽ നിന്നു പോലും നരകത്തിലേക...
# 23981  117383  Megjelenésekor a kritikusok kedvezően fogadták...
# 23982  117391  Temelj je proizvodne linije koja se primjenjuj...
# 23983  117412  4月8日首度訪泰，在新聞發布會現場超過200名記者爭相採訪，泰國主要的7頻道及報章雜誌等均大...
# 23984  117415  En 1926, Tibor Radó demanda si le prolongement...
# 23985  117418  A Kőröshegyi völgyhíd viadukt az M7-es autópál...
# 23986  117422  2012년에 피니와 퍼브는 Marble Entertainment와 한 만화에 등장하...
# 23987  117423  בשנת תר"א 1841 נפטר רבי יעקב קאזיס, רבה של מנט...
# 23988  117433  Kaspar Deutschenbaur, auch Caspar Deutschenbau...
# 23989  117438  ابن العلقمي وزير الخليفة العباسي المستعصم، رتب...
# 23990  117450  Από το 1970 βρήκε καλλιτεχνικό καταφύγιο στην ...
# 23991  117454  Олександр Денисенко є членом Національної спіл...
# 23992  117459  மொகமது ஃபுவாத் மசூம் (Muhammad Fuad Masum, குர...
# 23993  117465  மூர்த்தி திருநாமம் :- அகிலாண்டேசுரர் அம்பாள் ப...
# 23994  117468  현대 한국은 종교가 기독교인 사람이 꽤 많기 때문에 이와 연관된 서양식 성명을 갖는...
# 23995  117480  During World Class' golden era, Hart was also ...
# 23996  117489  Atractus edioi este o specie de șerpi din genu...
# 23997  117492  2010 року серед 201 особи працездатного віку (...
# 23998  117497  同年，太后崩。絳侯周勃、陳平諸臣共謀誅呂。朱虛侯章已殺呂產，文帝使人持節勞章。朱虛侯欲奪節信...
# 23999  117498  I det mindste opnåede Venedig den 18. april 14...
#
# [24000 rows x 2 columns]

# %%
x_train_reindex = x_train.reset_index()

# %%
x_train_reindex['Par'][3]
# Out:
# 'He was a economics graduate from Elphinstone College, Mumbai. He was an industrialist in plastics business. He served as a president of Gujarat Chamber of Commerce and Industry in 1990s.'

# %%
y_tr_new_1k
# Out:
# 0          Estonian
# 1           Swedish
# 2              Thai
# 3          Gujarati
# 4             Tamil
# 5        Vietnamese
# 6           Chinese
# 7             Dutch
# 8          Japanese
# 9           Turkish
# 10             Urdu
# 11         Japanese
# 12       Indonesian
# 13          Chinese
# 14           Danish
# 15       Portuguese
# 16           French
# 17          Chinese
# 18           Korean
# 19        Bulgarian
# 20             Thai
# 21         Estonian
# 22       Portuguese
# 23       Portuguese
# 24            Hindi
# 25            Tamil
# 26          Spanish
# 27        Bulgarian
# 28           French
# 29           French
#             ...
# 23970        Danish
# 23971        Hebrew
# 23972    Portuguese
# 23973     Ukrainian
# 23974       Turkish
# 23975         Dutch
# 23976         Tamil
# 23977       Tagalog
# 23978    Lithuanian
# 23979    Lithuanian
# 23980     Malayalam
# 23981     Hungarian
# 23982      Croatian
# 23983       Chinese
# 23984        French
# 23985     Hungarian
# 23986        Korean
# 23987        Hebrew
# 23988        German
# 23989        Arabic
# 23990         Greek
# 23991     Ukrainian
# 23992         Tamil
# 23993         Tamil
# 23994        Korean
# 23995       English
# 23996      Romanian
# 23997     Ukrainian
# 23998       Chinese
# 23999        Danish
# Name: English, Length: 24000, dtype: object

# %%
ft_predict = []
for i in range(len(x_train_reindex)): 
    sentences = x_train_reindex['Par'][i]
    predicted_lang = model.predict(sentences)
    print(predicted_lang)
    ft_predict.append(predicted_lang[0][0][9:])
# Out:
# (('__label__et',), array([0.87263]))
# (('__label__en',), array([0.26207453]))
# (('__label__th',), array([0.99940717]))
# (('__label__en',), array([0.99700701]))
# (('__label__ta',), array([0.99972832]))
# (('__label__vi',), array([0.99803317]))
# (('__label__zh',), array([0.99906862]))
# (('__label__nl',), array([0.99554825]))
# (('__label__ja',), array([1.00004518]))
# (('__label__tr',), array([0.97863638]))
# (('__label__ur',), array([0.94376165]))
# (('__label__ja',), array([1.00004745]))
# (('__label__id',), array([0.79528564]))
# (('__label__zh',), array([0.99787217]))
# (('__label__da',), array([0.94664299]))
# (('__label__pt',), array([0.855272]))
# (('__label__fr',), array([0.86295325]))
# (('__label__zh',), array([0.99940497]))
# (('__label__ko',), array([1.00006831]))
# (('__label__bg',), array([0.9240793]))
# (('__label__th',), array([0.99975604]))
# (('__label__et',), array([0.95673162]))
# (('__label__pt',), array([0.96831256]))
# (('__label__en',), array([0.73308909]))
# (('__label__hi',), array([0.99295318]))
# (('__label__ta',), array([0.99961758]))
# (('__label__es',), array([0.98304355]))
# (('__label__bg',), array([0.90271723]))
# (('__label__fr',), array([0.85974211]))
# (('__label__fr',), array([0.99195772]))
# (('__label__et',), array([0.2261683]))
# (('__label__ko',), array([1.0000664]))
# (('__label__de',), array([0.96394998]))
# (('__label__vi',), array([0.99902415]))
# (('__label__te',), array([0.99995095]))
# (('__label__it',), array([0.99041623]))
# (('__label__fr',), array([0.9970116]))
# (('__label__fi',), array([0.98362905]))
# (('__label__nl',), array([0.9794184]))
# (('__label__fa',), array([0.97934699]))
# (('__label__fr',), array([0.94293177]))
# (('__label__gu',), array([0.98422861]))
# (('__label__ro',), array([0.99552566]))
# (('__label__lv',), array([0.95775038]))
# (('__label__cs',), array([0.9870469]))
# (('__label__ru',), array([0.97297865]))
# (('__label__da',), array([0.92402631]))
# (('__label__ja',), array([1.00004959]))
# (('__label__lt',), array([0.98298502]))
# (('__label__sq',), array([0.9949373]))
# (('__label__id',), array([0.71050757]))
# (('__label__sk',), array([0.88572383]))
# (('__label__it',), array([0.99158585]))
# (('__label__uk',), array([0.99614149]))
# (('__label__lt',), array([0.96433884]))
# (('__label__hr',), array([0.56330454]))
# (('__label__vi',), array([0.99829519]))
# (('__label__en',), array([0.97893351]))
# (('__label__fr',), array([0.97347599]))
# (('__label__zh',), array([0.99728674]))
# (('__label__bn',), array([0.92395478]))
# (('__label__lt',), array([0.97128612]))
# (('__label__lt',), array([0.99507546]))
# (('__label__fi',), array([0.97963887]))
# (('__label__pt',), array([0.95890713]))
# (('__label__en',), array([0.95264345]))
# (('__label__cs',), array([0.98782825]))
# (('__label__ur',), array([0.88167346]))
# (('__label__bn',), array([0.99073392]))
# (('__label__id',), array([0.96370292]))
# (('__label__lt',), array([0.9604829]))
# (('__label__id',), array([0.81236166]))
# (('__label__ku',), array([0.10823555]))
# (('__label__zh',), array([0.99871624]))
# (('__label__ja',), array([1.0000484]))
# (('__label__ar',), array([0.98781294]))
# (('__label__zh',), array([0.83439851]))
# (('__label__sk',), array([0.84901547]))
# (('__label__ml',), array([0.99903351]))
# (('__label__he',), array([0.99912411]))
# (('__label__tl',), array([0.12218988]))
# (('__label__id',), array([0.79470098]))
# (('__label__sv',), array([0.92411888]))
# (('__label__en',), array([0.95673203]))
# (('__label__zh',), array([0.99321932]))
# (('__label__nl',), array([0.99048489]))
# (('__label__sq',), array([0.99675328]))
# (('__label__zh',), array([0.99809766]))
# (('__label__ru',), array([0.98855144]))
# (('__label__zh',), array([0.9939782]))
# (('__label__nl',), array([0.99614179]))
# (('__label__ar',), array([0.99123985]))
# (('__label__ar',), array([0.99091583]))
# (('__label__tr',), array([0.99276155]))
# (('__label__ur',), array([0.98272705]))
# (('__label__ja',), array([0.58572197]))
# (('__label__fr',), array([0.965532]))
# (('__label__he',), array([0.99981296]))
# (('__label__ku',), array([0.16949651]))
# (('__label__pt',), array([0.96261561]))
# (('__label__tl',), array([0.89638019]))
# (('__label__nn',), array([0.44493639]))
# (('__label__vi',), array([0.99813443]))
# (('__label__bg',), array([0.90657169]))
# (('__label__sq',), array([0.99777883]))
# (('__label__vi',), array([0.13927096]))
# (('__label__he',), array([0.99980402]))
# (('__label__gu',), array([0.99936604]))
# (('__label__te',), array([0.99995404]))
# (('__label__pt',), array([0.98294175]))
# (('__label__id',), array([0.91333061]))
# (('__label__lv',), array([0.93638551]))
# (('__label__vi',), array([0.99687546]))
# (('__label__id',), array([0.73987639]))
# (('__label__te',), array([0.99992895]))
# (('__label__ta',), array([0.99972612]))
# (('__label__hu',), array([0.98754698]))
# (('__label__it',), array([0.99560481]))
# (('__label__sv',), array([0.97999036]))
# (('__label__fa',), array([0.99164796]))
# (('__label__zh',), array([0.98701447]))
# (('__label__vi',), array([0.99867338]))
# (('__label__ru',), array([0.98209608]))
# (('__label__en',), array([0.5821299]))
# (('__label__ko',), array([1.00006938]))
# (('__label__lv',), array([0.96354544]))
# (('__label__he',), array([0.99932599]))
# (('__label__ar',), array([0.5377124]))
# (('__label__th',), array([0.99995333]))
# (('__label__sq',), array([0.96666408]))
# (('__label__pt',), array([0.96852005]))
# (('__label__nn',), array([0.59789771]))
# (('__label__he',), array([0.99991208]))
# (('__label__ar',), array([0.99359584]))
# (('__label__uk',), array([0.98475045]))
# (('__label__ta',), array([0.99971253]))
# (('__label__de',), array([0.90438086]))
# (('__label__pms',), array([0.16319998]))
# (('__label__hu',), array([0.98793316]))
# (('__label__ur',), array([0.96234202]))
# (('__label__uk',), array([0.99921852]))
# (('__label__de',), array([0.99670166]))
# (('__label__lv',), array([0.97737402]))
# (('__label__bn',), array([0.98400998]))
# (('__label__en',), array([0.94373298]))
# (('__label__vi',), array([0.16422735]))
# (('__label__cs',), array([0.98440564]))
# (('__label__ru',), array([0.97559106]))
# (('__label__fa',), array([0.97428745]))
# (('__label__zh',), array([0.98857641]))
# (('__label__lv',), array([0.782233]))
# (('__label__pl',), array([0.99418378]))
# (('__label__ja',), array([1.000049]))
# (('__label__pt',), array([0.96720779]))
# (('__label__te',), array([0.99991065]))
# (('__label__vi',), array([0.99819946]))
# (('__label__hi',), array([0.98451298]))
# (('__label__bn',), array([0.99513751]))
# (('__label__fa',), array([0.99254996]))
# (('__label__en',), array([0.51619089]))
# (('__label__nn',), array([0.30592006]))
# (('__label__en',), array([0.12414395]))
# (('__label__hr',), array([0.27956116]))
# (('__label__sv',), array([0.98641032]))
# (('__label__id',), array([0.28850067]))
# (('__label__bg',), array([0.94957185]))
# (('__label__hu',), array([0.99552172]))
# (('__label__fr',), array([0.99633515]))
# (('__label__tl',), array([0.95069212]))
# (('__label__bg',), array([0.92714196]))
# (('__label__ms',), array([0.13580289]))
# (('__label__en',), array([0.9813109]))
# (('__label__et',), array([0.96247578]))
# (('__label__id',), array([0.97405094]))
# (('__label__lt',), array([0.96239364]))
# (('__label__te',), array([0.99981302]))
# (('__label__ta',), array([0.99974418]))
# (('__label__bn',), array([0.99857539]))
# (('__label__ta',), array([0.99981189]))
# (('__label__sq',), array([0.99818933]))
# (('__label__bg',), array([0.96307093]))
# (('__label__zh',), array([0.99251014]))
# (('__label__en',), array([0.93868083]))
# (('__label__pl',), array([0.99085552]))
# (('__label__ko',), array([1.00006843]))
# (('__label__sv',), array([0.61667997]))
# (('__label__ja',), array([1.00004423]))
# (('__label__ru',), array([0.98230463]))
# (('__label__it',), array([0.97899544]))
# (('__label__el',), array([0.99750781]))
# (('__label__zh',), array([0.89434159]))
# (('__label__ta',), array([0.99975967]))
# (('__label__sq',), array([0.99579501]))
# (('__label__fa',), array([0.98802793]))
# (('__label__pl',), array([0.99673766]))
# (('__label__th',), array([0.99957752]))
# (('__label__uk',), array([0.98640257]))
# (('__label__bn',), array([0.99021947]))
# (('__label__en',), array([0.84485787]))
# (('__label__cs',), array([0.9813394]))
# (('__label__cs',), array([0.94901752]))
# (('__label__zh',), array([0.74538529]))
# (('__label__tr',), array([0.98770374]))
# (('__label__bn',), array([0.9912281]))
# (('__label__et',), array([0.9100821]))
# (('__label__en',), array([0.97846365]))
# (('__label__da',), array([0.91582996]))
# (('__label__sv',), array([0.97070122]))
# (('__label__zh',), array([0.96112752]))
# (('__label__tl',), array([0.89134324]))
# (('__label__ja',), array([0.99998724]))
# (('__label__he',), array([0.99973446]))
# (('__label__zh',), array([0.99987525]))
# (('__label__zh',), array([0.99066216]))
# (('__label__th',), array([0.9988907]))
# (('__label__nn',), array([0.50966805]))
# (('__label__fr',), array([0.99275362]))
# (('__label__te',), array([0.99991816]))
# (('__label__ar',), array([0.99048543]))
# (('__label__ro',), array([0.21798263]))
# (('__label__es',), array([0.98253232]))
# (('__label__gu',), array([0.99990654]))
# (('__label__ar',), array([0.99048591]))
# (('__label__ko',), array([1.00006926]))
# (('__label__fi',), array([0.98087764]))
# (('__label__th',), array([0.99953073]))
# (('__label__hu',), array([0.95939827]))
# (('__label__ar',), array([0.99373394]))
# (('__label__el',), array([0.99371523]))
# (('__label__et',), array([0.94277972]))
# (('__label__zh',), array([0.99993426]))
# (('__label__ja',), array([1.00004578]))
# (('__label__tr',), array([0.99054843]))
# (('__label__et',), array([0.9553476]))
# (('__label__ru',), array([0.99009848]))
# (('__label__bn',), array([0.9886536]))
# (('__label__mk',), array([0.98094493]))
# (('__label__fi',), array([0.98042041]))
# (('__label__nn',), array([0.73420495]))
# (('__label__en',), array([0.99800551]))
# (('__label__ml',), array([0.99821448]))
# (('__label__th',), array([0.99975592]))
# (('__label__ur',), array([0.78765571]))
# (('__label__ru',), array([0.98870057]))
# (('__label__zh',), array([0.99251866]))
# (('__label__bg',), array([0.95422196]))
# (('__label__he',), array([0.99983788]))
# (('__label__de',), array([0.99871254]))
# (('__label__ru',), array([0.95295233]))
# (('__label__mk',), array([0.91406792]))
# (('__label__ru',), array([0.99391776]))
# (('__label__zh',), array([1.00005639]))
# (('__label__hi',), array([0.96389812]))
# (('__label__zh',), array([0.99599046]))
# (('__label__ko',), array([1.00006998]))
# (('__label__fa',), array([0.99314952]))
# (('__label__zh',), array([0.96248788]))
# (('__label__sv',), array([0.99823898]))
# (('__label__zh',), array([0.90418744]))
# (('__label__gu',), array([0.99968755]))
# (('__label__ur',), array([0.80517846]))
# (('__label__gu',), array([0.9998579]))
# (('__label__ru',), array([0.98031479]))
# (('__label__he',), array([0.99900782]))
# (('__label__pl',), array([0.97216398]))
# (('__label__ko',), array([1.00006962]))
# (('__label__it',), array([0.99394453]))
# (('__label__ta',), array([0.99962127]))
# (('__label__de',), array([0.87170887]))
# (('__label__tr',), array([0.98175389]))
# (('__label__hr',), array([0.42736974]))
# (('__label__sv',), array([0.98726648]))
# (('__label__sr',), array([0.30013928]))
# (('__label__hi',), array([0.97929335]))
# (('__label__hi',), array([0.9850412]))
# (('__label__tr',), array([0.99822754]))
# (('__label__te',), array([0.99983215]))
# (('__label__hi',), array([0.98998982]))
# (('__label__sq',), array([0.99727815]))
# (('__label__th',), array([0.99961239]))
# (('__label__hi',), array([0.98417121]))
# (('__label__ml',), array([0.99939269]))
# (('__label__zh',), array([0.99593002]))
# (('__label__fi',), array([0.98374003]))
# (('__label__sq',), array([0.98715347]))
# (('__label__sk',), array([0.63363481]))
# (('__label__tr',), array([0.98496729]))
# (('__label__ht',), array([0.2156902]))
# (('__label__sq',), array([0.99373513]))
# (('__label__zh',), array([1.00002158]))
# (('__label__pt',), array([0.99902117]))
# (('__label__sh',), array([0.42850882]))
# (('__label__lv',), array([0.7787599]))
# (('__label__tr',), array([0.99417657]))
# (('__label__ur',), array([0.75489473]))
# (('__label__mk',), array([0.93914068]))
# (('__label__en',), array([0.97442001]))
# (('__label__bg',), array([0.94731617]))
# (('__label__en',), array([0.91661817]))
# (('__label__sq',), array([0.98998475]))
# (('__label__fr',), array([0.97536409]))
# (('__label__pl',), array([0.98100436]))
# (('__label__en',), array([0.95485038]))
# (('__label__sk',), array([0.78054142]))
# (('__label__cs',), array([0.98669779]))
# (('__label__zh',), array([0.99961573]))
# (('__label__hr',), array([0.33433133]))
# (('__label__tl',), array([0.94027829]))
# (('__label__th',), array([0.99952304]))
# (('__label__fi',), array([0.99466002]))
# (('__label__sk',), array([0.92632025]))
# (('__label__ko',), array([1.00006843]))
# (('__label__ja',), array([1.00004661]))
# (('__label__lt',), array([0.97745627]))
# (('__label__ml',), array([0.9994095]))
# (('__label__gu',), array([0.99869531]))
# (('__label__sk',), array([0.9154737]))
# (('__label__zh',), array([0.97879714]))
# (('__label__he',), array([0.99982518]))
# (('__label__es',), array([0.92280948]))
# (('__label__it',), array([0.98015624]))
# (('__label__en',), array([0.78086221]))
# (('__label__nn',), array([0.75540966]))
# (('__label__da',), array([0.93045825]))
# (('__label__sq',), array([0.99627912]))
# (('__label__de',), array([0.99498338]))
# (('__label__zh',), array([0.99871302]))
# (('__label__sk',), array([0.83631372]))
# (('__label__da',), array([0.92577022]))
# (('__label__tr',), array([0.99845827]))
# (('__label__no',), array([0.70570606]))
# (('__label__tl',), array([0.94995785]))
# (('__label__el',), array([0.99172735]))
# (('__label__pt',), array([0.98808855]))
# (('__label__it',), array([0.98898607]))
# (('__label__mk',), array([0.3074289]))
# (('__label__zh',), array([0.25950161]))
# (('__label__tl',), array([0.80242085]))
# (('__label__en',), array([0.29374936]))
# (('__label__uk',), array([0.99567771]))
# (('__label__en',), array([0.91815227]))
# (('__label__gu',), array([0.9995833]))
# (('__label__fr',), array([0.99048829]))
# (('__label__bn',), array([0.99240345]))
# (('__label__bg',), array([0.97847879]))
# (('__label__de',), array([0.99598962]))
# (('__label__th',), array([0.99983156]))
# (('__label__ja',), array([1.00003099]))
# (('__label__ta',), array([0.99956328]))
# (('__label__pl',), array([0.98478341]))
# (('__label__ko',), array([1.00006974]))
# (('__label__pl',), array([0.9961952]))
# (('__label__nl',), array([0.90694195]))
# (('__label__cs',), array([0.97623318]))
# (('__label__bn',), array([0.99760455]))
# (('__label__sv',), array([0.99296582]))
# (('__label__fa',), array([0.9908126]))
# (('__label__fi',), array([0.99282444]))
# (('__label__uk',), array([0.99663347]))
# (('__label__gu',), array([0.99887103]))
# (('__label__cs',), array([0.97384095]))
# (('__label__bg',), array([0.90219492]))
# (('__label__id',), array([0.75737214]))
# (('__label__te',), array([0.99983394]))
# (('__label__de',), array([0.94113296]))
# (('__label__de',), array([0.97604126]))
# (('__label__nl',), array([0.90957081]))
# (('__label__et',), array([0.95771396]))
# (('__label__fi',), array([0.99509287]))
# (('__label__tr',), array([0.99096161]))
# (('__label__pt',), array([0.92812365]))
# (('__label__et',), array([0.98068881]))
# (('__label__te',), array([0.9999519]))
# (('__label__da',), array([0.86906004]))
# (('__label__ar',), array([0.99350822]))
# (('__label__uk',), array([0.98528552]))
# (('__label__tr',), array([0.98660553]))
# (('__label__fr',), array([0.99334455]))
# (('__label__ur',), array([0.96681964]))
# (('__label__th',), array([0.99895221]))
# (('__label__tr',), array([0.52140498]))
# (('__label__ro',), array([0.99684596]))
# (('__label__sk',), array([0.81911719]))
# (('__label__ru',), array([0.98551244]))
# (('__label__fr',), array([0.97166002]))
# (('__label__nn',), array([0.78859794]))
# (('__label__vi',), array([0.99792987]))
# (('__label__es',), array([0.96567351]))
# (('__label__pl',), array([0.99461144]))
# (('__label__lt',), array([0.68662339]))
# (('__label__bg',), array([0.71440059]))
# (('__label__de',), array([0.9857021]))
# (('__label__zh',), array([0.99919778]))
# (('__label__mk',), array([0.95497751]))
# (('__label__bn',), array([0.99238676]))
# (('__label__uk',), array([0.98387063]))
# (('__label__sh',), array([0.39975104]))
# (('__label__pt',), array([0.99637246]))
# (('__label__de',), array([0.99382454]))
# (('__label__fa',), array([0.99065322]))
# (('__label__fa',), array([0.97559607]))
# (('__label__zh',), array([0.99816293]))
# (('__label__fi',), array([0.99452609]))
# (('__label__es',), array([0.9737314]))
# (('__label__fi',), array([0.98453689]))
# (('__label__de',), array([0.99898225]))
# (('__label__ro',), array([0.99668461]))
# (('__label__gu',), array([0.9989509]))
# (('__label__cs',), array([0.96701264]))
# (('__label__ja',), array([1.00004947]))
# (('__label__sk',), array([0.72157484]))
# (('__label__lt',), array([0.96484953]))
# (('__label__th',), array([0.99913138]))
# (('__label__tr',), array([0.98853028]))
# (('__label__zh',), array([0.99991059]))
# (('__label__vi',), array([0.99726868]))
# (('__label__ml',), array([0.99932283]))
# (('__label__tr',), array([0.99582624]))
# (('__label__ru',), array([0.92839336]))
# (('__label__sv',), array([0.91562712]))
# (('__label__ml',), array([0.99893439]))
# (('__label__sv',), array([0.95277971]))
# (('__label__he',), array([0.9996956]))
# (('__label__vi',), array([0.99884206]))
# (('__label__zh',), array([0.99692702]))
# (('__label__de',), array([0.98918772]))
# (('__label__pt',), array([0.94401711]))
# (('__label__bn',), array([0.99140698]))
# (('__label__nl',), array([0.9985677]))
# (('__label__id',), array([0.84025568]))
# (('__label__hu',), array([0.99312943]))
# (('__label__da',), array([0.94391245]))
# (('__label__hi',), array([0.95706505]))
# (('__label__nl',), array([0.96270031]))
# (('__label__sv',), array([0.99957263]))
# (('__label__sq',), array([0.99617857]))
# (('__label__sh',), array([0.46924672]))
# (('__label__cs',), array([0.94241422]))
# (('__label__el',), array([0.99702269]))
# (('__label__pl',), array([0.99669713]))
# (('__label__tl',), array([0.82047772]))
# (('__label__et',), array([0.40233734]))
# (('__label__id',), array([0.60770565]))
# (('__label__bg',), array([0.9090414]))
# (('__label__ko',), array([1.0000689]))
# (('__label__ja',), array([1.000036]))
# (('__label__fi',), array([0.98926604]))
# (('__label__vi',), array([0.99872923]))
# (('__label__lt',), array([0.87444842]))
# (('__label__ml',), array([0.99851263]))
# (('__label__uk',), array([0.99111998]))
# (('__label__pl',), array([0.65539253]))
# (('__label__tr',), array([0.99440491]))
# (('__label__zh',), array([0.99783498]))
# (('__label__uk',), array([0.99572259]))
# (('__label__sk',), array([0.93151081]))
# (('__label__lv',), array([0.89010048]))
# (('__label__bn',), array([0.98971754]))
# (('__label__el',), array([0.99535006]))
# (('__label__ml',), array([0.99936384]))
# (('__label__zh',), array([0.98106962]))
# (('__label__he',), array([0.9994598]))
# (('__label__pt',), array([0.9616738]))
# (('__label__fa',), array([0.9799068]))
# (('__label__hi',), array([0.98980695]))
# (('__label__he',), array([0.9998098]))
# (('__label__nl',), array([0.9633112]))
# (('__label__te',), array([0.99968076]))
# (('__label__hi',), array([0.98656607]))
# (('__label__ru',), array([0.98299289]))
# (('__label__ru',), array([0.98812419]))
# (('__label__zh',), array([0.99889362]))
# (('__label__cs',), array([0.97703487]))
# (('__label__ro',), array([0.99595881]))
# (('__label__ar',), array([0.99334776]))
# (('__label__uk',), array([0.99771953]))
# (('__label__zh',), array([0.4887884]))
# (('__label__zh',), array([0.99899673]))
# (('__label__en',), array([0.99043918]))
# (('__label__he',), array([0.99984354]))
# (('__label__it',), array([0.97978574]))
# (('__label__zh',), array([0.9542473]))
# (('__label__bg',), array([0.95173764]))
# (('__label__tl',), array([0.93345821]))
# (('__label__bg',), array([0.97568089]))
# (('__label__id',), array([0.7831282]))
# (('__label__da',), array([0.89922708]))
# (('__label__bg',), array([0.96750623]))
# (('__label__ru',), array([0.98296154]))
# (('__label__bg',), array([0.93870306]))
# (('__label__uk',), array([0.99432755]))
# (('__label__zh',), array([0.68931866]))
# (('__label__en',), array([0.9873417]))
# (('__label__tl',), array([0.86586988]))
# (('__label__sv',), array([0.97485787]))
# (('__label__en',), array([0.96684724]))
# (('__label__pl',), array([0.99647456]))
# (('__label__ta',), array([0.99917555]))
# (('__label__hi',), array([0.98841774]))
# (('__label__hu',), array([0.99276048]))
# (('__label__et',), array([0.96050572]))
# (('__label__ru',), array([0.99059898]))
# (('__label__id',), array([0.77343547]))
# (('__label__ar',), array([0.47101358]))
# (('__label__zh',), array([0.99569529]))
# (('__label__en',), array([0.9797346]))
# (('__label__hi',), array([0.98641992]))
# (('__label__vi',), array([0.99654442]))
# (('__label__zh',), array([0.94529742]))
# (('__label__ur',), array([0.970079]))
# (('__label__sq',), array([0.99664474]))
# (('__label__ml',), array([0.99953985]))
# (('__label__gu',), array([0.99957681]))
# (('__label__hu',), array([0.98755646]))
# (('__label__zh',), array([0.99977881]))
# (('__label__sk',), array([0.91118532]))
# (('__label__sv',), array([0.99442405]))
# (('__label__nl',), array([0.99060053]))
# (('__label__fa',), array([0.98320657]))
# (('__label__tr',), array([0.99695623]))
# (('__label__hu',), array([0.96386212]))
# (('__label__ja',), array([1.00004411]))
# (('__label__el',), array([0.99537438]))
# (('__label__sq',), array([0.99535686]))
# (('__label__sk',), array([0.87850988]))
# (('__label__fi',), array([0.9879601]))
# (('__label__ml',), array([0.99955601]))
# (('__label__ml',), array([0.99931961]))
# (('__label__id',), array([0.86448669]))
# (('__label__ko',), array([1.00006926]))
# (('__label__pt',), array([0.97498894]))
# (('__label__de',), array([0.9947682]))
# (('__label__hr',), array([0.59806436]))
# (('__label__sk',), array([0.8737554]))
# (('__label__lt',), array([0.94410384]))
# (('__label__he',), array([0.9998157]))
# (('__label__es',), array([0.97218412]))
# (('__label__ur',), array([0.91516072]))
# (('__label__it',), array([0.84029061]))
# (('__label__zh',), array([0.99353796]))
# (('__label__en',), array([0.69310373]))
# (('__label__ru',), array([0.99318957]))
# (('__label__zh',), array([0.90128016]))
# (('__label__th',), array([0.99877751]))
# (('__label__zh',), array([0.99980843]))
# (('__label__zh',), array([0.99444783]))
# (('__label__vi',), array([0.99984115]))
# (('__label__sq',), array([0.99028111]))
# (('__label__fa',), array([0.99189019]))
# (('__label__sk',), array([0.87616098]))
# (('__label__tr',), array([0.99029899]))
# (('__label__ar',), array([0.9926424]))
# (('__label__ur',), array([0.95022345]))
# (('__label__lv',), array([0.9859916]))
# (('__label__et',), array([0.90131211]))
# (('__label__ml',), array([0.99943298]))
# (('__label__lv',), array([0.95598435]))
# (('__label__ur',), array([0.88227069]))
# (('__label__mk',), array([0.96653104]))
# (('__label__zh',), array([0.99741173]))
# (('__label__bg',), array([0.88967603]))
# (('__label__th',), array([0.99970287]))
# (('__label__sq',), array([0.97716373]))
# (('__label__th',), array([0.99962109]))
# (('__label__ml',), array([0.99886996]))
# (('__label__sq',), array([0.99395949]))
# (('__label__en',), array([0.99075198]))
# (('__label__nn',), array([0.84144032]))
# (('__label__lv',), array([0.9332422]))
# (('__label__sk',), array([0.81350935]))
# (('__label__ro',), array([0.98126912]))
# (('__label__hr',), array([0.47598061]))
# (('__label__et',), array([0.97814852]))
# (('__label__gu',), array([0.999942]))
# (('__label__it',), array([0.99246669]))
# (('__label__ne',), array([0.13013652]))
# (('__label__gu',), array([0.99904603]))
# (('__label__en',), array([0.58958232]))
# (('__label__gu',), array([0.99991864]))
# (('__label__sv',), array([0.99700916]))
# (('__label__lt',), array([0.9877618]))
# (('__label__bg',), array([0.94807255]))
# (('__label__es',), array([0.92750764]))
# (('__label__he',), array([0.99952543]))
# (('__label__he',), array([0.99990606]))
# (('__label__ru',), array([0.99157935]))
# (('__label__es',), array([0.9503988]))
# (('__label__ru',), array([0.96785712]))
# (('__label__gu',), array([0.9985373]))
# (('__label__no',), array([0.49186525]))
# (('__label__ko',), array([1.00005102]))
# (('__label__de',), array([0.99870181]))
# (('__label__zh',), array([0.99070776]))
# (('__label__it',), array([0.99260038]))
# (('__label__lv',), array([0.95325404]))
# (('__label__ar',), array([0.98407996]))
# (('__label__sk',), array([0.71056193]))
# (('__label__gu',), array([0.99982506]))
# (('__label__pl',), array([0.99019033]))
# (('__label__sr',), array([0.50225133]))
# (('__label__et',), array([0.96244538]))
# (('__label__tr',), array([0.99410236]))
# (('__label__pl',), array([0.9916063]))
# (('__label__sq',), array([0.99565744]))
# (('__label__ru',), array([0.99021232]))
# (('__label__ur',), array([0.85837555]))
# (('__label__fi',), array([0.98400861]))
# (('__label__lb',), array([0.11928254]))
# (('__label__et',), array([0.979559]))
# (('__label__gu',), array([0.99932784]))
# (('__label__ru',), array([0.85054183]))
# (('__label__hu',), array([0.991458]))
# (('__label__ku',), array([0.27579051]))
# (('__label__it',), array([0.99627405]))
# (('__label__pt',), array([0.9727276]))
# (('__label__et',), array([0.98288333]))
# (('__label__zh',), array([0.99911779]))
# (('__label__pt',), array([0.89300781]))
# (('__label__ja',), array([1.00004637]))
# (('__label__te',), array([0.99982882]))
# (('__label__cs',), array([0.97884732]))
# (('__label__id',), array([0.85833883]))
# (('__label__pt',), array([0.98466945]))
# (('__label__ur',), array([0.95929921]))
# (('__label__sq',), array([0.40234563]))
# (('__label__pt',), array([0.99281943]))
# (('__label__lv',), array([0.96800381]))
# (('__label__tl',), array([0.08597339]))
# (('__label__hi',), array([0.97673839]))
# (('__label__et',), array([0.96680003]))
# (('__label__uk',), array([0.98917675]))
# (('__label__hi',), array([0.99369293]))
# (('__label__vi',), array([0.99980915]))
# (('__label__ko',), array([1.00006926]))
# (('__label__cs',), array([0.95012361]))
# (('__label__hi',), array([0.97978902]))
# (('__label__ru',), array([0.96499908]))
# (('__label__zh',), array([0.99964994]))
# (('__label__cs',), array([0.88734782]))
# (('__label__th',), array([0.99903148]))
# (('__label__hr',), array([0.62352473]))
# (('__label__sv',), array([0.99944389]))
# (('__label__he',), array([0.99990797]))
# (('__label__de',), array([0.99262017]))
# (('__label__hi',), array([0.9861505]))
# (('__label__hr',), array([0.534015]))
# (('__label__te',), array([0.99995983]))
# (('__label__pl',), array([0.99682736]))
# (('__label__bg',), array([0.91112959]))
# (('__label__ja',), array([1.00004673]))
# (('__label__es',), array([0.93295878]))
# (('__label__fi',), array([0.9933396]))
# (('__label__hi',), array([0.98835486]))
# (('__label__ru',), array([0.9898783]))
# (('__label__ro',), array([0.98910767]))
# (('__label__fi',), array([0.99138719]))
# (('__label__tr',), array([0.99141824]))
# (('__label__fi',), array([0.96504742]))
# (('__label__hu',), array([0.99624491]))
# (('__label__zh',), array([0.98390597]))
# (('__label__ja',), array([1.00000262]))
# (('__label__mk',), array([0.95298105]))
# (('__label__th',), array([0.99986064]))
# (('__label__sk',), array([0.86497062]))
# (('__label__hr',), array([0.59436351]))
# (('__label__et',), array([0.96071064]))
# (('__label__id',), array([0.81971383]))
# (('__label__fa',), array([0.98929894]))
# (('__label__fi',), array([0.96612459]))
# (('__label__en',), array([0.93436182]))
# (('__label__ml',), array([0.99961931]))
# (('__label__es',), array([0.98170072]))
# (('__label__fa',), array([0.98679703]))
# (('__label__ur',), array([0.94848174]))
# (('__label__zh',), array([0.98199338]))
# (('__label__lt',), array([0.99063265]))
# (('__label__tl',), array([0.95402074]))
# (('__label__da',), array([0.92701399]))
# (('__label__zh',), array([0.99194145]))
# (('__label__it',), array([0.99508095]))
# (('__label__el',), array([0.99518949]))
# (('__label__bg',), array([0.93081534]))
# (('__label__bn',), array([0.9953087]))
# (('__label__pl',), array([0.99823725]))
# (('__label__zh',), array([0.98121053]))
# (('__label__ku',), array([0.1163061]))
# (('__label__ht',), array([0.17413078]))
# (('__label__fi',), array([0.98172277]))
# (('__label__ta',), array([0.99994147]))
# (('__label__tl',), array([0.95441675]))
# (('__label__bn',), array([0.9936496]))
# (('__label__he',), array([0.99941027]))
# (('__label__fa',), array([0.9885875]))
# (('__label__lv',), array([0.92564797]))
# (('__label__fr',), array([0.99877906]))
# (('__label__ru',), array([0.98145336]))
# (('__label__ko',), array([1.00006628]))
# (('__label__uk',), array([0.99775541]))
# (('__label__ar',), array([0.99205393]))
# (('__label__cs',), array([0.97821337]))
# (('__label__zh',), array([0.9997161]))
# (('__label__mk',), array([0.97476631]))
# (('__label__tr',), array([0.98479104]))
# (('__label__fr',), array([0.84551346]))
# (('__label__sq',), array([0.99128205]))
# (('__label__nn',), array([0.58420217]))
# (('__label__he',), array([0.9997384]))
# (('__label__sq',), array([0.99786222]))
# (('__label__da',), array([0.62362719]))
# (('__label__bg',), array([0.86897308]))
# (('__label__fr',), array([0.991458]))
# (('__label__sv',), array([0.99913698]))
# (('__label__pt',), array([0.590114]))
# (('__label__ml',), array([0.99946874]))
# (('__label__fa',), array([0.98483282]))
# (('__label__sv',), array([0.99787319]))
# (('__label__pl',), array([0.99549741]))
# (('__label__da',), array([0.94647157]))
# (('__label__tr',), array([0.92157036]))
# (('__label__zh',), array([0.94384891]))
# (('__label__el',), array([0.99644053]))
# (('__label__fa',), array([0.64135307]))
# (('__label__en',), array([0.94803935]))
# (('__label__ja',), array([1.00004148]))
# (('__label__tr',), array([0.99217117]))
# (('__label__zh',), array([0.99782711]))
# (('__label__ur',), array([0.72394317]))
# (('__label__de',), array([0.99441111]))
# (('__label__hr',), array([0.37256056]))
# (('__label__zh',), array([0.9712348]))
# (('__label__fa',), array([0.99054509]))
# (('__label__pl',), array([0.99461371]))
# (('__label__lt',), array([0.99300838]))
# (('__label__ru',), array([0.99577177]))
# (('__label__hu',), array([0.96247405]))
# (('__label__vi',), array([0.99861526]))
# (('__label__da',), array([0.7829591]))
# (('__label__pt',), array([0.97814745]))
# (('__label__zh',), array([0.82116783]))
# (('__label__sk',), array([0.8214221]))
# (('__label__fi',), array([0.98799896]))
# (('__label__de',), array([0.986983]))
# (('__label__ar',), array([0.99346358]))
# (('__label__da',), array([0.84131402]))
# (('__label__ro',), array([0.96453625]))
# (('__label__ja',), array([0.99866813]))
# (('__label__lv',), array([0.90488166]))
# (('__label__gu',), array([0.99990475]))
# (('__label__hu',), array([0.98848414]))
# (('__label__zh',), array([0.98436201]))
# (('__label__it',), array([0.98165065]))
# (('__label__fi',), array([0.99028432]))
# (('__label__lt',), array([0.98701972]))
# (('__label__de',), array([0.99271387]))
# (('__label__no',), array([0.85959476]))
# (('__label__pl',), array([0.97689962]))
# (('__label__bn',), array([0.99694294]))
# (('__label__nn',), array([0.92641532]))
# (('__label__mk',), array([0.95073462]))
# (('__label__sv',), array([0.99811429]))
# (('__label__ro',), array([0.99724042]))
# (('__label__pl',), array([0.99655694]))
# (('__label__mk',), array([0.94040537]))
# (('__label__zh',), array([0.98969543]))
# (('__label__no',), array([0.4673993]))
# (('__label__lv',), array([0.95937937]))
# (('__label__id',), array([0.61943513]))
# (('__label__fa',), array([0.9831602]))
# (('__label__lt',), array([0.98975247]))
# (('__label__et',), array([0.90818906]))
# (('__label__it',), array([0.99803299]))
# (('__label__hu',), array([0.98992401]))
# (('__label__hr',), array([0.51330966]))
# (('__label__tl',), array([0.76516622]))
# (('__label__ru',), array([0.98808587]))
# (('__label__zh',), array([0.90430886]))
# (('__label__fi',), array([0.96009386]))
# (('__label__hu',), array([0.87917912]))
# (('__label__cs',), array([0.93932062]))
# (('__label__zh',), array([0.99987787]))
# (('__label__nl',), array([0.99681103]))
# (('__label__nl',), array([0.95134473]))
# (('__label__da',), array([0.6248346]))
# (('__label__nn',), array([0.80542988]))
# (('__label__pt',), array([0.98995662]))
# (('__label__te',), array([0.99991262]))
# (('__label__pt',), array([0.96005225]))
# (('__label__wa',), array([0.1869196]))
# (('__label__ur',), array([0.90684938]))
# (('__label__mk',), array([0.87757033]))
# (('__label__cs',), array([0.98192763]))
# (('__label__fr',), array([0.93514162]))
# (('__label__ru',), array([0.67029238]))
# (('__label__bg',), array([0.96734029]))
# (('__label__lt',), array([0.95988995]))
# (('__label__ur',), array([0.84177727]))
# (('__label__lv',), array([0.93313599]))
# (('__label__nn',), array([0.8079316]))
# (('__label__fi',), array([0.99274957]))
# (('__label__te',), array([1.0000155]))
# (('__label__te',), array([0.99994808]))
# (('__label__nl',), array([0.98678738]))
# (('__label__fi',), array([0.94866723]))
# (('__label__en',), array([0.98798633]))
# (('__label__hu',), array([0.99434417]))
# (('__label__he',), array([0.99909776]))
# (('__label__ja',), array([1.00003612]))
# (('__label__el',), array([0.99728543]))
# (('__label__de',), array([0.93284971]))
# (('__label__cs',), array([0.99334759]))
# (('__label__fa',), array([0.98260379]))
# (('__label__he',), array([0.99981326]))
# (('__label__bn',), array([0.99321425]))
# (('__label__da',), array([0.86915261]))
# (('__label__lv',), array([0.96649593]))
# (('__label__ur',), array([0.9736439]))
# (('__label__pt',), array([0.94420046]))
# (('__label__en',), array([0.99319762]))
# (('__label__nn',), array([0.59597713]))
# (('__label__te',), array([0.9998309]))
# (('__label__nn',), array([0.63251555]))
# (('__label__he',), array([0.99976939]))
# (('__label__hi',), array([0.97702652]))
# (('__label__el',), array([0.99611098]))
# (('__label__te',), array([1.00000751]))
# (('__label__sh',), array([0.42742649]))
# (('__label__es',), array([0.96619999]))
# (('__label__zh',), array([0.99853551]))
# (('__label__fr',), array([0.9923988]))
# (('__label__mk',), array([0.90397269]))
# (('__label__pl',), array([0.98872685]))
# (('__label__zh',), array([0.96897143]))
# (('__label__uk',), array([0.9907077]))
# (('__label__ar',), array([0.87380189]))
# (('__label__cs',), array([0.95664936]))
# (('__label__vi',), array([0.99710196]))
# (('__label__lt',), array([0.98689383]))
# (('__label__el',), array([0.99727356]))
# (('__label__mk',), array([0.89661419]))
# (('__label__zh',), array([0.99977279]))
# (('__label__cs',), array([0.96380514]))
# (('__label__el',), array([0.99782431]))
# (('__label__id',), array([0.56645226]))
# (('__label__en',), array([0.98603231]))
# (('__label__ta',), array([0.99977785]))
# (('__label__zh',), array([0.99152309]))
# (('__label__gu',), array([0.99964184]))
# (('__label__sv',), array([0.99945939]))
# (('__label__th',), array([0.99931991]))
# (('__label__hr',), array([0.54055929]))
# (('__label__sq',), array([0.99627048]))
# (('__label__en',), array([0.98763496]))
# (('__label__te',), array([0.99996156]))
# (('__label__mk',), array([0.93056029]))
# (('__label__pl',), array([0.99378324]))
# (('__label__ja',), array([1.0000484]))
# (('__label__fi',), array([0.94896924]))
# (('__label__sq',), array([0.9865154]))
# (('__label__tr',), array([0.99348247]))
# (('__label__da',), array([0.89681262]))
# (('__label__lt',), array([0.98655176]))
# (('__label__bn',), array([0.98725879]))
# (('__label__sk',), array([0.63956779]))
# (('__label__ko',), array([1.00006986]))
# (('__label__ro',), array([0.99446219]))
# (('__label__nl',), array([0.97954822]))
# (('__label__nl',), array([0.99018979]))
# (('__label__bg',), array([0.85162723]))
# (('__label__te',), array([0.9998669]))
# (('__label__nn',), array([0.95094532]))
# (('__label__es',), array([0.95838654]))
# (('__label__te',), array([0.99993187]))
# (('__label__ro',), array([0.99823624]))
# (('__label__nn',), array([0.9620496]))
# (('__label__lt',), array([0.98024535]))
# (('__label__ko',), array([1.00006449]))
# (('__label__vi',), array([0.99843252]))
# (('__label__hr',), array([0.48520082]))
# (('__label__hr',), array([0.27485654]))
# (('__label__pl',), array([0.99508619]))
# (('__label__zh',), array([0.98490256]))
# (('__label__hu',), array([0.98729086]))
# (('__label__vi',), array([0.99612832]))
# (('__label__sq',), array([0.99540919]))
# (('__label__te',), array([0.999919]))
# (('__label__he',), array([0.99976486]))
# (('__label__bg',), array([0.94303042]))
# (('__label__zh',), array([1.0000025]))
# (('__label__en',), array([0.29374936]))
# (('__label__mk',), array([0.94640851]))
# (('__label__mk',), array([0.96613741]))
# (('__label__cs',), array([0.98772961]))
# (('__label__tr',), array([0.95945233]))
# (('__label__te',), array([0.99976242]))
# (('__label__ur',), array([0.9592886]))
# (('__label__da',), array([0.81864291]))
# (('__label__ml',), array([0.99941015]))
# (('__label__es',), array([0.85436219]))
# (('__label__hr',), array([0.31627944]))
# (('__label__mk',), array([0.96446252]))
# (('__label__uk',), array([0.99349648]))
# (('__label__en',), array([0.96694946]))
# (('__label__pt',), array([0.97350413]))
# (('__label__ro',), array([0.99690413]))
# (('__label__hu',), array([0.98176181]))
# (('__label__tr',), array([0.94716221]))
# (('__label__es',), array([0.79536319]))
# (('__label__id',), array([0.84060407]))
# (('__label__sq',), array([0.67101645]))
# (('__label__cs',), array([0.99318218]))
# (('__label__sv',), array([0.99274981]))
# (('__label__de',), array([0.99471742]))
# (('__label__ja',), array([1.0000484]))
# (('__label__th',), array([0.99930698]))
# (('__label__nl',), array([0.9965843]))
# (('__label__ja',), array([1.00003636]))
# (('__label__it',), array([0.98669237]))
# (('__label__sv',), array([0.95480531]))
# (('__label__uk',), array([0.99641412]))
# (('__label__et',), array([0.9783209]))
# (('__label__ar',), array([0.99540967]))
# (('__label__ku',), array([0.11135536]))
# (('__label__tr',), array([0.99084073]))
# (('__label__sv',), array([0.9917962]))
# (('__label__sv',), array([0.98333502]))
# (('__label__it',), array([0.98187441]))
# (('__label__sk',), array([0.71369523]))
# (('__label__tl',), array([0.19327115]))
# (('__label__tl',), array([0.71620703]))
# (('__label__cs',), array([0.97404701]))
# (('__label__ml',), array([0.99949592]))
# (('__label__ru',), array([0.98933423]))
# (('__label__zh',), array([0.81298608]))
# (('__label__hi',), array([0.99390674]))
# (('__label__id',), array([0.78797406]))
# (('__label__fr',), array([0.98800796]))
# (('__label__en',), array([0.42819276]))
# (('__label__fi',), array([0.99265951]))
# (('__label__tl',), array([0.91636646]))
# (('__label__zh',), array([0.99923652]))
# (('__label__gu',), array([0.99939996]))
# (('__label__bn',), array([0.94344753]))
# (('__label__ko',), array([1.00006855]))
# (('__label__it',), array([0.9944033]))
# (('__label__it',), array([0.97691602]))
# (('__label__ru',), array([0.98403031]))
# (('__label__vi',), array([0.9997434]))
# (('__label__zh',), array([0.99929982]))
# (('__label__th',), array([0.99976844]))
# (('__label__lv',), array([0.95973408]))
# (('__label__ur',), array([0.98852164]))
# (('__label__et',), array([0.9952231]))
# (('__label__ar',), array([0.9893499]))
# (('__label__fa',), array([0.97048992]))
# (('__label__fr',), array([0.98780721]))
# (('__label__fa',), array([0.98321623]))
# (('__label__pl',), array([0.97448653]))
# (('__label__en',), array([0.95799893]))
# (('__label__pt',), array([0.45386404]))
# (('__label__pl',), array([0.99829394]))
# (('__label__te',), array([0.99992305]))
# (('__label__te',), array([0.99091846]))
# (('__label__hr',), array([0.65419602]))
# (('__label__ko',), array([1.00006258]))
# (('__label__zh',), array([0.99841911]))
# (('__label__gu',), array([0.99943656]))
# (('__label__sq',), array([0.98662591]))
# (('__label__id',), array([0.84926152]))
# (('__label__lt',), array([0.96258307]))
# (('__label__pt',), array([0.98355258]))
# (('__label__hr',), array([0.42627072]))
# (('__label__da',), array([0.95557946]))
# (('__label__zh',), array([0.99999601]))
# (('__label__he',), array([0.99995995]))
# (('__label__ro',), array([0.9962424]))
# (('__label__lt',), array([0.99791628]))
# (('__label__nl',), array([0.978499]))
# (('__label__ml',), array([0.9995966]))
# (('__label__de',), array([0.99831676]))
# (('__label__sv',), array([0.99791008]))
# (('__label__pl',), array([0.98447299]))
# (('__label__te',), array([0.99991429]))
# (('__label__et',), array([0.89308196]))
# (('__label__zh',), array([0.7872414]))
# (('__label__ml',), array([0.99946553]))
# (('__label__ja',), array([0.99985605]))
# (('__label__ku',), array([0.12390146]))
# (('__label__id',), array([0.96636909]))
# (('__label__fa',), array([0.99382895]))
# (('__label__hr',), array([0.71888012]))
# (('__label__vi',), array([0.9989416]))
# (('__label__te',), array([0.99972016]))
# (('__label__tl',), array([0.91474897]))
# (('__label__ko',), array([1.00006962]))
# (('__label__sk',), array([0.97627044]))
# (('__label__ro',), array([0.997657]))
# (('__label__ja',), array([1.00004447]))
# (('__label__fr',), array([0.99098998]))
# (('__label__hi',), array([0.99013013]))
# (('__label__ru',), array([0.98494571]))
# (('__label__vi',), array([0.99931258]))
# (('__label__fa',), array([0.9940697]))
# (('__label__tr',), array([0.99429625]))
# (('__label__tl',), array([0.89248502]))
# (('__label__hu',), array([0.94448692]))
# (('__label__lb',), array([0.06001066]))
# (('__label__ru',), array([0.95135009]))
# (('__label__gu',), array([0.99907899]))
# (('__label__fr',), array([0.98926502]))
# (('__label__zh',), array([0.99985284]))
# (('__label__gu',), array([0.99914581]))
# (('__label__it',), array([0.95433259]))
# (('__label__cs',), array([0.98147017]))
# (('__label__ko',), array([1.00006926]))
# (('__label__zh',), array([0.99711359]))
# (('__label__mk',), array([0.92094123]))
# (('__label__pl',), array([0.99649513]))
# (('__label__hi',), array([0.98846763]))
# (('__label__ar',), array([0.9766205]))
# (('__label__ru',), array([0.97775549]))
# (('__label__bg',), array([0.95001274]))
# (('__label__bg',), array([0.87585616]))
# (('__label__tr',), array([0.99239266]))
# (('__label__fi',), array([0.98970973]))
# (('__label__ko',), array([1.00006962]))
# (('__label__lt',), array([0.97578841]))
# (('__label__zh',), array([0.99017346]))
# (('__label__gu',), array([0.99953711]))
# (('__label__fi',), array([0.97811586]))
# (('__label__id',), array([0.88980323]))
# (('__label__ar',), array([0.99392742]))
# (('__label__he',), array([0.99937487]))
# (('__label__ht',), array([0.13978012]))
# (('__label__en',), array([0.46548799]))
# (('__label__gu',), array([0.99942297]))
# (('__label__lt',), array([0.9746545]))
# (('__label__zh',), array([0.99958324]))
# (('__label__bg',), array([0.97790104]))
# (('__label__bn',), array([0.99537325]))
# (('__label__hi',), array([0.98178667]))
# (('__label__pt',), array([0.9496451]))
# (('__label__tl',), array([0.88722408]))
# (('__label__ru',), array([0.98943913]))
# (('__label__pl',), array([0.99554574]))
# (('__label__it',), array([0.99415272]))
# (('__label__th',), array([0.99990481]))
# (('__label__nl',), array([0.98903865]))
# (('__label__ta',), array([0.9994486]))
# (('__label__el',), array([0.99713498]))
# (('__label__zh',), array([0.99893481]))
# (('__label__cs',), array([0.93697238]))
# (('__label__sq',), array([0.99646688]))
# (('__label__tr',), array([0.8895545]))
# (('__label__nn',), array([0.50095063]))
# (('__label__th',), array([0.99947429]))
# (('__label__pt',), array([0.9621585]))
# (('__label__fa',), array([0.98557663]))
# (('__label__zh',), array([0.94182962]))
# (('__label__he',), array([0.99910533]))
# (('__label__ro',), array([0.96910948]))
# (('__label__cs',), array([0.98968804]))
# (('__label__bg',), array([0.94413233]))
# (('__label__fa',), array([0.98782873]))
# (('__label__hi',), array([0.95872062]))
# (('__label__es',), array([0.97977722]))
# (('__label__sq',), array([0.96977013]))
# (('__label__te',), array([0.99967945]))
# (('__label__bg',), array([0.88458478]))
# (('__label__zh',), array([0.55187869]))
# (('__label__ta',), array([0.99982798]))
# (('__label__vi',), array([0.9981637]))
# (('__label__zh',), array([0.9954896]))
# (('__label__zh',), array([0.73795968]))
# (('__label__cs',), array([0.97814661]))
# (('__label__fa',), array([0.98945522]))
# (('__label__tl',), array([0.92131835]))
# (('__label__pt',), array([0.95397067]))
# (('__label__es',), array([0.97139215]))
# (('__label__zh',), array([0.99990386]))
# (('__label__gu',), array([0.99921763]))
# (('__label__nl',), array([0.96566671]))
# (('__label__en',), array([0.98569655]))
# (('__label__vi',), array([0.9991461]))
# (('__label__pt',), array([0.9230634]))
# (('__label__ml',), array([0.99871862]))
# (('__label__fi',), array([0.98870605]))
# (('__label__sk',), array([0.83959216]))
# (('__label__zh',), array([0.74941361]))
# (('__label__zh',), array([0.9965139]))
# (('__label__fi',), array([0.94262725]))
# (('__label__nn',), array([0.6663366]))
# (('__label__uk',), array([0.99683899]))
# (('__label__ar',), array([0.99096078]))
# (('__label__nn',), array([0.80313736]))
# (('__label__tr',), array([0.99355596]))
# (('__label__hr',), array([0.64341301]))
# (('__label__es',), array([0.95984453]))
# (('__label__da',), array([0.66305411]))
# (('__label__hu',), array([0.98944145]))
# (('__label__da',), array([0.85494554]))
# (('__label__ja',), array([0.99994272]))
# (('__label__ml',), array([0.99952453]))
# (('__label__it',), array([0.99065638]))
# (('__label__lv',), array([0.94196367]))
# (('__label__te',), array([0.99998569]))
# (('__label__ml',), array([0.99890131]))
# (('__label__ku',), array([0.16750704]))
# (('__label__uk',), array([0.99495202]))
# (('__label__ko',), array([1.00006092]))
# (('__label__it',), array([0.99211645]))
# (('__label__zh',), array([0.99856287]))
# (('__label__gu',), array([0.99988395]))
# (('__label__fi',), array([0.99766833]))
# (('__label__el',), array([0.99883538]))
# (('__label__ml',), array([0.99946201]))
# (('__label__tl',), array([0.91287738]))
# (('__label__fi',), array([0.98749936]))
# (('__label__ku',), array([0.14813119]))
# (('__label__sh',), array([0.32309535]))
# (('__label__pl',), array([0.99440211]))
# (('__label__sq',), array([0.99495476]))
# (('__label__bg',), array([0.98803383]))
# (('__label__gu',), array([0.99982607]))
# (('__label__te',), array([0.99984974]))
# (('__label__zh',), array([0.99967468]))
# (('__label__zh',), array([0.98992455]))
# (('__label__ku',), array([0.23101491]))
# (('__label__hu',), array([0.72168159]))
# (('__label__zh',), array([0.98912901]))
# (('__label__bg',), array([0.93422037]))
# (('__label__et',), array([0.89397258]))
# (('__label__sk',), array([0.45772815]))
# (('__label__ru',), array([0.98636436]))
# (('__label__el',), array([0.99691898]))
# (('__label__zh',), array([0.99806988]))
# (('__label__zh',), array([0.99394321]))
# (('__label__bn',), array([0.98854059]))
# (('__label__bg',), array([0.94475824]))
# (('__label__en',), array([0.97765034]))
# (('__label__gu',), array([0.99983114]))
# (('__label__ta',), array([0.9996506]))
# (('__label__nn',), array([0.91709161]))
# (('__label__es',), array([0.93030709]))
# (('__label__lv',), array([0.98997784]))
# (('__label__zh',), array([0.99719888]))
# (('__label__en',), array([0.96836269]))
# (('__label__cs',), array([0.97819674]))
# (('__label__sv',), array([0.99431884]))
# (('__label__te',), array([0.9998619]))
# (('__label__hr',), array([0.57616466]))
# (('__label__he',), array([0.99974728]))
# (('__label__ja',), array([1.00003338]))
# (('__label__he',), array([0.99986601]))
# (('__label__ml',), array([0.99896049]))
# (('__label__he',), array([0.99931931]))
# (('__label__sh',), array([0.28238094]))
# (('__label__lv',), array([0.89975691]))
# (('__label__ml',), array([0.9979775]))
# (('__label__ko',), array([1.00006974]))
# (('__label__pl',), array([0.97552341]))
# (('__label__es',), array([0.96717405]))
# (('__label__et',), array([0.90080172]))
# (('__label__te',), array([0.99991304]))
# (('__label__cs',), array([0.98508286]))
# (('__label__vi',), array([0.99212408]))
# (('__label__te',), array([0.99997199]))
# (('__label__tr',), array([0.98773777]))
# (('__label__ru',), array([0.99089456]))
# (('__label__te',), array([0.99967736]))
# (('__label__sq',), array([0.97272187]))
# (('__label__tl',), array([0.90246361]))
# (('__label__fi',), array([0.78312355]))
# (('__label__ko',), array([1.00006974]))
# (('__label__lv',), array([0.97204608]))
# (('__label__zh',), array([0.98912543]))
# (('__label__sq',), array([0.99872041]))
# (('__label__sq',), array([0.98548412]))
# (('__label__mk',), array([0.98184144]))
# (('__label__he',), array([0.9998433]))
# (('__label__te',), array([0.99971944]))
# (('__label__et',), array([0.92077374]))
# (('__label__ur',), array([0.95567328]))
# (('__label__zh',), array([0.99630058]))
# (('__label__pt',), array([0.96871638]))
# (('__label__hr',), array([0.42490235]))
# (('__label__uk',), array([0.99361992]))
# (('__label__fr',), array([0.99378353]))
# (('__label__sv',), array([0.99720848]))
# (('__label__ru',), array([0.99190146]))
# (('__label__mk',), array([0.97010285]))
# (('__label__ro',), array([0.99846214]))
# (('__label__nl',), array([0.98994857]))
# (('__label__el',), array([0.99804109]))
# (('__label__ja',), array([1.0000478]))
# (('__label__diq',), array([0.10920455]))
# (('__label__hi',), array([0.98988175]))
# (('__label__nl',), array([0.99673897]))
# (('__label__pt',), array([0.95656663]))
# (('__label__cs',), array([0.51236844]))
# (('__label__el',), array([0.99724239]))
# (('__label__zh',), array([0.98674965]))
# (('__label__de',), array([0.9952361]))
# (('__label__ku',), array([0.41094393]))
# ...
# (('__label__ja',), array([1.00004244]))
# (('__label__bg',), array([0.95691371]))
# (('__label__nn',), array([0.80722308]))
# (('__label__pt',), array([0.98530424]))
# (('__label__en',), array([0.9915626]))
# (('__label__lb',), array([0.19539991]))
# (('__label__pt',), array([0.96641666]))
# (('__label__pt',), array([0.95441306]))
# (('__label__bn',), array([0.99825186]))
# (('__label__tr',), array([0.96606874]))
# (('__label__mk',), array([0.90783602]))
# (('__label__ru',), array([0.98772085]))
# (('__label__sq',), array([0.99516636]))
# (('__label__zh',), array([0.99954838]))
# (('__label__en',), array([0.98866683]))
# (('__label__gu',), array([0.9995873]))
# (('__label__fi',), array([0.97216547]))
# (('__label__hr',), array([0.49286324]))
# (('__label__it',), array([0.99450099]))
# (('__label__zh',), array([0.85710669]))
# (('__label__zh',), array([0.99969953]))
# (('__label__el',), array([0.9962157]))
# (('__label__hi',), array([0.99178892]))
# (('__label__bn',), array([0.99402517]))
# (('__label__uk',), array([0.99194473]))
# (('__label__fa',), array([0.98764086]))
# (('__label__ko',), array([1.00006962]))
# (('__label__sq',), array([0.97940737]))
# (('__label__it',), array([0.99081969]))
# (('__label__uk',), array([0.99046785]))
# (('__label__et',), array([0.86221009]))
# (('__label__pl',), array([0.99527425]))
# (('__label__sq',), array([0.99330926]))
# (('__label__mk',), array([0.96174675]))
# (('__label__he',), array([0.99930394]))
# (('__label__el',), array([0.99705797]))
# (('__label__zh',), array([0.99324137]))
# (('__label__vi',), array([0.20963305]))
# (('__label__zh',), array([0.99925148]))
# (('__label__fa',), array([0.98791611]))
# (('__label__en',), array([0.85530877]))
# (('__label__bn',), array([0.99631149]))
# (('__label__da',), array([0.93529958]))
# (('__label__ar',), array([0.98598218]))
# (('__label__sq',), array([0.99348712]))
# (('__label__zh',), array([0.99773651]))
# (('__label__fi',), array([0.92996514]))
# (('__label__ro',), array([0.93205607]))
# (('__label__el',), array([0.99444783]))
# (('__label__sq',), array([0.89973462]))
# (('__label__hu',), array([0.98930025]))
# (('__label__nl',), array([0.90191585]))
# (('__label__da',), array([0.53041005]))
# (('__label__sv',), array([0.98070025]))
# (('__label__tr',), array([0.98688114]))
# (('__label__pl',), array([0.64260608]))
# (('__label__da',), array([0.92272055]))
# (('__label__sv',), array([0.9995656]))
# (('__label__th',), array([0.99948651]))
# (('__label__es',), array([0.98155606]))
# (('__label__cs',), array([0.98616236]))
# (('__label__gu',), array([0.9999342]))
# (('__label__bn',), array([0.98766136]))
# (('__label__sv',), array([0.99953371]))
# (('__label__pt',), array([0.9760133]))
# (('__label__tr',), array([0.96992916]))
# (('__label__bn',), array([0.99299318]))
# (('__label__it',), array([0.99126107]))
# (('__label__fa',), array([0.97867584]))
# (('__label__sq',), array([0.97069991]))
# (('__label__uk',), array([0.9809891]))
# (('__label__cs',), array([0.98688477]))
# (('__label__nl',), array([0.98011512]))
# (('__label__te',), array([0.99953306]))
# (('__label__he',), array([0.99978203]))
# (('__label__gu',), array([0.99946249]))
# (('__label__mk',), array([0.94485778]))
# (('__label__ml',), array([0.99927872]))
# (('__label__zh',), array([0.88197547]))
# (('__label__uk',), array([0.9896937]))
# (('__label__ur',), array([0.86950946]))
# (('__label__he',), array([0.99964976]))
# (('__label__pl',), array([0.98712099]))
# (('__label__pt',), array([0.98489887]))
# (('__label__mk',), array([0.91580802]))
# (('__label__el',), array([0.9971652]))
# (('__label__ro',), array([0.99382597]))
# (('__label__zh',), array([0.96785653]))
# (('__label__ar',), array([0.65417928]))
# (('__label__cs',), array([0.97716504]))
# (('__label__id',), array([0.76865178]))
# (('__label__da',), array([0.89863205]))
# (('__label__ru',), array([0.98818094]))
# (('__label__th',), array([0.99911678]))
# (('__label__ja',), array([1.0000478]))
# (('__label__ja',), array([1.00004792]))
# (('__label__ru',), array([0.88312209]))
# (('__label__ar',), array([0.99135655]))
# (('__label__nl',), array([0.99734694]))
# (('__label__id',), array([0.8377865]))
# (('__label__fr',), array([0.99774146]))
# (('__label__lv',), array([0.98001856]))
# (('__label__fa',), array([0.99271035]))
# (('__label__ja',), array([1.0000484]))
# (('__label__ta',), array([0.99985445]))
# (('__label__hu',), array([0.9797045]))
# (('__label__sq',), array([0.99217087]))
# (('__label__zh',), array([0.98383313]))
# (('__label__ur',), array([0.76379609]))
# (('__label__th',), array([0.99969542]))
# (('__label__zh',), array([0.99980539]))
# (('__label__pl',), array([0.99873072]))
# (('__label__ar',), array([0.98055005]))
# (('__label__ar',), array([0.98555833]))
# (('__label__sk',), array([0.70992696]))
# (('__label__hu',), array([0.97947055]))
# (('__label__sk',), array([0.88089681]))
# (('__label__en',), array([0.9618066]))
# (('__label__nl',), array([0.99756092]))
# (('__label__mk',), array([0.97028679]))
# (('__label__th',), array([0.99969578]))
# (('__label__pl',), array([0.99333698]))
# (('__label__lt',), array([0.89032966]))
# (('__label__zh',), array([0.99866331]))
# (('__label__lt',), array([0.83271837]))
# (('__label__mk',), array([0.8382796]))
# (('__label__zh',), array([0.88822144]))
# (('__label__ur',), array([0.90030164]))
# (('__label__et',), array([0.66628486]))
# (('__label__pl',), array([0.9804647]))
# (('__label__ar',), array([0.99159855]))
# (('__label__vi',), array([0.99922127]))
# (('__label__el',), array([0.99708277]))
# (('__label__fi',), array([0.98228216]))
# (('__label__ur',), array([0.97450948]))
# (('__label__fi',), array([0.98569858]))
# (('__label__hu',), array([0.98261756]))
# (('__label__nn',), array([0.58071625]))
# (('__label__sk',), array([0.75432271]))
# (('__label__da',), array([0.95367181]))
# (('__label__ml',), array([0.99621087]))
# (('__label__ru',), array([0.95813549]))
# (('__label__el',), array([0.99816692]))
# (('__label__ta',), array([0.99956751]))
# (('__label__en',), array([0.98492092]))
# (('__label__en',), array([0.97623897]))
# (('__label__vi',), array([0.99667752]))
# (('__label__zh',), array([0.99955302]))
# (('__label__hr',), array([0.53954101]))
# (('__label__ru',), array([0.97425634]))
# (('__label__es',), array([0.967125]))
# (('__label__lv',), array([0.92409003]))
# (('__label__id',), array([0.30987576]))
# (('__label__lt',), array([0.74921727]))
# (('__label__pl',), array([0.99311548]))
# (('__label__es',), array([0.99326408]))
# (('__label__he',), array([0.99985009]))
# (('__label__lv',), array([0.96149224]))
# (('__label__es',), array([0.83454645]))
# (('__label__vi',), array([0.99629968]))
# (('__label__bn',), array([0.98967785]))
# (('__label__hu',), array([0.99268395]))
# (('__label__bg',), array([0.92026711]))
# (('__label__ml',), array([0.99868417]))
# (('__label__es',), array([0.96136415]))
# (('__label__tl',), array([0.91114992]))
# (('__label__nl',), array([0.99432933]))
# (('__label__fa',), array([0.99376839]))
# (('__label__en',), array([0.96956825]))
# (('__label__ro',), array([0.99889976]))
# (('__label__he',), array([0.99968851]))
# (('__label__sv',), array([0.9994536]))
# (('__label__mk',), array([0.95847654]))
# (('__label__pt',), array([0.94809818]))
# (('__label__ja',), array([1.00000322]))
# (('__label__et',), array([0.79015791]))
# (('__label__el',), array([0.99762732]))
# (('__label__ta',), array([0.9996084]))
# (('__label__zh',), array([0.99555874]))
# (('__label__ur',), array([0.9204514]))
# (('__label__ur',), array([0.95260918]))
# (('__label__bn',), array([0.99389786]))
# (('__label__de',), array([0.98961222]))
# (('__label__bn',), array([0.99241197]))
# (('__label__ko',), array([1.00006723]))
# (('__label__de',), array([0.99652928]))
# (('__label__el',), array([0.99748635]))
# (('__label__mk',), array([0.97599411]))
# (('__label__lv',), array([0.91439182]))
# (('__label__no',), array([0.44552937]))
# (('__label__tr',), array([0.97546774]))
# (('__label__sv',), array([0.99932301]))
# (('__label__es',), array([0.97348797]))
# (('__label__fr',), array([0.99447572]))
# (('__label__sv',), array([0.99460524]))
# (('__label__tl',), array([0.92039895]))
# (('__label__es',), array([0.97610044]))
# (('__label__he',), array([0.99956071]))
# (('__label__es',), array([0.98827654]))
# (('__label__lt',), array([0.9962588]))
# (('__label__hr',), array([0.38710025]))
# (('__label__he',), array([0.99951625]))
# (('__label__ja',), array([1.00003874]))
# (('__label__id',), array([0.76290673]))
# (('__label__zh',), array([0.34467232]))
# (('__label__da',), array([0.92086405]))
# (('__label__ko',), array([1.00006914]))
# (('__label__he',), array([0.99980652]))
# (('__label__fi',), array([0.97244692]))
# (('__label__zh',), array([0.99972957]))
# (('__label__hr',), array([0.40787053]))
# (('__label__de',), array([0.99451691]))
# (('__label__fa',), array([0.99441403]))
# (('__label__nn',), array([0.51295823]))
# (('__label__sv',), array([0.99540371]))
# (('__label__ja',), array([1.00004876]))
# (('__label__hi',), array([0.98756289]))
# (('__label__vi',), array([0.99274266]))
# (('__label__ur',), array([0.96428543]))
# (('__label__et',), array([0.77579993]))
# (('__label__te',), array([0.99987078]))
# (('__label__th',), array([0.99869084]))
# (('__label__ro',), array([0.99866891]))
# (('__label__zh',), array([0.98479539]))
# (('__label__fr',), array([0.70161927]))
# (('__label__hr',), array([0.44945687]))
# (('__label__hu',), array([0.98871428]))
# (('__label__de',), array([0.96867299]))
# (('__label__pt',), array([0.96369588]))
# (('__label__ru',), array([0.98492575]))
# (('__label__th',), array([0.99906045]))
# (('__label__el',), array([0.99747854]))
# (('__label__zh',), array([0.98878211]))
# (('__label__fr',), array([0.90492815]))
# (('__label__tl',), array([0.97383624]))
# (('__label__tl',), array([0.13461059]))
# (('__label__he',), array([0.99990433]))
# (('__label__gu',), array([0.99977809]))
# (('__label__lt',), array([0.99780113]))
# (('__label__pl',), array([0.99638212]))
# (('__label__mk',), array([0.93353224]))
# (('__label__de',), array([0.9968136]))
# (('__label__lt',), array([0.98666358]))
# (('__label__te',), array([0.99980944]))
# (('__label__zh',), array([0.99357271]))
# (('__label__nl',), array([0.98459274]))
# (('__label__ur',), array([0.72801983]))
# (('__label__cs',), array([0.96678764]))
# (('__label__de',), array([0.99592352]))
# (('__label__mk',), array([0.96938014]))
# (('__label__nn',), array([0.98733407]))
# (('__label__zh',), array([0.99888515]))
# (('__label__zh',), array([0.99607056]))
# (('__label__hu',), array([0.98660129]))
# (('__label__zh',), array([0.98743796]))
# (('__label__mk',), array([0.9560799]))
# (('__label__bg',), array([0.4488917]))
# (('__label__sk',), array([0.76563454]))
# (('__label__ar',), array([0.99534589]))
# (('__label__el',), array([0.99686724]))
# (('__label__gu',), array([0.99987441]))
# (('__label__en',), array([0.91757524]))
# (('__label__nn',), array([0.82556492]))
# (('__label__et',), array([0.93522352]))
# (('__label__ar',), array([0.98940665]))
# (('__label__id',), array([0.87429839]))
# (('__label__ur',), array([0.8854689]))
# (('__label__ta',), array([0.99970198]))
# (('__label__ta',), array([0.99981433]))
# (('__label__ml',), array([0.99933976]))
# (('__label__fi',), array([0.97166622]))
# (('__label__sq',), array([0.98715746]))
# (('__label__hu',), array([0.98510981]))
# (('__label__gu',), array([0.9999755]))
# (('__label__lv',), array([0.92871428]))
# (('__label__ja',), array([1.00004756]))
# (('__label__ta',), array([0.99966681]))
# (('__label__ro',), array([0.9930858]))
# (('__label__ml',), array([0.99962461]))
# (('__label__gu',), array([0.99983746]))
# (('__label__pt',), array([0.89593232]))
# (('__label__fi',), array([0.98931539]))
# (('__label__id',), array([0.86407751]))
# (('__label__lv',), array([0.95193338]))
# (('__label__ht',), array([0.1485973]))
# (('__label__zh',), array([0.99033707]))
# (('__label__ru',), array([0.98781389]))
# (('__label__sh',), array([0.36447319]))
# (('__label__th',), array([0.99966419]))
# (('__label__sk',), array([0.96900225]))
# (('__label__ro',), array([0.99882758]))
# (('__label__de',), array([0.95730436]))
# (('__label__hu',), array([0.98748887]))
# (('__label__ko',), array([1.00006437]))
# (('__label__ro',), array([0.97125453]))
# (('__label__de',), array([0.98585808]))
# (('__label__hi',), array([0.98619211]))
# (('__label__bn',), array([0.98940903]))
# (('__label__hi',), array([0.99251145]))
# (('__label__da',), array([0.88324177]))
# (('__label__ru',), array([0.99093634]))
# (('__label__zh',), array([0.99986821]))
# (('__label__zh',), array([0.99982089]))
# (('__label__en',), array([0.98938268]))
# (('__label__zh',), array([0.97180688]))
# (('__label__zh',), array([0.99989218]))
# (('__label__ar',), array([0.98816764]))
# (('__label__te',), array([0.99978012]))
# (('__label__ko',), array([1.00006878]))
# (('__label__ur',), array([0.93560821]))
# (('__label__vi',), array([0.99770641]))
# (('__label__ml',), array([0.99917489]))
# (('__label__fa',), array([0.99226201]))
# (('__label__sq',), array([0.98294193]))
# (('__label__ja',), array([1.00003397]))
# (('__label__hu',), array([0.99377298]))
# (('__label__hu',), array([0.98834115]))
# (('__label__bn',), array([0.99581242]))
# (('__label__id',), array([0.8614217]))
# (('__label__pl',), array([0.99457484]))
# (('__label__ru',), array([0.95172602]))
# (('__label__uk',), array([0.98162848]))
# (('__label__el',), array([0.99697167]))
# (('__label__id',), array([0.68570524]))
# (('__label__fi',), array([0.99070704]))
# (('__label__fa',), array([0.97364056]))
# (('__label__ja',), array([0.99978828]))
# (('__label__th',), array([0.99984688]))
# (('__label__th',), array([0.99937582]))
# (('__label__hu',), array([0.98797363]))
# (('__label__ja',), array([1.00000155]))
# (('__label__fi',), array([0.99616402]))
# (('__label__ta',), array([0.99967408]))
# (('__label__el',), array([0.99484658]))
# (('__label__zh',), array([0.99951243]))
# (('__label__sq',), array([0.99202937]))
# (('__label__nn',), array([0.83348382]))
# (('__label__ko',), array([1.0000689]))
# (('__label__ru',), array([0.97776926]))
# (('__label__lt',), array([0.96235836]))
# (('__label__ko',), array([1.00006974]))
# (('__label__bg',), array([0.82681763]))
# (('__label__ar',), array([0.98862267]))
# (('__label__ta',), array([0.99976367]))
# (('__label__en',), array([0.94233537]))
# (('__label__pt',), array([0.88370723]))
# (('__label__bn',), array([0.99857938]))
# (('__label__de',), array([0.99765044]))
# (('__label__ur',), array([0.45502388]))
# (('__label__mk',), array([0.91794288]))
# (('__label__pt',), array([0.97786677]))
# (('__label__mk',), array([0.91607952]))
# (('__label__pt',), array([0.94188994]))
# (('__label__zh',), array([0.99590093]))
# (('__label__hr',), array([0.67288899]))
# (('__label__sk',), array([0.89498276]))
# (('__label__te',), array([0.99992436]))
# (('__label__it',), array([0.99182552]))
# (('__label__te',), array([0.99988598]))
# (('__label__th',), array([0.99950534]))
# (('__label__gu',), array([0.99926281]))
# (('__label__hu',), array([0.98887014]))
# (('__label__sk',), array([0.83776331]))
# (('__label__pl',), array([0.98538405]))
# (('__label__fi',), array([0.9944911]))
# (('__label__id',), array([0.80632168]))
# (('__label__ru',), array([0.98947632]))
# (('__label__fi',), array([0.98539096]))
# (('__label__ta',), array([0.99979293]))
# (('__label__mk',), array([0.93554848]))
# (('__label__da',), array([0.83178973]))
# (('__label__he',), array([0.99962205]))
# (('__label__pt',), array([0.93673968]))
# (('__label__uk',), array([0.99599767]))
# (('__label__tr',), array([0.99180758]))
# (('__label__nl',), array([0.9798739]))
# (('__label__ta',), array([0.99987179]))
# (('__label__tl',), array([0.93389755]))
# (('__label__lt',), array([0.96199393]))
# (('__label__lt',), array([0.95693612]))
# (('__label__ml',), array([0.99932671]))
# (('__label__hu',), array([0.98617524]))
# (('__label__sh',), array([0.2973361]))
# (('__label__zh',), array([0.99558848]))
# (('__label__fr',), array([0.99107963]))
# (('__label__hu',), array([0.98269522]))
# (('__label__ko',), array([1.00006914]))
# (('__label__he',), array([0.99983567]))
# (('__label__de',), array([0.99632257]))
# (('__label__ar',), array([0.99135524]))
# (('__label__el',), array([0.99700159]))
# (('__label__uk',), array([0.99491036]))
# (('__label__ta',), array([0.99955785]))
# (('__label__ta',), array([0.99997729]))
# (('__label__ko',), array([1.0000689]))
# (('__label__en',), array([0.97930628]))
# (('__label__ro',), array([0.98303586]))
# (('__label__uk',), array([0.9782452]))
# (('__label__zh',), array([0.95473647]))
# (('__label__da',), array([0.83708334]))

# %%
x_train
# Out:
#                                                       Par
# 0       Klement Gottwaldi surnukeha palsameeriti ning ...
# 1       Sebes, Joseph; Pereira Thomas (1961) (på eng)....
# 4       ถนนเจริญกรุง (อักษรโรมัน: Thanon Charoen Krung...
# 7       He was a economics graduate from Elphinstone C...
# 13      விசாகப்பட்டினம் தமிழ்ச்சங்கத்தை இந்துப் பத்திர...
# 14      Bùi Tiến Dũng (sinh năm 1959 tại huyện Ứng Hòa...
# 19      UNC有得一只历史悠久个'诚信守则'。渠是由学堂个诚信法庭（Honor Court）来执行个...
# 26      De spons behoort tot het geslacht Haliclona en...
# 29      エノが行きがかりでバスに乗ってしまい、気分が悪くなった際に助けるが、今すぐバスを降りたいと運...
# 38      Tsutinalar (İngilizce: Tsuut'ina): Kanada'da A...
# 44      برقی بار (electric charge) تمام زیرجوہری ذرات ...
# 46      シャーリー・フィールドは、サン・ベルナルド・アベニュー沿い市民センターとR&Tマーティン高校...
# 49      Kemunculan pertamanya adalah ketika mencium ka...
# 51      1998年11月，一位中年女人自創燒炭自殺，將自己同燒烤爐封響沖涼房裏面。由於呢種方法之前，...
# 52      Indtil 1545 havde flådecheferne kunnet hyre et...
# 53      Barocco (pt: Escândalo de 1ª página) é um film...
# 54      Association de recherche et de sauvegarde de l...
# 67      胡赛尼本人和小说的主人公阿米尔一样，都是出生在阿富汗首都喀布尔，少年时代便离开了这个国家。胡...
# 68      한국에서 성씨가 사용되기 시작한 정확한 시기는 알 수 없으나, 한자(漢字) 등 중국...
# 73      Разположено е в полите на планината Плана и из...
# 74      การฟาดฟันของบรรดาสาวงามในกองประกวด Miss Beauty...
# 86      Dorota Rabczewska, artistinimega Doda (sündinu...
# 88      Diante destes gerenciamentos, podendo ser feit...
# 90      Besemer, S., Van der Geest, V., Murray, J., Bi...
# 93      महाराष्ट्र, १ मई १९६० को भारत का राज्य बनाया ग...
# 101     ஆங்கில எழுத்துக்களை மட்டும் அல்லாமல் பன்மொழி எ...
# 119     En Navidad de 1974, poco después de que interp...
# 120     Маратѐа (на италиански: Maratea, на местен диа...
# 125     La chirurgie comprenant principalement l'ablat...
# 126     Dès les années 1920, les communes voisines d'A...
# ...                                                   ...
# 117333  Fnatmide (Sarcoptes scabiei) er en type mide, ...
# 117337  פרופיל B (warm and wet)- תחת פרופיל זה החולה ע...
# 117342  Podemos fazer a mesma coisa durante anos, sem,...
# 117346  Мустанг групується навколо річки Калі-Гандакі ...
# 117347  20 Haziran 2012 tarihinde Arianespace, Kazakis...
# 117351  In Schiedam bevinden zich ongeveer 35 scholen ...
# 117361  வாராந்தாவினைச் சார்ந்த பகுதியில் டீ/காஃபி பெறு...
# 117364  Si Papa Benedicto IX (c. 1012 – c. 1056) na ip...
# 117375  Džingulis – tradicinis lietuvių liaudies ritmi...
# 117381  Birželio 13 d. – Gintaras Goda, teisininkas, t...
# 117382  സ്വർഗ്ഗവാതിലിന് മുൻപിൽ നിന്നു പോലും നരകത്തിലേക...
# 117383  Megjelenésekor a kritikusok kedvezően fogadták...
# 117391  Temelj je proizvodne linije koja se primjenjuj...
# 117412  4月8日首度訪泰，在新聞發布會現場超過200名記者爭相採訪，泰國主要的7頻道及報章雜誌等均大...
# 117415  En 1926, Tibor Radó demanda si le prolongement...
# 117418  A Kőröshegyi völgyhíd viadukt az M7-es autópál...
# 117422  2012년에 피니와 퍼브는 Marble Entertainment와 한 만화에 등장하...
# 117423  בשנת תר"א 1841 נפטר רבי יעקב קאזיס, רבה של מנט...
# 117433  Kaspar Deutschenbaur, auch Caspar Deutschenbau...
# 117438  ابن العلقمي وزير الخليفة العباسي المستعصم، رتب...
# 117450  Από το 1970 βρήκε καλλιτεχνικό καταφύγιο στην ...
# 117454  Олександр Денисенко є членом Національної спіл...
# 117459  மொகமது ஃபுவாத் மசூம் (Muhammad Fuad Masum, குர...
# 117465  மூர்த்தி திருநாமம் :- அகிலாண்டேசுரர் அம்பாள் ப...
# 117468  현대 한국은 종교가 기독교인 사람이 꽤 많기 때문에 이와 연관된 서양식 성명을 갖는...
# 117480  During World Class' golden era, Hart was also ...
# 117489  Atractus edioi este o specie de șerpi din genu...
# 117492  2010 року серед 201 особи працездатного віку (...
# 117497  同年，太后崩。絳侯周勃、陳平諸臣共謀誅呂。朱虛侯章已殺呂產，文帝使人持節勞章。朱虛侯欲奪節信...
# 117498  I det mindste opnåede Venedig den 18. april 14...
#
# [24000 rows x 1 columns]

# %%
ft_names = []
for i in range(len(ft_predict)):
    if len(ft_predict[i]) == 3:
        ft_names.append('nan')
    else:
        lang_name = languages.get(alpha_2=ft_predict[i]).name
        if '(' in lang_name:
            ft_names.append(re.sub("[(\[].*?[\)]", "", lang_name)[:-1])
        else:
            ft_names.append(lang_name)

# %%
acc = accuracy_score(y_tr_new_1k, ft_names)
print("Accuracy: ", acc)
# Out:
# Accuracy:  0.915125

# %%
# Out:
# 0         Estonian
# 1          Swedish
# 2             Thai
# 3         Gujarati
# 4            Tamil
# 5       Vietnamese
# 6          Chinese
# 7            Dutch
# 8         Japanese
# 9          Turkish
# 10            Urdu
# 11        Japanese
# 12      Indonesian
# 13         Chinese
# 14          Danish
# 15      Portuguese
# 16          French
# 17         Chinese
# 18          Korean
# 19       Bulgarian
# 20            Thai
# 21        Estonian
# 22      Portuguese
# 23      Portuguese
# 24           Hindi
# 25           Tamil
# 26         Spanish
# 27       Bulgarian
# 28          French
# 29          French
#            ...
# 9970        Hebrew
# 9971       Chinese
# 9972       Tagalog
# 9973       Persian
# 9974         Czech
# 9975       Turkish
# 9976    Portuguese
# 9977    Lithuanian
# 9978       Finnish
# 9979     Hungarian
# 9980        Danish
# 9981       Swedish
# 9982       English
# 9983       Persian
# 9984          Thai
# 9985        Arabic
# 9986          Urdu
# 9987       Spanish
# 9988      Estonian
# 9989          Urdu
# 9990       Finnish
# 9991        Danish
# 9992         Tamil
# 9993    Indonesian
# 9994        Danish
# 9995      Gujarati
# 9996        Polish
# 9997      Gujarati
# 9998        Arabic
# 9999        Slovak
# Name: English, Length: 10000, dtype: object

# %%
import sys
import gzip
import json

## FastText 
#!pip install fasttext
import fasttext
# download this pretrained model 
model = fasttext.load_model('fast_text_model/lid.176.ftz')

#!pip install pycountry
from pycountry import languages


def get_lang(text):
    '''
    This function uses the pretrained model from FastText 
    to detect the language of a document. 
    It returns a tuple in the form of (('__label__en',), array([0.26207453]))
    '''
    predicted_lang = model.predict(text)
    # only keep the language code such as 'en' from the output of the prediction
    ft_predict = predicted_lang[0][0][9:]
    
    # We need to convert the ISO 639 codes to find full name of the language for each symbol.
    # From the 46 common languages we aimed to detect, they all have two letter codes. 
    if len(ft_predict) != 2:
        ft_names = 'nan'
        
    else:
        # Convert to full name in English 
        lang_name = languages.get(alpha_2=ft_predict).name
        # We only keep the full name of the language
        if '(' in lang_name:
            ft_names= re.sub("[(\[].*?[\)]", "", lang_name)[:-1]
        else:
            ft_names = lang_name
    return ft_names

if __name__ == '__main__':
    
    #Json_path = sys.argv[1]
    Json_path = 'Data/Jobs/linkedin/FF64062CA67CA0E0C4D1720A676C6637_.gz'
    
    with gzip.GzipFile(Json_path,"r") as json_file:
        job = json.load(json_file)
        text = job['Body']
        job['Language'] = get_lang(text) 

    json_str = json.dumps(job, indent = 4) + "\n"   

    with open(Json_path+'new_lang', 'w') as outfile:
        outfile.write(json_str)

# %%
import sys
import gzip
import json


def get_lang(text):

    return ''

if __name__ == '__main__':
    
    Json_path = sys.argv[1]
    with open(Json_path,"r") as json_file:
        job = json.load(json_file)
        text = job['Body']
        job['Language'] = get_lang(text) 

    json_str = json.dumps(job, indent = 4) + "\n"   

    with open(Json_path+'new_lang', 'w') as outfile:
        outfile.write(json_str)
# Out:
# <_io.TextIOWrapper name='Data/Jobs/linkedin/0A0BBE99D9A73C88E82671CAB37247FD_.gz' mode='r' encoding='UTF-8'>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-222-4f1706bd4b13> in <module>
#       2 a ffs
#       3 '''
# ----> 4 sds
#
# NameError: name 'sds' is not defined
